# %% [markdown]
# ### Commands

# %%
from firecloud import api as firecloud_api
import glob
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### Parameters
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"
paths_to_samples_info = "paths_to_batches_info.xlsx"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"
batches_info = pd.read_excel(paths_to_samples_info)

# %% [markdown]
# #### Deletions

# %%
### Delete unnecessary attributes in samples
attrs = ["annotate_variants_vcf", "annotate_variants_vcf_index", "oncotated_maf", "mutect2_vcf_index", "match_normal_oncotated_maf", "gnomad_vcf", "merged_vcfs", "match_primary_tumor_bam_file"]
for idx, row in all_samples.iterrows():
    fc_interface.delete_entity_attributes(namespace, workspace, "sample", row['entity:sample_id'], attrs)

# %%
### Delete method repostory
firecloud_api.delete_repository_method('tsca', 'CreatePoN', 15)

# %%
### Delete method repository
firecloud_api.delete_repository_method('tsca', 'Mutect2_for_Normal', 1)

# %%
### Delete multiple method repositories
for i in range(10, 23):
    firecloud_api.delete_repository_method('tsca', 'CreatePoN', i)

# %%
### Delete method config
firecloud_api.delete_workspace_config(namespace, workspace, "tsca", "Mutect2_for_Normal")

# %% [markdown]
# #### Pair creation

# %%
### Create pairs
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
### Upload pairs
res = fc_interface.upload_pairs(namespace, workspace, clean_pairs_list)

# %%
# ### Delete unnecessary attributes in pairs
# ### NOT WOKING
# all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
# pairs_list = fc_interface.create_pairs_list(all_samples)
# attrs = ["__annotate_variants_vcf", "__annotate_variants_vcf_index", \
#          "__scattered_intervals", "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2", \
#          "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2"]
# for idx, row in pairs_list.iterrows():
#     fc_interface.delete_entity_attributes(namespace, workspace, "pair", row['entity:pair_id'], attrs)

# %%
### Upload metadata for given batch
fc_interface.update_batch_metadata('TSCA21', \
                                  '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                                      paths_to_samples_info, \
                                        namespace, workspace, google_bucket_id)

# %%
### Delete sample_set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### All paths to batch info
# pd.read_excel('paths_to_batches_info.xlsx').path_to_samples_info.tolist()

# %%
### Create cumulative PoN (all batches)
batches_info = pd.read_excel(paths_to_samples_info)
PoN = fc_interface.create_panel_of_normals(batches_info.path_to_samples_info.tolist(), -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'CumPoN21', namespace, workspace)

# %%
### Create PoN from normals of only one batch (no samples from other batches)
batches_info = pd.read_excel(paths_to_samples_info)
tsca21_path = batches_info.path_to_samples_info.tolist()[-1]
PoN = fc_interface.create_panel_of_normals([tsca21_path], -1, 'PoN_TSCA21_Normals')
fc_interface.upload_pon(PoN, 'PoN_TSCA21_Normals', namespace, workspace)

# %%
### Delete pair set
fc_interface.delete_pair_set(namespace, workspace, 'TSCA1213')

# %%
### Delete sample set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### Download method configs
fc_interface.download_method_configs(namespace, workspace)

# %%
### Upload pairsets
tn_pairsets, tp_pairsets = fc_interface.create_pairsets(all_samples, clean_pairs_list)
fc_interface.upload_pairsets(namespace, workspace, tn_pairsets, "TN")
fc_interface.upload_pairsets(namespace, workspace, tp_pairsets, "TP")

# %%
### Delete all pairs
for idx, row in clean_pairs_list.iterrows():
    res = fc_interface.delete_pair(namespace, workspace, row['entity:pair_id'])
    print(res)

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

### Update pair attributes
update_pair_attrs(namespace, workspace, clean_pairs_list, attrs=['control_sample_tsca_id'])

# %%
### Create PoN from all normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
### Create PoN with normals from batch + other normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
# PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
# fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
# batch_id = 'TSCA21'
# batch_path = batches_info.loc[batches_info.tsca_id==batch_id, 'path_to_samples_info'].item()
# pd.read_table(batch_path)
# batch_id, paths, N, name

# %%
# Retrieve samples before export to FC
tsca21 = \
    fc_interface.\
        prepare_batch_samples_for_metadata_export('/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                            'TSCA21', google_bucket_id)

# %%
### Update WDLs
fc_interface.download_remote_wdls(namespace, workspace)

# %%
### Prepare cohorts for export to FC
cohorts = fc_interface.prepare_cohorts_for_metadata_export(paths_to_batches_info, google_bucket_id)

# %%
# # Delete cohorts
# cohort_codes = pd.read_table('cohort_files/cohort_names_dictionary.txt', header=None)
# for coh_code in cohort_codes.loc[:, 1].tolist():
#     res = fc_interface.delete_sample_set(namespace, workspace, coh_code)

# %%
# ### Upload metadata for given batch
# fc_interface.update_batch_metadata('TSCA21', \
#                                   '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
#                                       paths_to_samples_info, \
#                                         namespace, workspace, google_bucket_id)
# Out:
# 65 Participants in this batch
# 95 Samples in this batch

# %%
# Export metadata
(r1, r2, r3, r4, r5, r6) = fc_interface.export_batch_metadata_to_fc('TSCA21', namespace, workspace)

# %%
# Cohorts
cohorts = fc_interface.prepare_cohorts_for_metadata_export(paths_to_batches_info, google_bucket_id)

# %%
### Create panel of normals from batch
pon = fc_interface.create_panel_of_normals_from_batch(batch_id, paths_to_samples_info, N=20).shape

# %%
### Create panel of normals from batch
for i, row in batches_info.iterrows():
    pon, name = fc_interface.create_panel_of_normals_from_batch(row['tsca_id'], paths_to_samples_info, N=20)
    fc_interface.upload_pon(pon, name, namespace, workspace)

# %%
# Retrieve samples before export to FC
tsca21 = \
    fc_interface.\
        prepare_batch_samples_for_metadata_export('/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                            'TSCA21', google_bucket_id)

# %%
### Prepare cohorts for export to FC
cohorts = fc_interface.\
            prepare_cohorts_for_metadata_export(paths_to_samples_info, google_bucket_id, \
                                               blacklist=["CCLF_AA1012-Tumor-SM-F67DF"])

cohorts_sample_set_metadata = "cohort_files/fc_upload_sample_set_cohorts.txt"
res = fc_interface.upload_entities_from_tsv(namespace, workspace, cohorts_sample_set_metadata)

# %%
# Export metadata
(r1, r2, r3, r4, r5, r6) = fc_interface.export_batch_metadata_to_fc('TSCA21', namespace, workspace)

# %%
### Cohort of all tumors
res = fc_interface.upload_cohort_all_tumors(paths_to_samples_info, google_bucket_id, \
                                      'Cum_Tumors_22_all', namespace, workspace, ['DW039-Tumor-SM-DB2IF'])

# %%
# fc_interface.merge_walkupseq_files(paths_to_samples_info)
# Out:
# (1045, 14)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
fc_interface.update_bsp_data(curr_tsca_id="TSCA22", prev_tsca_id="TSCA21")
# Out:
#     18S/28S Ratio  Age BSP Notes BSP Notes PT  Cell Count  \
# 0             NaN  NaN       NaN          NaN   2000000.0
# 1             NaN  NaN       NaN          NaN   2000000.0
# 2             NaN  NaN       NaN          NaN   2000000.0
# 3             NaN  NaN       NaN          NaN   3000000.0
# 4             NaN  NaN       NaN          NaN   2000000.0
# 5             NaN  NaN       NaN    pediatric   2630000.0
# 6             NaN  NaN       NaN    pediatric   8070000.0
# 7             NaN  NaN       NaN          NaN   3980000.0
# 8             NaN  NaN       NaN    pediatric   1760000.0
# 9             NaN   55       NaN          NaN   7100000.0
# 10            NaN  NaN       NaN          NaN         0.0
# 11            NaN  NaN       NaN          NaN         0.0
# 12            NaN  NaN       NaN          NaN         0.0
# 13            NaN  NaN       NaN          NaN         0.0
# 14            NaN  NaN       NaN          NaN         0.0
# 15            NaN  NaN       NaN          NaN         0.0
# 16            NaN  NaN       NaN          NaN         0.0
# 17            NaN  NaN       NaN          NaN         0.0
# 18            NaN  NaN       NaN          NaN         0.0
# 19            NaN  NaN       NaN          NaN         0.0
# 20            NaN  NaN       NaN          NaN         0.0
# 21            NaN  NaN       NaN          NaN         0.0
# 22            NaN  NaN       NaN          NaN         0.0
# 23            NaN  NaN       NaN          NaN         0.0
# 24            NaN  NaN       NaN          NaN         0.0
# 25            NaN  NaN       NaN          NaN         0.0
# 26            NaN  NaN       NaN          NaN         0.0
# 27            NaN  NaN       NaN          NaN         0.0
# 28            NaN  NaN       NaN          NaN         0.0
# 29            NaN  NaN       NaN          NaN         0.0
# ..            ...  ...       ...          ...         ...
# 66            NaN  NaN       NaN          NaN         0.0
# 67            NaN  NaN       NaN          NaN         0.0
# 68            NaN  NaN       NaN          NaN         0.0
# 69            NaN  NaN       NaN          NaN   1629000.0
# 70            NaN  NaN       NaN          NaN   3438000.0
# 71            NaN  NaN       NaN          NaN         0.0
# 72            NaN  NaN       NaN          NaN         0.0
# 73            NaN  NaN       NaN          NaN         0.0
# 74            NaN  NaN       NaN          NaN  12123000.0
# 75            NaN  NaN       NaN          NaN         0.0
# 76            NaN  NaN       NaN          NaN         0.0
# 77            NaN  NaN       NaN          NaN         0.0
# 78            NaN  NaN       NaN          NaN         0.0
# 79            NaN  NaN       NaN          NaN         0.0
# 80            NaN  NaN       NaN          NaN         0.0
# 81            NaN  NaN       NaN          NaN         0.0
# 82            NaN  NaN       NaN          NaN         0.0
# 83            NaN  NaN       NaN          NaN         0.0
# 84            NaN  NaN       NaN          NaN         0.0
# 85            NaN  NaN       NaN          NaN         0.0
# 86            NaN  NaN       NaN          NaN         0.0
# 87            NaN  NaN       NaN          NaN         0.0
# 88            NaN  NaN       NaN          NaN         0.0
# 89            NaN  NaN       NaN          NaN         0.0
# 90            NaN  NaN       NaN          NaN         0.0
# 91            NaN  NaN       NaN          NaN         0.0
# 92            NaN  NaN       NaN          NaN         0.0
# 93            NaN  NaN       NaN          NaN   1008000.0
# 94            NaN  NaN       NaN          NaN   4554000.0
# 95            NaN  NaN       NaN          NaN         0.0
#
#     Collaborator Family ID  Collaborator NCI Plate ID  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
# 8                      NaN                        NaN
# 9                      NaN                        NaN
# 10                     NaN                        NaN
# 11                     NaN                        NaN
# 12                     NaN                        NaN
# 13                     NaN                        NaN
# 14                     NaN                        NaN
# 15                     NaN                        NaN
# 16                     NaN                        NaN
# 17                     NaN                        NaN
# 18                     NaN                        NaN
# 19                     NaN                        NaN
# 20                     NaN                        NaN
# 21                     NaN                        NaN
# 22                     NaN                        NaN
# 23                     NaN                        NaN
# 24                     NaN                        NaN
# 25                     NaN                        NaN
# 26                     NaN                        NaN
# 27                     NaN                        NaN
# 28                     NaN                        NaN
# 29                     NaN                        NaN
# ..                     ...                        ...
# 66                     NaN                        NaN
# 67                     NaN                        NaN
# 68                     NaN                        NaN
# 69                     NaN                        NaN
# 70                     NaN                        NaN
# 71                     NaN                        NaN
# 72                     NaN                        NaN
# 73                     NaN                        NaN
# 74                     NaN                        NaN
# 75                     NaN                        NaN
# 76                     NaN                        NaN
# 77                     NaN                        NaN
# 78                     NaN                        NaN
# 79                     NaN                        NaN
# 80                     NaN                        NaN
# 81                     NaN                        NaN
# 82                     NaN                        NaN
# 83                     NaN                        NaN
# 84                     NaN                        NaN
# 85                     NaN                        NaN
# 86                     NaN                        NaN
# 87                     NaN                        NaN
# 88                     NaN                        NaN
# 89                     NaN                        NaN
# 90                     NaN                        NaN
# 91                     NaN                        NaN
# 92                     NaN                        NaN
# 93                     NaN                        NaN
# 94                     NaN                        NaN
# 95                     NaN                        NaN
#
#    Collaborator Participant ID  Collaborator Participant ID_2  \
# 0                        DW027                            NaN
# 1                        DW031                            NaN
# 2                        DW031                            NaN
# 3                        DW032                            NaN
# 4                        DW033                            NaN
# 5                    COG-H-430                            NaN
# 6                     CHLA-200                            NaN
# 7                       UM-UC9                            NaN
# 8                   COG-AR-359                            NaN
# 9                         SW13                            NaN
# 10                       JNT49                            NaN
# 11                       JNT50                            NaN
# 12                       JNT51                            NaN
# 13                       JNT52                            NaN
# 14                       JNT53                            NaN
# 15                       JNT54                            NaN
# 16                       JNT55                            NaN
# 17                       JNT56                            NaN
# 18                       JNT57                            NaN
# 19                       JNT58                            NaN
# 20                       JNT59                            NaN
# 21                       JNT60                            NaN
# 22                       JNT61                            NaN
# 23                       JNT62                            NaN
# 24                       JNT63                            NaN
# 25                       JNT64                            NaN
# 26                       JNT65                            NaN
# 27                       JNT66                            NaN
# 28                       JNT67                            NaN
# 29                       JNT68                            NaN
# ..                         ...                            ...
# 66                 CCLF_KL1103                            NaN
# 67                 CCLF_KL1107                            NaN
# 68               CCLF_RCRF1010                            NaN
# 69               CCLF_PEDS1034                            NaN
# 70               CCLF_PEDS1040                            NaN
# 71                 CCLF_KL1124                            NaN
# 72                 CCLF_KL1113                            NaN
# 73                 CCLF_AB1018                            NaN
# 74                       CY020                            NaN
# 75                 CCLF_KL1051                            NaN
# 76               CCLF_RCRF1014                            NaN
# 77                 CCLF_AA1038                            NaN
# 78                 CCLF_KL1058                            NaN
# 79                 CCLF_NB1001                            NaN
# 80                       EW012                            NaN
# 81               CCLF_PEDS1040                            NaN
# 82               CCLF_PEDS1047                            NaN
# 83                 CCLF_KL1082                            NaN
# 84                 CCLF_SS1009                            NaN
# 85                 CCLF_KL1051                            NaN
# 86                       TC011                            NaN
# 87                 CCLF_AA1005                            NaN
# 88                       TC013                            NaN
# 89                 CCLF_AB1028                            NaN
# 90                 CCLF_AB1032                            NaN
# 91                       EH031                            NaN
# 92                       HG018                            NaN
# 93               CCLF_PEDS1041                            NaN
# 94               CCLF_PEDS1040                            NaN
# 95                 CCLF_KL1121                            NaN
#
#     Collaborator Participant ID_3      ...        \
# 0                             NaN      ...
# 1                             NaN      ...
# 2                             NaN      ...
# 3                             NaN      ...
# 4                             NaN      ...
# 5                             NaN      ...
# 6                             NaN      ...
# 7                             NaN      ...
# 8                             NaN      ...
# 9                             NaN      ...
# 10                            NaN      ...
# 11                            NaN      ...
# 12                            NaN      ...
# 13                            NaN      ...
# 14                            NaN      ...
# 15                            NaN      ...
# 16                            NaN      ...
# 17                            NaN      ...
# 18                            NaN      ...
# 19                            NaN      ...
# 20                            NaN      ...
# 21                            NaN      ...
# 22                            NaN      ...
# 23                            NaN      ...
# 24                            NaN      ...
# 25                            NaN      ...
# 26                            NaN      ...
# 27                            NaN      ...
# 28                            NaN      ...
# 29                            NaN      ...
# ..                            ...      ...
# 66                            NaN      ...
# 67                            NaN      ...
# 68                            NaN      ...
# 69                            NaN      ...
# 70                            NaN      ...
# 71                            NaN      ...
# 72                            NaN      ...
# 73                            NaN      ...
# 74                            NaN      ...
# 75                            NaN      ...
# 76                            NaN      ...
# 77                            NaN      ...
# 78                            NaN      ...
# 79                            NaN      ...
# 80                            NaN      ...
# 81                            NaN      ...
# 82                            NaN      ...
# 83                            NaN      ...
# 84                            NaN      ...
# 85                            NaN      ...
# 86                            NaN      ...
# 87                            NaN      ...
# 88                            NaN      ...
# 89                            NaN      ...
# 90                            NaN      ...
# 91                            NaN      ...
# 92                            NaN      ...
# 93                            NaN      ...
# 94                            NaN      ...
# 95                            NaN      ...
#
#                                    Stock Type Changed    Tissue Site  \
# 0   Stock Type changed from Not Stock to Active Stock          Blood
# 1   Stock Type changed from Not Stock to Active Stock          Blood
# 2   Stock Type changed from Not Stock to Active Stock          Blood
# 3   Stock Type changed from Not Stock to Active Stock          Blood
# 4   Stock Type changed from Not Stock to Active Stock          Blood
# 5   Stock Type changed from Not Stock to Active Stock          Liver
# 6   Stock Type changed from Not Stock to Active Stock          Brain
# 7   Stock Type changed from Not Stock to Active Stock        Bladder
# 8   Stock Type changed from Not Stock to Active Stock          Brain
# 9   Stock Type changed from Not Stock to Active Stock  Adrenal Gland
# 10                                                NaN            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19                                                NaN            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN            NaN
# 23                                                NaN            NaN
# 24                                                NaN            NaN
# 25                                                NaN            NaN
# 26                                                NaN            NaN
# 27                                                NaN            NaN
# 28                                                NaN            NaN
# 29                                                NaN            NaN
# ..                                                ...            ...
# 66                                                NaN            NaN
# 67                                                NaN            NaN
# 68                                                NaN            NaN
# 69                                                NaN            NaN
# 70                                                NaN            NaN
# 71                                                NaN            NaN
# 72                                                NaN            NaN
# 73                                                NaN            NaN
# 74                                                NaN            NaN
# 75                                                NaN            NaN
# 76                                                NaN            NaN
# 77                                                NaN            NaN
# 78                                                NaN            NaN
# 79                                                NaN            NaN
# 80                                                NaN            NaN
# 81                                                NaN            NaN
# 82                                                NaN            NaN
# 83                                                NaN            NaN
# 84                                                NaN            NaN
# 85                                                NaN            NaN
# 86                                                NaN            NaN
# 87                                                NaN            NaN
# 88                                                NaN            NaN
# 89                                                NaN            NaN
# 90                                                NaN            NaN
# 91                                                NaN            NaN
# 92                                                NaN            NaN
# 93                                                NaN            NaN
# 94                                                NaN            NaN
# 95                                                NaN            NaN
#
#     Tissue Site Misc                                  Tube Type Changed  \
# 0                NaN  Tube Type changed from Cryo vial [2.0 (1.8)mL]...
# 1                NaN  Tube Type changed from Cryo vial [2.0 (1.8)mL]...
# 2                NaN  Tube Type changed from Cryo vial [2.0 (1.8)mL]...
# 3                NaN  Tube Type changed from Cryo vial [2.0 (1.8)mL]...
# 4                NaN  Tube Type changed from Cryo vial [2.0 (1.8)mL]...
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 7                NaN                                                NaN
# 8                NaN                                                NaN
# 9                NaN                                                NaN
# 10               NaN                                                NaN
# 11               NaN                                                NaN
# 12               NaN                                                NaN
# 13               NaN                                                NaN
# 14               NaN                                                NaN
# 15               NaN                                                NaN
# 16               NaN                                                NaN
# 17               NaN                                                NaN
# 18               NaN                                                NaN
# 19               NaN                                                NaN
# 20               NaN                                                NaN
# 21               NaN                                                NaN
# 22               NaN                                                NaN
# 23               NaN                                                NaN
# 24               NaN                                                NaN
# 25               NaN                                                NaN
# 26               NaN                                                NaN
# 27               NaN                                                NaN
# 28               NaN                                                NaN
# 29               NaN                                                NaN
# ..               ...                                                ...
# 66               NaN                                                NaN
# 67               NaN                                                NaN
# 68               NaN                                                NaN
# 69               NaN                                                NaN
# 70               NaN                                                NaN
# 71               NaN                                                NaN
# 72               NaN                                                NaN
# 73               NaN                                                NaN
# 74               NaN                                                NaN
# 75               NaN                                                NaN
# 76               NaN                                                NaN
# 77               NaN                                                NaN
# 78               NaN                                                NaN
# 79               NaN                                                NaN
# 80               NaN                                                NaN
# 81               NaN                                                NaN
# 82               NaN                                                NaN
# 83               NaN                                                NaN
# 84               NaN                                                NaN
# 85               NaN                                                NaN
# 86               NaN                                                NaN
# 87               NaN                                                NaN
# 88               NaN                                                NaN
# 89               NaN                                                NaN
# 90               NaN                                                NaN
# 91               NaN                                                NaN
# 92               NaN                                                NaN
# 93               NaN                                                NaN
# 94               NaN                                                NaN
# 95               NaN                                                NaN
#
#    Tumor Percent  Tumor Type  UUID  Volume  \
# 0            NaN     Primary   NaN   76.00
# 1            NaN     Primary   NaN   76.00
# 2            NaN     Primary   NaN   97.40
# 3            NaN     Primary   NaN   91.90
# 4            NaN     Primary   NaN   76.00
# 5            NaN     Primary   NaN  296.53
# 6            NaN     Primary   NaN  430.73
# 7            NaN     Primary   NaN  160.00
# 8            NaN     Primary   NaN  225.25
# 9            NaN     Primary   NaN  160.00
# 10           NaN     Primary   NaN    3.00
# 11           NaN     Primary   NaN    3.00
# 12           NaN     Primary   NaN    3.00
# 13           NaN     Primary   NaN    3.00
# 14           NaN     Primary   NaN    3.00
# 15           NaN     Primary   NaN    3.00
# 16           NaN     Primary   NaN    3.00
# 17           NaN     Primary   NaN    3.00
# 18           NaN     Primary   NaN    3.00
# 19           NaN     Primary   NaN    3.00
# 20           NaN  Metastatic   NaN    3.00
# 21           NaN     Primary   NaN    3.00
# 22           NaN     Primary   NaN    3.00
# 23           NaN     Primary   NaN    3.00
# 24           NaN     Primary   NaN    3.00
# 25           NaN     Primary   NaN    3.00
# 26           NaN     Primary   NaN    3.00
# 27           NaN  Metastatic   NaN    3.00
# 28           NaN     Primary   NaN    3.00
# 29           NaN     Primary   NaN    3.00
# ..           ...         ...   ...     ...
# 66           NaN         NaN   NaN   20.00
# 67           NaN         NaN   NaN   20.00
# 68           NaN         NaN   NaN   20.00
# 69           NaN         NaN   NaN   20.00
# 70           NaN         NaN   NaN   20.00
# 71           NaN         NaN   NaN   20.00
# 72           NaN         NaN   NaN   20.00
# 73           NaN         NaN   NaN   20.00
# 74           NaN         NaN   NaN   20.00
# 75           NaN         NaN   NaN   20.00
# 76           NaN         NaN   NaN   20.00
# 77           NaN         NaN   NaN   20.00
# 78           NaN         NaN   NaN   20.00
# 79           NaN         NaN   NaN   20.00
# 80           NaN         NaN   NaN   20.00
# 81           NaN         NaN   NaN   20.00
# 82           NaN         NaN   NaN   20.00
# 83           NaN         NaN   NaN   20.00
# 84           NaN         NaN   NaN   20.00
# 85           NaN         NaN   NaN   20.00
# 86           NaN         NaN   NaN   20.00
# 87           NaN         NaN   NaN   20.00
# 88           NaN         NaN   NaN   20.00
# 89           NaN         NaN   NaN   20.00
# 90           NaN         NaN   NaN   20.00
# 91           NaN         NaN   NaN   20.00
# 92           NaN         NaN   NaN   20.00
# 93           NaN         NaN   NaN   20.00
# 94           NaN         NaN   NaN   20.00
# 95           NaN         NaN   NaN   20.00
#
#                                        Volume Changed  Year of Birth
# 0   Volume changed from 1000.0ul to 150.0ul, Volum...            NaN
# 1   Volume changed from 1000.0ul to 150.0ul, Volum...            NaN
# 2   Volume changed from 1000.0ul to 150.0ul, Volum...            NaN
# 3   Volume changed from 1000.0ul to 150.0ul, Volum...            NaN
# 4   Volume changed from 1000.0ul to 150.0ul, Volum...            NaN
# 5   Volume changed from 316.53ul to 316.53ul, Volu...            NaN
# 6   Volume changed from 470.73ul to 450.73ul, Volu...            NaN
# 7   Volume changed from 180.0ul to 180.0ul, Volume...            NaN
# 8   Volume changed from 245.25ul to 225.25ul, Volu...            NaN
# 9   Volume changed from 180.0ul to 180.0ul, Volume...            NaN
# 10  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 11  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 12  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 13  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 14  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 15  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 16  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 17  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 18  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 19  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 20  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 21  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 22  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 23  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 24  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 25  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 26  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 27  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 28  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# 29  Volume changed from 23.0ul to 3.0ul, Volume ch...            NaN
# ..                                                ...            ...
# 66                                                NaN            NaN
# 67                                                NaN            NaN
# 68                                                NaN            NaN
# 69                                                NaN            NaN
# 70                                                NaN            NaN
# 71                                                NaN            NaN
# 72                                                NaN            NaN
# 73                                                NaN            NaN
# 74                                                NaN            NaN
# 75                                                NaN            NaN
# 76                                                NaN            NaN
# 77                                                NaN            NaN
# 78                                                NaN            NaN
# 79                                                NaN            NaN
# 80                                                NaN            NaN
# 81                                                NaN            NaN
# 82                                                NaN            NaN
# 83                                                NaN            NaN
# 84                                                NaN            NaN
# 85                                                NaN            NaN
# 86                                                NaN            NaN
# 87                                                NaN            NaN
# 88                                                NaN            NaN
# 89                                                NaN            NaN
# 90                                                NaN            NaN
# 91                                                NaN            NaN
# 92                                                NaN            NaN
# 93                                                NaN            NaN
# 94                                                NaN            NaN
# 95                                                NaN            NaN
#
# [1513 rows x 82 columns]

# %% [markdown]
# ## Refined: New Batch Workflow

# %%
tsca_id = "TSCA22"
path_to_batch_samples_info = batches_info.loc[batches_info.tsca_id==tsca_id, 'path_to_samples_info'].item()

# %%
### ALL SAMPLES
## Prepare
# fc_interface.prepare_patients_for_metadata_export(path_to_batch_samples_info, tsca_id)
# fc_interface.prepare_batch_sample_set_for_metadata_export(path_to_batch_samples_info, tsca_id)
# fc_interface.prepare_batch_samples_for_metadata_export(path_to_batch_samples_info, tsca_id, google_bucket_id)

## Export
# fc_interface.export_batch_metadata_to_fc(tsca_id, namespace, workspace)

# %%
### PANEL OF NORMALS BATCH
## Prepare 
# pon, name = fc_interface.create_panel_of_normals_from_batch(tsca_id, paths_to_samples_info, N=20)

# Export
# fc_interface.upload_pon(pon, name, namespace, workspace)

# %%
### PANEL OF NORMALS CUMULATIVE
## Prepare
# batches_info = pd.read_excel(paths_to_samples_info)
# PoN = fc_interface.create_panel_of_normals(batches_info.path_to_samples_info.tolist(), -1, 'Cum_PoN_22_all')

# Export
# fc_interface.upload_pon(PoN, 'Cum_PoN_22_all', namespace, workspace)
# Out:
# Creating panel of 163 normals
# <Response [200]>

# %%
### COHORT SAMPLE SETS
## Prepare
cohorts = fc_interface.prepare_cohorts_for_metadata_export(paths_to_samples_info, google_bucket_id, blacklist, tsca_id)

# %%
cohorts['membership:sample_set_id'].value_counts()
# Out:
# COHORT_PEDS         191
# COHORT_BT           110
# COHORT_CCLF_RCRF     47
# COHORT_CSHL_PDAC     47
# COHORT_AA            39
# COHORT_AB            29
# COHORT_CY            25
# COHORT_EH            22
# COHORT_JL            21
# COHORT_JB            18
# COHORT_SS            16
# COHORT_HG            15
# COHORT_NB            14
# COHORT_TC            13
# COHORT_NH            12
# COHORT_EW            11
# COHORT_DW             8
# COHORT_SP             6
# COHORT_CO             6
# COHORT_COLO           4
# COHORT_JNT            1
# COHORT_GG             1
# COHORT_PM             1
# COHORT_PK             1
# Name: membership:sample_set_id, dtype: int64

# %%
### PAIRS
