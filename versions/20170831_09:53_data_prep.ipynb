# %%
# pd.read_table("/xchip/clf/seq_data/processed_for_fh/tsca20_201707_SN0125362/tsca20_201707_SN0125362.import_samples.txt")

# %%
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
paths_to_batches_info = pd.read_excel("paths_to_batches_info.xlsx")
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)

# %%
all_samples [ all_samples.sample_type == "Normal"].shape
# Out:
# (146, 18)

# %%
pon_name = 'PoN50'
num_normals = 50
PoN = fc_interface.create_panel_of_normals(paths_to_batches_info.path_to_samples_info.tolist(), num_normals, pon_name)
# fc_interface.upload_pon(PoN, pon_name, namespace, workspace)
# Out:
# Creating panel of 50 normals

# %%
fc_interface.delete_sample_set(namespace, work)

# %%
PoN.sort_values(by='sample_id')
# Out:
#     membership:sample_set_id                      sample_id
# 297                    PoN50    CCLF_JL1001-Normal-SM-EUVFR
# 322                    PoN50  CCLF_PEDS1005-Normal-SM-EUVG6
# 270                    PoN50  CCLF_PEDS1011-Normal-SM-E7RZE
# 192                    PoN50  CCLF_PEDS1019-Normal-SM-F67EO
# 93                     PoN50  CCLF_PEDS1021-Normal-SM-E7RZX
# 234                    PoN50  CCLF_PEDS1022-Normal-SM-E7RZ3
# 72                     PoN50  CCLF_PEDS1025-Normal-SM-F29S8
# 96                     PoN50  CCLF_PEDS1026-Normal-SM-EUVHW
# 206                    PoN50  CCLF_PEDS1033-Normal-SM-F29SC
# 118                    PoN50   CCLF_RCRF004-Normal-SM-DHZ5M
# 148                    PoN50  CCLF_RCRF1007-Normal-SM-E7S1M
# 253                    PoN50    CCLF_SS1007-Normal-SM-F67EP
# 7                      PoN50          EH014-Normal-SM-D4L27
# 102                    PoN50          EH014-Normal-SM-D4L35
# 107                    PoN50          EH015-Normal-SM-D4L2J
# 29                     PoN50          EH016-Normal-SM-DB2JP
# 84                     PoN50          EH016-Normal-SM-DHZ69
# 77                     PoN50          EH020-Normal-SM-DB2IQ
# 201                    PoN50          EH021-Normal-SM-DHZ4X
# 241                    PoN50          EH027-Normal-SM-F29SX
# 219                    PoN50           JL54-Normal-SM-D4L3X
# 98                     PoN50           JL57-Normal-SM-DNULJ
# 136                    PoN50           JL58-Normal-SM-D4L4B
# 48                     PoN50           JL58-Normal-SM-DB2JJ
# 85                     PoN50           JL59-Normal-SM-DHZ6D
# 50                     PoN50           JL62-Normal-SM-DHZ6L
# 162                    PoN50        PEDS063-Normal-SM-F67EX
# 188                    PoN50        PEDS153-Normal-SM-D4L1X
# 247                    PoN50        PEDS153-Normal-SM-DB2IU
# 198                    PoN50        PEDS162-Normal-SM-DHZ7Y
# 232                    PoN50        PEDS166-Normal-SM-DB2I5
# 173                    PoN50        PEDS168-Normal-SM-D4L44
# 271                    PoN50        PEDS171-Normal-SM-D4L1V
# 165                    PoN50        PEDS176-Normal-SM-D4L2I
# 62                     PoN50        PEDS177-Normal-SM-DB2IV
# 167                    PoN50        PEDS179-Normal-SM-DHZ7N
# 258                    PoN50        PEDS179-Normal-SM-DHZ8Z
# 79                     PoN50        PEDS182-Normal-SM-DHZA1
# 100                    PoN50        PEDS185-Normal-SM-D4L2Y
# 187                    PoN50        PEDS191-Normal-SM-E7S25
# 281                    PoN50        PEDS194-Normal-SM-DB2IW
# 195                    PoN50        PEDS194-Normal-SM-DHZ8D
# 325                    PoN50        PEDS196-Normal-SM-DNULT
# 170                    PoN50        PEDS199-Normal-SM-DB2K9
# 113                    PoN50        PEDS199-Normal-SM-E7S1P
# 287                    PoN50        PEDS203-Normal-SM-DHZ8B
# 157                    PoN50        PEDS207-Normal-SM-DHZ6C
# 184                    PoN50        PEDS209-Normal-SM-E7S1H
# 304                    PoN50        PEDS211-Normal-SM-E7S1T
# 216                    PoN50          TC007-Normal-SM-DHZ6S
