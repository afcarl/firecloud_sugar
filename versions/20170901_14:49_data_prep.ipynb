# %%
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
paths_to_samples_info = "paths_to_batches_info.xlsx"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_batches_info, google_bucket_id)

# %%
all_samples.to_csv("all_samples.txt", sep="\t", index=False)

# %% [markdown]
# ### Pairs

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
clean_pairs_list[clean_pairs_list.control_sample_id!="NA"]
# Out:
#                                          entity:pair_id  \
# 60        EH014-Tumor-SM-D4L26_EH014-Normal-SM-D4L35_TN
# 62        EH014-Tumor-SM-D4L1T_EH014-Normal-SM-D4L35_TN
# 64        EH014-Tumor-SM-D4L2W_EH014-Normal-SM-D4L27_TN
# 66        EH015-Tumor-SM-D4L1Z_EH015-Normal-SM-D4L2L_TN
# 68        EH015-Tumor-SM-D4L2X_EH015-Normal-SM-D4L2L_TN
# 70        EH015-Tumor-SM-D4L3A_EH015-Normal-SM-D4L2J_TN
# 72        EH015-Tumor-SM-D4L2B_EH015-Normal-SM-D4L38_TN
# 81         HG002-Tumor-SM-D4L3T_HG002-Tumor-SM-DHZ4W_TP
# 90          JL54-Tumor-SM-D4L2D_JL54-Normal-SM-D4L3X_TN
# 92          JL58-Tumor-SM-D4L32_JL58-Normal-SM-DB2JJ_TN
# 93          JL58-Tumor-SM-D4L32_JL58-Normal-SM-D4L4B_TP
# 290   PEDS153-Tumor-SM-D4L39_PEDS153-Normal-SM-DB2IU_TN
# 292   PEDS153-Tumor-SM-D4L3G_PEDS153-Normal-SM-DB2IU_TN
# 298   PEDS165-Tumor-SM-D4L2U_PEDS165-Normal-SM-D4L3J_TN
# 300   PEDS165-Tumor-SM-D4L29_PEDS165-Normal-SM-D4L3J_TN
# 302   PEDS165-Tumor-SM-D4L1U_PEDS165-Normal-SM-D4L3J_TN
# ...

# %%
clean_pairs_list[clean_pairs_list.participant_id=="CCLF_PEDS1034"]
# Out:
#                                          entity:pair_id  \
# 1548  CCLF_PEDS1034-Tumor-SM-F67EF_CCLF_PEDS1034-Nor...
# 1549                 CCLF_PEDS1034-Tumor-SM-F67EF_NA_TP
# 1674  CCLF_PEDS1034-Tumor-SM-GBJBL_CCLF_PEDS1034-Nor...
# 1675                 CCLF_PEDS1034-Tumor-SM-GBJBL_NA_TP
# 1676  CCLF_PEDS1034-Tumor-SM-GBJ9K_CCLF_PEDS1034-Nor...
# 1677                 CCLF_PEDS1034-Tumor-SM-GBJ9K_NA_TP
#
#                     case_sample_id              control_sample_id  \
# 1548  CCLF_PEDS1034-Tumor-SM-F67EF  CCLF_PEDS1034-Normal-SM-F67G4
# 1549  CCLF_PEDS1034-Tumor-SM-F67EF                             NA
# 1674  CCLF_PEDS1034-Tumor-SM-GBJBL  CCLF_PEDS1034-Normal-SM-F67G4
# 1675  CCLF_PEDS1034-Tumor-SM-GBJBL                             NA
# 1676  CCLF_PEDS1034-Tumor-SM-GBJ9K  CCLF_PEDS1034-Normal-SM-F67G4
# 1677  CCLF_PEDS1034-Tumor-SM-GBJ9K                             NA
#
#      participant_id     match_type
# 1548  CCLF_PEDS1034   tumor_normal
# ...

# %%
comb = pd.merge(all_samples[['entity:sample_id', 'tsca_id']], \
         clean_pairs_list, left_on='entity:sample_id', \
         right_on='case_sample_id', how='inner')

# %%
comb[comb.participant_id=="CCLF_PEDS1034"]
# Out:
#                   entity:sample_id tsca_id  \
# 1546  CCLF_PEDS1034-Tumor-SM-F67EF  TSCA20
# 1547  CCLF_PEDS1034-Tumor-SM-F67EF  TSCA20
# 1672  CCLF_PEDS1034-Tumor-SM-GBJBL  TSCA21
# 1673  CCLF_PEDS1034-Tumor-SM-GBJBL  TSCA21
# 1674  CCLF_PEDS1034-Tumor-SM-GBJ9K  TSCA21
# 1675  CCLF_PEDS1034-Tumor-SM-GBJ9K  TSCA21
#
#                                          entity:pair_id  \
# 1546  CCLF_PEDS1034-Tumor-SM-F67EF_CCLF_PEDS1034-Nor...
# 1547                 CCLF_PEDS1034-Tumor-SM-F67EF_NA_TP
# 1672  CCLF_PEDS1034-Tumor-SM-GBJBL_CCLF_PEDS1034-Nor...
# 1673                 CCLF_PEDS1034-Tumor-SM-GBJBL_NA_TP
# 1674  CCLF_PEDS1034-Tumor-SM-GBJ9K_CCLF_PEDS1034-Nor...
# 1675                 CCLF_PEDS1034-Tumor-SM-GBJ9K_NA_TP
#
#                     case_sample_id              control_sample_id  \
# 1546  CCLF_PEDS1034-Tumor-SM-F67EF  CCLF_PEDS1034-Normal-SM-F67G4
# 1547  CCLF_PEDS1034-Tumor-SM-F67EF                             NA
# ...

# %%
comb[ comb['entity:pair_id'] == "PEDS167-Tumor-SM-DB2IE_PEDS167-Tumor-SM-D4L31_TP"]
# Out:
#            entity:sample_id tsca_id  \
# 443  PEDS167-Tumor-SM-DB2IE  TSCA14
#
#                                        entity:pair_id          case_sample_id  \
# 443  PEDS167-Tumor-SM-DB2IE_PEDS167-Tumor-SM-D4L31_TP  PEDS167-Tumor-SM-DB2IE
#
#           control_sample_id participant_id     match_type
# 443  PEDS167-Tumor-SM-D4L31        PEDS167  tumor_primary

# %%
comb = comb.rename(columns={'tsca_id': 'membership:pair_set_id', 'entity:pair_id': 'pair_id'})

# %%
comb
# Out:
#                entity:sample_id membership:pair_set_id  \
# 0           AA34-Tumor-SM-D4L25               TSCA1213
# 1           AA34-Tumor-SM-D4L25               TSCA1213
# 2           AA36-Tumor-SM-D4L2H               TSCA1213
# 3           AA36-Tumor-SM-D4L2H               TSCA1213
# 4           AA39-Tumor-SM-D4L3Q               TSCA1213
# 5           AA39-Tumor-SM-D4L3Q               TSCA1213
# 6           AA40-Tumor-SM-D4L42               TSCA1213
# 7           AA40-Tumor-SM-D4L42               TSCA1213
# 8          AB044-Tumor-SM-D4L2M               TSCA1213
# 9          AB044-Tumor-SM-D4L2M               TSCA1213
# 10       ANGMCSS-Tumor-SM-D4L2G               TSCA1213
# 11       ANGMCSS-Tumor-SM-D4L2G               TSCA1213
# 12        BT1008-Tumor-SM-D4L45               TSCA1213
# 13        BT1008-Tumor-SM-D4L45               TSCA1213
# 14         BT922-Tumor-SM-D4L1W               TSCA1213
# 15         BT922-Tumor-SM-D4L1W               TSCA1213
# ...

# %%
pairsets = create_pairset(all_samples, pairs)

# %%
pairsets[ pairsets['pair_id'] == "PEDS167-Tumor-SM-DB2IE_PEDS167-Tumor-SM-D4L31_TP"]
# Out:
#     membership:pair_set_id                                           pair_id
# 445                 TSCA14  PEDS167-Tumor-SM-DB2IE_PEDS167-Tumor-SM-D4L31_TP

# %%
res = fc_interface.upload_pairsets(namespace, workspace, pairsets)

# %%
res.json()
# Out:
# {'causes': [{'causes': [],
#    'message': 'pair PEDS167-Tumor-SM-DB2IE_PEDS167-Tumor-SM-D4L31_TP not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
#    'message': 'pair CCLF_JL1001-Tumor-SM-EUVG4_CCLF_JL1001-Normal-SM-EUVFR_TN not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
#    'message': 'pair PEDS182-Tumor-SM-DHZ9C_PEDS182-Normal-SM-DHZA1_TN not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
#    'message': 'pair EH020-Tumor-SM-DHZ85_EH020-Normal-SM-DB2IQ_TN not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
#    'message': 'pair EH019-Tumor-SM-DHZ9T_EH019-Normal-SM-DHZ8I_TN not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
#    'message': 'pair PEDS195-Tumor-SM-DHZ7L_PEDS195-Tumor-SM-DHZ7Z_TP not found',
#    'source': 'rawls',
#    'stackTrace': []},
#   {'causes': [],
# ...

# %%
clean_pairs_list[clean_pairs_list['entity:pair_id'] == "PEDS195-Tumor-SM-DHZ7Z" ]
# Out:
# Empty DataFrame
# Columns: [entity:pair_id, case_sample_id, control_sample_id, participant_id, match_type]
# Index: []

# %%
clean_pairs_list.head(1)
# Out:
#               entity:pair_id       case_sample_id control_sample_id  \
# 0  AA34-Tumor-SM-D4L25_NA_TN  AA34-Tumor-SM-D4L25                NA
#
#   participant_id    match_type
# 0           AA34  tumor_normal

# %%
pairsets.head(1)
# Out:
#   membership:pair_set_id                    pair_id
# 0               TSCA1213  AA34-Tumor-SM-D4L25_NA_TN

# %%
all_samples[all_samples['entity:sample_id'] == "PEDS167-Tumor-SM-DB2IE"]
# Out:
#           entity:sample_id participant_id  \
# 66  PEDS167-Tumor-SM-DB2IE        PEDS167
#
#                                clean_bam_file_capture  external_id_validation  \
# 66  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  PEDS167T_2_AR5_RETM_p5
#
#      aggregation_product_name_validation bsp_sample_id_validation  \
# 66  TSCA Rapid Cancer Detection Panel v2                 SM-DB9JL
#
#    stock_sample_id_validation sample_type picard_aggregation_type_validation  \
# 66                   SM-DB2IE       Tumor                                PCR
#
#    processed_subtype_validation source_subtype_validation  \
# 66          Cells:Pellet frozen   Cells:Cell Line, Viable
#
#    squid_sample_id_validation tumor_subtype short_letter_code  \
# 66     PEDS167T_2_AR5_RETM_p5       Primary                TP
#
#                                          bam_filename  \
# 66  1_PEDS167T_2_AR5_RETM_p5_HYTLGBCXX.1.aligned.d...
#
#                                          bai_filename  \
# ...

# %%
clean_pairs_list[clean_pairs_list['case_sample_id'] == "PEDS167-Tumor-SM-DB2IE" ]
# Out:
#                                         entity:pair_id  \
# 444  PEDS167-Tumor-SM-DB2IE_PEDS167-Normal-SM-D4L3M_TN
# 445  PEDS167-Tumor-SM-DB2IE_PEDS167-Normal-SM-D4L3M_TP
#
#              case_sample_id        control_sample_id participant_id  \
# 444  PEDS167-Tumor-SM-DB2IE  PEDS167-Normal-SM-D4L3M        PEDS167
# 445  PEDS167-Tumor-SM-DB2IE  PEDS167-Normal-SM-D4L3M        PEDS167
#
#         match_type
# 444   tumor_normal
# 445  tumor_primary
