# %% [markdown]
# ### Commands

# %%
from firecloud import api as firecloud_api
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### Parameters
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"
paths_to_samples_info = "paths_to_batches_info.xlsx"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"

# %% [markdown]
# #### Deletions

# %%
### Delete unnecessary attributes in samples
attrs = ["annotate_variants_vcf", "annotate_variants_vcf_index", "oncotated_maf", "mutect2_vcf_index", "match_normal_oncotated_maf", "gnomad_vcf", "merged_vcfs", "match_primary_tumor_bam_file"]
for idx, row in all_samples.iterrows():
    fc_interface.delete_entity_attributes(namespace, workspace, "sample", row['entity:sample_id'], attrs)

# %%
### Delete method repostory
firecloud_api.delete_repository_method('tsca', 'CreatePoN', 15)

# %%
### Delete method repository
firecloud_api.delete_repository_method('tsca', 'Mutect2_for_Normal', 1)

# %%
### Delete multiple method repositories
for i in range(10, 23):
    firecloud_api.delete_repository_method('tsca', 'CreatePoN', i)

# %%
### Delete method config
firecloud_api.delete_workspace_config(namespace, workspace, "tsca", "Mutect2_for_Normal")

# %% [markdown]
# #### Pair creation

# %%
### Create pairs
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
### Upload pairs
res = fc_interface.upload_pairs(namespace, workspace, clean_pairs_list)

# %%
# ### Delete unnecessary attributes in pairs
# ### NOT WOKING
# all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
# pairs_list = fc_interface.create_pairs_list(all_samples)
# attrs = ["__annotate_variants_vcf", "__annotate_variants_vcf_index", \
#          "__scattered_intervals", "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2", \
#          "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2"]
# for idx, row in pairs_list.iterrows():
#     fc_interface.delete_entity_attributes(namespace, workspace, "pair", row['entity:pair_id'], attrs)

# %%
### Upload metadata for given batch
fc_interface.update_batch_metadata('TSCA21', \
                                  '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                                      paths_to_samples_info, \
                                        namespace, workspace, google_bucket_id)

# %%
### Delete sample_set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### All paths to batch info
# pd.read_excel('paths_to_batches_info.xlsx').path_to_samples_info.tolist()

# %%
### Create cumulative PoN (all batches)
batches_info = pd.read_excel(paths_to_samples_info)
PoN = fc_interface.create_panel_of_normals(batches_info.path_to_samples_info.tolist(), -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'CumPoN21', namespace, workspace)

# %%
### Create PoN from normals of only one batch (no samples from other batches)
batches_info = pd.read_excel(paths_to_samples_info)
tsca21_path = batches_info.path_to_samples_info.tolist()[-1]
PoN = fc_interface.create_panel_of_normals([tsca21_path], -1, 'PoN_TSCA21_Normals')
fc_interface.upload_pon(PoN, 'PoN_TSCA21_Normals', namespace, workspace)

# %%
### Delete pair set
fc_interface.delete_pair_set(namespace, workspace, 'TSCA1213')

# %%
### Delete sample set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### Download method configs
fc_interface.download_method_configs(namespace, workspace)

# %%
### Upload pairsets
tn_pairsets, tp_pairsets = fc_interface.create_pairsets(all_samples, clean_pairs_list)
fc_interface.upload_pairsets(namespace, workspace, tn_pairsets, "TN")
fc_interface.upload_pairsets(namespace, workspace, tp_pairsets, "TP")

# %%
### Delete all pairs
for idx, row in clean_pairs_list.iterrows():
    res = fc_interface.delete_pair(namespace, workspace, row['entity:pair_id'])
    print(res)

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

### Update pair attributes
update_pair_attrs(namespace, workspace, clean_pairs_list, attrs=['control_sample_tsca_id'])

# %%
### Create PoN from all normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
### Create PoN with normals from batch + other normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
# PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
# fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
# batch_id = 'TSCA21'
# batch_path = batches_info.loc[batches_info.tsca_id==batch_id, 'path_to_samples_info'].item()
# pd.read_table(batch_path)
# batch_id, paths, N, name

# %%
### Update WDLs
fc_interface.download_remote_wdls(namespace, workspace)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
import glob

# %%
walkupseq_files = glob.glob('walkupseq_files/*')

# %%
def add_cohort_to_sample(samples):
    """Add cohort to each sample in @samples df
    Args:
        - samples: samples df as created by method @prepare_batch_samples_for_metadata_export
    """
    # Files 
    # TODO: use glob to read all paths in a given folder
    walkupseq_files = ['walkupseq_files/tsca21_walkupseq_201708_sample_info.txt', \
                   'walkupseq_files/tsca20_walkupseq_201707_sample_info.txt', \
                   'walkupseq_files/tsca19_walkupseq_201706_sample_info.txt']
    
    # Create df with 
    dfs = []
for f in walkupseq_files:
    df_tmp = pd.read_table(f)
    dfs.append(df_tmp)

# %%
walkupseq = pd.concat(dfs, axis=0)

# %%
walkupseq.columns
# Out:
# Index(['Exported DNA SM-ID', 'Container', 'Stock DNA SM-ID', 'Material Type',
#        'Volume', 'Concentration', 'Container.1', 'Position',
#        'Parent DNA SM-ID', 'Root SM-ID', 'Participant ID(s)', 'Collection',
#        'Original Material Type', 'Material Type.1', 'Cell Count', 'Position.1',
#        'Position (ColWise)', 'Collaborator Participant ID',
#        'Collaborator Sample ID', 'Collaborator Sample ID_2',
#        'Collaborator Sample ID_3', 'Age', 'Gender', 'Primary Disease', 'Race',
#        'Collected After 01/25/2015', 'Sample Type', 'Tissue Site',
#        'Tissue Site Misc', 'Tumor Type', 'Cell Line Starting Sample',
#        'Culture Medium', 'Passage Date', 'Passage Number',
#        'Passage Number on Receipt', 'Percent FBS', 'Media on Tube', 'Notes 1',
#        'Notes 2', 'External Sample ID'],
#       dtype='object')

# %%
walkupseq[ walkupseq['External Sample ID'] == "AA53T_2_OPAC_p11"]
# Out:
#    Exported DNA SM-ID    Container Stock DNA SM-ID    Material Type  Volume  \
# 13           SM-GBJ9E  CO-24765025        SM-GB4TR  DNA:DNA Somatic    98.0
#
#     Concentration  Container.1 Position Parent DNA SM-ID Root SM-ID  \
# 13           7.69  CO-24746306      B02         SM-F5YNH   SM-DJ5U2
#
#           ...         Cell Line Starting Sample  \
# 13        ...                             EYIZV
#
#                                        Culture Medium  \
# 13  Manufactured in BSP: CM1:022017: 50.0 %, Manuf...
#
#                Passage Date Passage Number  Passage Number on Receipt  \
# 13  2017-06-26 10:28:11.538           11.0                        NaN
#
#     Percent FBS  Media on Tube Notes 1 Notes 2 External Sample ID
# 13          NaN           OPAC   2D, V     NaN   AA53T_2_OPAC_p11
#
# [1 rows x 40 columns]

# %%
### Add collaborator ids to all walkupseqs
### Gather all samples
### For each sample:
###    Add collaborator
### Gather by collaborators

# %%
tsca21 = \
    fc_interface.\
        prepare_batch_samples_for_metadata_export('/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                            'TSCA21', google_bucket_id)

# %%
tsca21.columns
# Out:
# Index(['entity:sample_id', 'participant_id', 'clean_bam_file_capture',
#        'external_id_validation', 'aggregation_product_name_validation',
#        'bsp_sample_id_validation', 'stock_sample_id_validation', 'sample_type',
#        'picard_aggregation_type_validation', 'processed_subtype_validation',
#        'source_subtype_validation', 'squid_sample_id_validation',
#        'tumor_subtype', 'short_letter_code', 'bam_filename', 'bai_filename',
#        'clean_bai_file_capture', 'tsca_id'],
#       dtype='object')

# %%
pd.merge(tsca21, walkupseq[['External Sample ID', 'Collection']], \
         left_on='external_id_validation', \
         right_on='External Sample ID')
# Out:
#                  entity:sample_id participant_id  \
# 0             AA53-Tumor-SM-GBJ9E           AA53
# 1             AA55-Tumor-SM-GBJBF           AA55
# 2             AA56-Tumor-SM-GBJ92           AA56
# 3            AB059-Tumor-SM-GBJAS          AB059
# 4            AB059-Tumor-SM-GBJ9G          AB059
# 5           BT1016-Tumor-SM-GBJ9Q         BT1016
# 6           BT1160-Tumor-SM-GBJBE         BT1160
# 7           BT1160-Tumor-SM-GBJ9C         BT1160
# 8            BT869-Tumor-SM-GBJ9O          BT869
# 9      CCLF_AA1016-Tumor-SM-GBJAG    CCLF_AA1016
# 10     CCLF_AA1019-Tumor-SM-GBJ91    CCLF_AA1019
# 11     CCLF_AA1022-Tumor-SM-GBJ9T    CCLF_AA1022
# 12     CCLF_AA1023-Tumor-SM-GBJ9H    CCLF_AA1023
# 13     CCLF_AA1024-Tumor-SM-GBJ93    CCLF_AA1024
# 14     CCLF_AA1026-Tumor-SM-GBJ9N    CCLF_AA1026
# 15            AA53-Tumor-SM-GBJAU           AA53
# 16     CCLF_AB1021-Tumor-SM-GBJ9P    CCLF_AB1021
# 17     CCLF_AB1022-Tumor-SM-GBJAQ    CCLF_AB1022
# 18     CCLF_AB1025-Tumor-SM-GBJBH    CCLF_AB1025
# 19     CCLF_AB1026-Tumor-SM-GBJ96    CCLF_AB1026
# 20     CCLF_JL1003-Tumor-SM-GBJB4    CCLF_JL1003
# 21     CCLF_KL1068-Tumor-SM-GBJBJ    CCLF_KL1068
# 22     CCLF_KL1073-Tumor-SM-GBJBG    CCLF_KL1073
# 23     CCLF_KL1075-Tumor-SM-GBJAR    CCLF_KL1075
# 24     CCLF_KL1076-Tumor-SM-GBJB5    CCLF_KL1076
# 25     CCLF_KL1077-Tumor-SM-GBJB7    CCLF_KL1077
# 26     CCLF_KL1100-Tumor-SM-GBJ9U    CCLF_KL1100
# 27     CCLF_KL1101-Tumor-SM-GBJ9I    CCLF_KL1101
# 28     CCLF_NH1002-Tumor-SM-GBJ9D    CCLF_NH1002
# 29     CCLF_NH1003-Tumor-SM-GBJA3    CCLF_NH1003
# ..                            ...            ...
# 56   CCLF_RCRF1016-Tumor-SM-GBJB8  CCLF_RCRF1016
# 57  CCLF_RCRF1017-Normal-SM-GBJAJ  CCLF_RCRF1017
# 58   CCLF_RCRF1017-Tumor-SM-GBJA7  CCLF_RCRF1017
# 59          COL016-Tumor-SM-GBJ9B         COL016
# 60          COL016-Tumor-SM-GBJBO         COL016
# 61           CY013-Tumor-SM-GBJBD          CY013
# 62           CY016-Tumor-SM-GBJ9F          CY016
# 63           CY016-Tumor-SM-GBJA5          CY016
# 64           CY017-Tumor-SM-GBJA4          CY017
# 65           CY018-Tumor-SM-GBJAV          CY018
# 66           CY019-Tumor-SM-GBJA6          CY019
# 67           CY020-Tumor-SM-GBJ9R          CY020
# 68        SUDIPGIV-Tumor-SM-GBJB2       SUDIPGIV
# 69      SUDIPGXIII-Tumor-SM-GBJA1     SUDIPGXIII
# 70      SUDIPGXVII-Tumor-SM-GBJAD     SUDIPGXVII
# 71       SUDIPGXXV-Tumor-SM-GBJAP      SUDIPGXXV
# 72           EH028-Tumor-SM-GBJAE          EH028
# 73          EH029-Normal-SM-GBJAT          EH029
# 74           EH029-Tumor-SM-GBJB6          EH029
# 75          EH030-Normal-SM-GBJBI          EH030
# 76           EH030-Tumor-SM-GBJ95          EH030
# 77           JL62-Normal-SM-GBJAO           JL62
# 78        PEDS063-Normal-SM-GBJB9        PEDS063
# 79         PEDS063-Tumor-SM-GBJAK        PEDS063
# 80         PEDS063-Tumor-SM-GBJ9W        PEDS063
# 81        PEDS105-Normal-SM-GBJ9V        PEDS105
# 82        PEDS105-Normal-SM-GBJBP        PEDS105
# 83         PEDS142-Tumor-SM-GBJAW        PEDS142
# 84           TC011-Tumor-SM-GBJA2          TC011
# 85           TC012-Tumor-SM-GBJ9Y          TC012
#
#                                clean_bam_file_capture  \
# 0   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 1   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 2   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 3   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 4   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 5   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 6   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 7   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 8   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 9   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 10  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 11  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 12  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 13  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 14  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 15  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 16  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 17  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 18  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 19  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 20  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 21  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 22  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 23  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 24  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 25  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 26  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 27  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 28  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 29  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# ..                                                ...
# 56  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 57  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 58  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 59  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 60  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 61  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 62  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 63  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 64  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 65  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 66  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 67  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 68  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 69  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 70  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 71  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 72  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 73  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 74  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 75  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 76  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 77  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 78  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 79  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 80  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 81  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 82  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 83  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 84  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 85  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
#
#        external_id_validation   aggregation_product_name_validation  \
# 0            AA53T_2_OPAC_p11  TSCA Rapid Cancer Detection Panel v2
# 1                AA55T_CM_p12  TSCA Rapid Cancer Detection Panel v2
# 2              AA56T_OPAC_p12  TSCA Rapid Cancer Detection Panel v2
# 3               AB059T_CM_p12  TSCA Rapid Cancer Detection Panel v2
# 4             AB059T_OPAC_p12  TSCA Rapid Cancer Detection Panel v2
# 5   BT1018_NSA_p5_LowAdherent  TSCA Rapid Cancer Detection Panel v2
# 6                BT1160_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 7           BT1160_KL_Primary  TSCA Rapid Cancer Detection Panel v2
# 8                 BT869_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 9    CCLF_AA1016T_ASC_OPAC_p3  TSCA Rapid Cancer Detection Panel v2
# 10       CCLF_AA1019T_Primary  TSCA Rapid Cancer Detection Panel v2
# 11       CCLF_AA1022T_Primary  TSCA Rapid Cancer Detection Panel v2
# 12       CCLF_AA1023T_Primary  TSCA Rapid Cancer Detection Panel v2
# 13    CCLF_AA1024T_PF_Primary  TSCA Rapid Cancer Detection Panel v2
# 14   CCLF_AA1026T_ASC_Primary  TSCA Rapid Cancer Detection Panel v2
# 15   CCLF_AA1027T_ASC_Primary  TSCA Rapid Cancer Detection Panel v2
# 16   CCLF_AB1021T_ASC_Primary  TSCA Rapid Cancer Detection Panel v2
# 17       CCLF_AB1022T_Primary  TSCA Rapid Cancer Detection Panel v2
# 18       CCLF_AB1025T_Primary  TSCA Rapid Cancer Detection Panel v2
# 19       CCLF_AB1026T_Primary  TSCA Rapid Cancer Detection Panel v2
# 20         CCLF_JL1003T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 21         CCLF_KL1068T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 22         CCLF_KL1073T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 23         CCLF_KL1075T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 24         CCLF_KL1076T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 25         CCLF_KL1077T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 26       CCLF_KL1100T_Primary  TSCA Rapid Cancer Detection Panel v2
# 27       CCLF_KL1101T_Primary  TSCA Rapid Cancer Detection Panel v2
# 28       CCLF_NH1002T_OPAC_p4  TSCA Rapid Cancer Detection Panel v2
# 29       CCLF_NH1003T_OPAC_p5  TSCA Rapid Cancer Detection Panel v2
# ..                        ...                                   ...
# 56     CCLF_RCRF1016T_Primary  TSCA Rapid Cancer Detection Panel v2
# 57     CCLF_RCRF1017N_Primary  TSCA Rapid Cancer Detection Panel v2
# 58     CCLF_RCRF1017T_Primary  TSCA Rapid Cancer Detection Panel v2
# 59            COL016T_OPAC_p2  TSCA Rapid Cancer Detection Panel v2
# 60            COL016T_OPAC_p4  TSCA Rapid Cancer Detection Panel v2
# 61               CY013T_CM_p7  TSCA Rapid Cancer Detection Panel v2
# 62               CY016T_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 63             CY016T_RETM_p7  TSCA Rapid Cancer Detection Panel v2
# 64             CY017T_RETM_p7  TSCA Rapid Cancer Detection Panel v2
# 65             CY018T_Primary  TSCA Rapid Cancer Detection Panel v2
# 66             CY019T_Primary  TSCA Rapid Cancer Detection Panel v2
# 67             CY020T_Primary  TSCA Rapid Cancer Detection Panel v2
# 68               DIPGIV_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 69             DIPGXIII_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 70             DIPGXVII_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 71              DIPGXXV_KL_CL  TSCA Rapid Cancer Detection Panel v2
# 72             EH028T_Primary  TSCA Rapid Cancer Detection Panel v2
# 73             EH029N_Primary  TSCA Rapid Cancer Detection Panel v2
# 74             EH029T_Primary  TSCA Rapid Cancer Detection Panel v2
# 75             EH030N_Primary  TSCA Rapid Cancer Detection Panel v2
# 76             EH030T_Primary  TSCA Rapid Cancer Detection Panel v2
# 77              JL62N_RETM_p5  TSCA Rapid Cancer Detection Panel v2
# 78             PEDS063N_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 79             PEDS063T_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 80           PEDS063T_RETM_p6  TSCA Rapid Cancer Detection Panel v2
# 81             PEDS105N_CM_p9  TSCA Rapid Cancer Detection Panel v2
# 82           PEDS105N_Primary  TSCA Rapid Cancer Detection Panel v2
# 83           PEDS142T_RETM_p9  TSCA Rapid Cancer Detection Panel v2
# 84             TC011T_Primary  TSCA Rapid Cancer Detection Panel v2
# 85             TC012T_Primary  TSCA Rapid Cancer Detection Panel v2
#
#    bsp_sample_id_validation stock_sample_id_validation sample_type  \
# 0                  SM-GBJ9E                   SM-GB4TR       Tumor
# 1                  SM-GBJBF                   SM-GB4DD       Tumor
# 2                  SM-GBJ92                   SM-GB4U1       Tumor
# 3                  SM-GBJAS                   SM-GB4U5       Tumor
# 4                  SM-GBJ9G                   SM-GB4TZ       Tumor
# 5                  SM-GBJ9Q                   SM-GB4U4       Tumor
# 6                  SM-GBJBE                   SM-G8SIU       Tumor
# 7                  SM-GBJ9C                   SM-G8SIO       Tumor
# 8                  SM-GBJ9O                   SM-G8SIP       Tumor
# 9                  SM-GBJAG                   SM-GB4CK       Tumor
# 10                 SM-GBJ91                   SM-GB4BA       Tumor
# 11                 SM-GBJ9T                   SM-GB4C1       Tumor
# 12                 SM-GBJ9H                   SM-GB4BP       Tumor
# 13                 SM-GBJ93                   SM-GB4TY       Tumor
# 14                 SM-GBJ9N                   SM-GB4BV       Tumor
# 15                 SM-GBJAU                   SM-GB4U2       Tumor
# 16                 SM-GBJ9P                   SM-GB4BW       Tumor
# 17                 SM-GBJAQ                   SM-GB4CS       Tumor
# 18                 SM-GBJBH                   SM-GB4DF       Tumor
# 19                 SM-GBJ96                   SM-GB4BF       Tumor
# 20                 SM-GBJB4                   SM-GB4D4       Tumor
# 21                 SM-GBJBJ                   SM-GB4DH       Tumor
# 22                 SM-GBJBG                   SM-GB4DE       Tumor
# 23                 SM-GBJAR                   SM-GB4CT       Tumor
# 24                 SM-GBJB5                   SM-GB4D5       Tumor
# 25                 SM-GBJB7                   SM-GB4D7       Tumor
# 26                 SM-GBJ9U                   SM-GB4C2       Tumor
# 27                 SM-GBJ9I                   SM-GB4BQ       Tumor
# 28                 SM-GBJ9D                   SM-GB4BL       Tumor
# 29                 SM-GBJA3                   SM-GB4C9       Tumor
# ..                      ...                        ...         ...
# 56                 SM-GBJB8                   SM-GB4D8       Tumor
# 57                 SM-GBJAJ                   SM-GB4CN      Normal
# 58                 SM-GBJA7                   SM-GB4TW       Tumor
# 59                 SM-GBJ9B                   SM-GB4BK       Tumor
# 60                 SM-GBJBO                   SM-GB4DM       Tumor
# 61                 SM-GBJBD                   SM-F66AZ       Tumor
# 62                 SM-GBJ9F                   SM-GB4BN       Tumor
# 63                 SM-GBJA5                   SM-GB4CB       Tumor
# 64                 SM-GBJA4                   SM-GB4CA       Tumor
# 65                 SM-GBJAV                   SM-GB4CX       Tumor
# 66                 SM-GBJA6                   SM-GB4TV       Tumor
# 67                 SM-GBJ9R                   SM-GB4BY       Tumor
# 68                 SM-GBJB2                   SM-G8SIT       Tumor
# 69                 SM-GBJA1                   SM-G8SIQ       Tumor
# 70                 SM-GBJAD                   SM-G8SIR       Tumor
# 71                 SM-GBJAP                   SM-G8SIS       Tumor
# 72                 SM-GBJAE                   SM-GB4CI       Tumor
# 73                 SM-GBJAT                   SM-GB4TS      Normal
# 74                 SM-GBJB6                   SM-GB4U3       Tumor
# 75                 SM-GBJBI                   SM-GB4TX      Normal
# 76                 SM-GBJ95                   SM-GB4TU       Tumor
# 77                 SM-GBJAO                   SM-F66B8      Normal
# 78                 SM-GBJB9                   SM-GB4D9      Normal
# 79                 SM-GBJAK                   SM-GB4CO       Tumor
# 80                 SM-GBJ9W                   SM-GB4C4       Tumor
# 81                 SM-GBJ9V                   SM-GB4C3      Normal
# 82                 SM-GBJBP                   SM-F66B7      Normal
# 83                 SM-GBJAW                   SM-GB4CY       Tumor
# 84                 SM-GBJA2                   SM-GB4C8       Tumor
# 85                 SM-GBJ9Y                   SM-GB4C6       Tumor
#
#    picard_aggregation_type_validation processed_subtype_validation  \
# 0                                 PCR              DNA:DNA Somatic
# 1                                 PCR              DNA:DNA Somatic
# 2                                 PCR              DNA:DNA Somatic
# 3                                 PCR              DNA:DNA Somatic
# 4                                 PCR              DNA:DNA Somatic
# 5                                 PCR              DNA:DNA Somatic
# 6                                 PCR              DNA:DNA Somatic
# 7                                 PCR              DNA:DNA Somatic
# 8                                 PCR              DNA:DNA Somatic
# 9                                 PCR              DNA:DNA Somatic
# 10                                PCR              DNA:DNA Somatic
# 11                                PCR              DNA:DNA Somatic
# 12                                PCR              DNA:DNA Somatic
# 13                                PCR              DNA:DNA Somatic
# 14                                PCR              DNA:DNA Somatic
# 15                                PCR              DNA:DNA Somatic
# 16                                PCR              DNA:DNA Somatic
# 17                                PCR              DNA:DNA Somatic
# 18                                PCR              DNA:DNA Somatic
# 19                                PCR              DNA:DNA Somatic
# 20                                PCR              DNA:DNA Somatic
# 21                                PCR              DNA:DNA Somatic
# 22                                PCR              DNA:DNA Somatic
# 23                                PCR              DNA:DNA Somatic
# 24                                PCR              DNA:DNA Somatic
# 25                                PCR              DNA:DNA Somatic
# 26                                PCR              DNA:DNA Somatic
# 27                                PCR              DNA:DNA Somatic
# 28                                PCR              DNA:DNA Somatic
# 29                                PCR              DNA:DNA Somatic
# ..                                ...                          ...
# 56                                PCR              DNA:DNA Somatic
# 57                                PCR              DNA:DNA Somatic
# 58                                PCR              DNA:DNA Somatic
# 59                                PCR              DNA:DNA Somatic
# 60                                PCR              DNA:DNA Somatic
# 61                                PCR              DNA:DNA Somatic
# 62                                PCR              DNA:DNA Somatic
# 63                                PCR              DNA:DNA Somatic
# 64                                PCR              DNA:DNA Somatic
# 65                                PCR              DNA:DNA Somatic
# 66                                PCR              DNA:DNA Somatic
# 67                                PCR              DNA:DNA Somatic
# 68                                PCR              DNA:DNA Somatic
# 69                                PCR              DNA:DNA Somatic
# 70                                PCR              DNA:DNA Somatic
# 71                                PCR              DNA:DNA Somatic
# 72                                PCR              DNA:DNA Somatic
# 73                                PCR              DNA:DNA Somatic
# 74                                PCR              DNA:DNA Somatic
# 75                                PCR              DNA:DNA Somatic
# 76                                PCR              DNA:DNA Somatic
# 77                                PCR              DNA:DNA Somatic
# 78                                PCR              DNA:DNA Somatic
# 79                                PCR              DNA:DNA Somatic
# 80                                PCR              DNA:DNA Somatic
# 81                                PCR              DNA:DNA Somatic
# 82                                PCR              DNA:DNA Somatic
# 83                                PCR              DNA:DNA Somatic
# 84                                PCR              DNA:DNA Somatic
# 85                                PCR              DNA:DNA Somatic
#
#    source_subtype_validation squid_sample_id_validation tumor_subtype  \
# 0    Cells:Cell Line, Viable           AA53T_2_OPAC_p11    Metastatic
# 1    Cells:Cell Line, Viable               AA55T_CM_p12    Metastatic
# 2    Cells:Cell Line, Viable             AA56T_OPAC_p12    Metastatic
# 3    Cells:Cell Line, Viable              AB059T_CM_p12    Metastatic
# 4    Cells:Cell Line, Viable            AB059T_OPAC_p12    Metastatic
# 5    Cells:Cell Line, Viable  BT1018_NSA_p5_LowAdherent       Primary
# 6    Cells:Cell Line, Viable               BT1160_KL_CL       Primary
# 7    Cells:Cell Line, Viable          BT1160_KL_Primary       Primary
# 8    Cells:Cell Line, Viable                BT869_KL_CL       Primary
# 9        Tissue:Fresh Tissue   CCLF_AA1016T_ASC_OPAC_p3    Metastatic
# 10       Tissue:Fresh Tissue       CCLF_AA1019T_Primary       Primary
# 11       Tissue:Fresh Tissue       CCLF_AA1022T_Primary       Primary
# 12       Tissue:Fresh Tissue       CCLF_AA1023T_Primary       Primary
# 13       Tissue:Fresh Tissue    CCLF_AA1024T_PF_Primary    Metastatic
# 14       Tissue:Fresh Tissue   CCLF_AA1026T_ASC_Primary    Metastatic
# 15       Tissue:Fresh Tissue   CCLF_AA1027T_ASC_Primary    Metastatic
# 16       Tissue:Fresh Tissue   CCLF_AB1021T_ASC_Primary    Metastatic
# 17       Tissue:Fresh Tissue       CCLF_AB1022T_Primary       Primary
# 18       Tissue:Fresh Tissue       CCLF_AB1025T_Primary       Primary
# 19       Tissue:Fresh Tissue       CCLF_AB1026T_Primary       Primary
# 20   Cells:Cell Line, Viable         CCLF_JL1003T_CM_p5    Metastatic
# 21   Cells:Cell Line, Viable         CCLF_KL1068T_CM_p5       Primary
# 22   Cells:Cell Line, Viable         CCLF_KL1073T_CM_p5       Primary
# 23   Cells:Cell Line, Viable         CCLF_KL1075T_CM_p5    Metastatic
# 24   Cells:Cell Line, Viable         CCLF_KL1076T_CM_p5     Recurrent
# 25   Cells:Cell Line, Viable         CCLF_KL1077T_CM_p5     Recurrent
# 26       Tissue:Fresh Tissue       CCLF_KL1100T_Primary       Primary
# 27       Tissue:Fresh Tissue       CCLF_KL1101T_Primary       Primary
# 28       Tissue:Fresh Tissue       CCLF_NH1002T_OPAC_p4       Primary
# 29   Cells:Cell Line, Viable       CCLF_NH1003T_OPAC_p5       Primary
# ..                       ...                        ...           ...
# 56       Tissue:Fresh Tissue     CCLF_RCRF1016T_Primary       Primary
# 57       Tissue:Fresh Tissue     CCLF_RCRF1017N_Primary           NaN
# 58       Tissue:Fresh Tissue     CCLF_RCRF1017T_Primary       Primary
# 59       Tissue:Fresh Tissue            COL016T_OPAC_p2       Primary
# 60   Cells:Cell Line, Viable            COL016T_OPAC_p4       Primary
# 61   Cells:Cell Line, Viable               CY013T_CM_p7    Metastatic
# 62   Cells:Cell Line, Viable               CY016T_CM_p6    Metastatic
# 63   Cells:Cell Line, Viable             CY016T_RETM_p7    Metastatic
# 64   Cells:Cell Line, Viable             CY017T_RETM_p7    Metastatic
# 65       Tissue:Fresh Tissue             CY018T_Primary    Metastatic
# 66       Tissue:Fresh Tissue             CY019T_Primary    Metastatic
# 67       Tissue:Fresh Tissue             CY020T_Primary    Metastatic
# 68   Cells:Cell Line, Viable               DIPGIV_KL_CL       Primary
# 69   Cells:Cell Line, Viable             DIPGXIII_KL_CL       Primary
# 70   Cells:Cell Line, Viable             DIPGXVII_KL_CL       Primary
# 71   Cells:Cell Line, Viable              DIPGXXV_KL_CL       Primary
# 72       Tissue:Fresh Tissue             EH028T_Primary       Primary
# 73       Tissue:Fresh Tissue             EH029N_Primary           NaN
# 74       Tissue:Fresh Tissue             EH029T_Primary       Primary
# 75       Tissue:Fresh Tissue             EH030N_Primary           NaN
# 76       Tissue:Fresh Tissue             EH030T_Primary       Primary
# 77   Cells:Cell Line, Viable              JL62N_RETM_p5           NaN
# 78       Tissue:Fresh Tissue             PEDS063N_CM_p6       Primary
# 79       Tissue:Fresh Tissue             PEDS063T_CM_p6       Primary
# 80       Tissue:Fresh Tissue           PEDS063T_RETM_p6       Primary
# 81       Tissue:Fresh Tissue             PEDS105N_CM_p9           NaN
# 82       Tissue:Fresh Tissue           PEDS105N_Primary           NaN
# 83       Tissue:Fresh Tissue           PEDS142T_RETM_p9       Primary
# 84       Tissue:Fresh Tissue             TC011T_Primary    Metastatic
# 85       Tissue:Fresh Tissue             TC012T_Primary    Metastatic
#
#    short_letter_code                                       bam_filename  \
# 0                 TM  2_AA53T_2_OPAC_p11_HM5LTBCXY.2.aligned.duplica...
# 1                 TM  2_AA55T_CM_p12_HM5LTBCXY.2.aligned.duplicates_...
# 2                 TM  2_AA56T_OPAC_p12_HM5LTBCXY.2.aligned.duplicate...
# 3                 TM  2_AB059T_CM_p12_HM5LTBCXY.2.aligned.duplicates...
# 4                 TM  2_AB059T_OPAC_p12_HM5LTBCXY.2.aligned.duplicat...
# 5                 TP  2_BT1018_NSA_p5_LowAdherent_HM5LTBCXY.2.aligne...
# 6                 TP  2_BT1160_KL_CL_HM5LTBCXY.2.aligned.duplicates_...
# 7                 TP  2_BT1160_KL_Primary_HM5LTBCXY.2.aligned.duplic...
# 8                 TP  2_BT869_KL_CL_HM5LTBCXY.2.aligned.duplicates_m...
# 9                 TM  2_CCLF_AA1016T_ASC_OPAC_p3_HM5LTBCXY.2.aligned...
# 10                TP  2_CCLF_AA1019T_Primary_HM5LTBCXY.2.aligned.dup...
# 11                TP  2_CCLF_AA1022T_Primary_HM5LTBCXY.2.aligned.dup...
# 12                TP  2_CCLF_AA1023T_Primary_HM5LTBCXY.2.aligned.dup...
# 13                TM  2_CCLF_AA1024T_PF_Primary_HM5LTBCXY.2.aligned....
# 14                TM  2_CCLF_AA1026T_ASC_Primary_HM5LTBCXY.2.aligned...
# 15                TM  2_CCLF_AA1027T_ASC_Primary_HM5LTBCXY.2.aligned...
# 16                TM  2_CCLF_AB1021T_ASC_Primary_HM5LTBCXY.2.aligned...
# 17                TP  2_CCLF_AB1022T_Primary_HM5LTBCXY.2.aligned.dup...
# 18                TP  2_CCLF_AB1025T_Primary_HM5LTBCXY.2.aligned.dup...
# 19                TP  2_CCLF_AB1026T_Primary_HM5LTBCXY.2.aligned.dup...
# 20                TM  2_CCLF_JL1003T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 21                TP  2_CCLF_KL1068T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 22                TP  2_CCLF_KL1073T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 23                TM  2_CCLF_KL1075T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 24                TR  2_CCLF_KL1076T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 25                TR  2_CCLF_KL1077T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 26                TP  2_CCLF_KL1100T_Primary_HM5LTBCXY.2.aligned.dup...
# 27                TP  2_CCLF_KL1101T_Primary_HM5LTBCXY.2.aligned.dup...
# 28                TP  2_CCLF_NH1002T_OPAC_p4_HM5LTBCXY.2.aligned.dup...
# 29                TP  2_CCLF_NH1003T_OPAC_p5_HM5LTBCXY.2.aligned.dup...
# ..               ...                                                ...
# 56                TP  2_CCLF_RCRF1016T_Primary_HM5LTBCXY.2.aligned.d...
# 57              NDNA  2_CCLF_RCRF1017N_Primary_HM5LTBCXY.2.aligned.d...
# 58                TP  2_CCLF_RCRF1017T_Primary_HM5LTBCXY.2.aligned.d...
# 59                TP  2_COL016T_OPAC_p2_HM5LTBCXY.2.aligned.duplicat...
# 60                TP  2_COL016T_OPAC_p4_HM5LTBCXY.2.aligned.duplicat...
# 61                TM  2_CY013T_CM_p7_HM5LTBCXY.2.aligned.duplicates_...
# 62                TM  2_CY016T_CM_p6_HM5LTBCXY.2.aligned.duplicates_...
# 63                TM  2_CY016T_RETM_p7_HM5LTBCXY.2.aligned.duplicate...
# 64                TM  2_CY017T_RETM_p7_HM5LTBCXY.2.aligned.duplicate...
# 65                TM  2_CY018T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 66                TM  2_CY019T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 67                TM  2_CY020T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 68                TP  2_DIPGIV_KL_CL_HM5LTBCXY.2.aligned.duplicates_...
# 69                TP  2_DIPGXIII_KL_CL_HM5LTBCXY.2.aligned.duplicate...
# 70                TP  2_DIPGXVII_KL_CL_HM5LTBCXY.2.aligned.duplicate...
# 71                TP  2_DIPGXXV_KL_CL_HM5LTBCXY.2.aligned.duplicates...
# 72                TP  2_EH028T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 73              NDNA  2_EH029N_Primary_HM5LTBCXY.2.aligned.duplicate...
# 74                TP  2_EH029T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 75              NDNA  2_EH030N_Primary_HM5LTBCXY.2.aligned.duplicate...
# 76                TP  2_EH030T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 77             NCELL  2_JL62N_RETM_p5_HM5LTBCXY.2.aligned.duplicates...
# 78              NDNA  2_PEDS063N_CM_p6_HM5LTBCXY.2.aligned.duplicate...
# 79                TP  2_PEDS063T_CM_p6_HM5LTBCXY.2.aligned.duplicate...
# 80                TP  2_PEDS063T_RETM_p6_HM5LTBCXY.2.aligned.duplica...
# 81              NDNA  2_PEDS105N_CM_p9_HM5LTBCXY.2.aligned.duplicate...
# 82              NDNA  2_PEDS105N_Primary_HM5LTBCXY.2.aligned.duplica...
# 83                TP  2_PEDS142T_RETM_p9_HM5LTBCXY.2.aligned.duplica...
# 84                TM  2_TC011T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 85                TM  2_TC012T_Primary_HM5LTBCXY.2.aligned.duplicate...
#
#                                          bai_filename  \
# 0   2_AA53T_2_OPAC_p11_HM5LTBCXY.2.aligned.duplica...
# 1   2_AA55T_CM_p12_HM5LTBCXY.2.aligned.duplicates_...
# 2   2_AA56T_OPAC_p12_HM5LTBCXY.2.aligned.duplicate...
# 3   2_AB059T_CM_p12_HM5LTBCXY.2.aligned.duplicates...
# 4   2_AB059T_OPAC_p12_HM5LTBCXY.2.aligned.duplicat...
# 5   2_BT1018_NSA_p5_LowAdherent_HM5LTBCXY.2.aligne...
# 6   2_BT1160_KL_CL_HM5LTBCXY.2.aligned.duplicates_...
# 7   2_BT1160_KL_Primary_HM5LTBCXY.2.aligned.duplic...
# 8   2_BT869_KL_CL_HM5LTBCXY.2.aligned.duplicates_m...
# 9   2_CCLF_AA1016T_ASC_OPAC_p3_HM5LTBCXY.2.aligned...
# 10  2_CCLF_AA1019T_Primary_HM5LTBCXY.2.aligned.dup...
# 11  2_CCLF_AA1022T_Primary_HM5LTBCXY.2.aligned.dup...
# 12  2_CCLF_AA1023T_Primary_HM5LTBCXY.2.aligned.dup...
# 13  2_CCLF_AA1024T_PF_Primary_HM5LTBCXY.2.aligned....
# 14  2_CCLF_AA1026T_ASC_Primary_HM5LTBCXY.2.aligned...
# 15  2_CCLF_AA1027T_ASC_Primary_HM5LTBCXY.2.aligned...
# 16  2_CCLF_AB1021T_ASC_Primary_HM5LTBCXY.2.aligned...
# 17  2_CCLF_AB1022T_Primary_HM5LTBCXY.2.aligned.dup...
# 18  2_CCLF_AB1025T_Primary_HM5LTBCXY.2.aligned.dup...
# 19  2_CCLF_AB1026T_Primary_HM5LTBCXY.2.aligned.dup...
# 20  2_CCLF_JL1003T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 21  2_CCLF_KL1068T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 22  2_CCLF_KL1073T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 23  2_CCLF_KL1075T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 24  2_CCLF_KL1076T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 25  2_CCLF_KL1077T_CM_p5_HM5LTBCXY.2.aligned.dupli...
# 26  2_CCLF_KL1100T_Primary_HM5LTBCXY.2.aligned.dup...
# 27  2_CCLF_KL1101T_Primary_HM5LTBCXY.2.aligned.dup...
# 28  2_CCLF_NH1002T_OPAC_p4_HM5LTBCXY.2.aligned.dup...
# 29  2_CCLF_NH1003T_OPAC_p5_HM5LTBCXY.2.aligned.dup...
# ..                                                ...
# 56  2_CCLF_RCRF1016T_Primary_HM5LTBCXY.2.aligned.d...
# 57  2_CCLF_RCRF1017N_Primary_HM5LTBCXY.2.aligned.d...
# 58  2_CCLF_RCRF1017T_Primary_HM5LTBCXY.2.aligned.d...
# 59  2_COL016T_OPAC_p2_HM5LTBCXY.2.aligned.duplicat...
# 60  2_COL016T_OPAC_p4_HM5LTBCXY.2.aligned.duplicat...
# 61  2_CY013T_CM_p7_HM5LTBCXY.2.aligned.duplicates_...
# 62  2_CY016T_CM_p6_HM5LTBCXY.2.aligned.duplicates_...
# 63  2_CY016T_RETM_p7_HM5LTBCXY.2.aligned.duplicate...
# 64  2_CY017T_RETM_p7_HM5LTBCXY.2.aligned.duplicate...
# 65  2_CY018T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 66  2_CY019T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 67  2_CY020T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 68  2_DIPGIV_KL_CL_HM5LTBCXY.2.aligned.duplicates_...
# 69  2_DIPGXIII_KL_CL_HM5LTBCXY.2.aligned.duplicate...
# 70  2_DIPGXVII_KL_CL_HM5LTBCXY.2.aligned.duplicate...
# 71  2_DIPGXXV_KL_CL_HM5LTBCXY.2.aligned.duplicates...
# 72  2_EH028T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 73  2_EH029N_Primary_HM5LTBCXY.2.aligned.duplicate...
# 74  2_EH029T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 75  2_EH030N_Primary_HM5LTBCXY.2.aligned.duplicate...
# 76  2_EH030T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 77  2_JL62N_RETM_p5_HM5LTBCXY.2.aligned.duplicates...
# 78  2_PEDS063N_CM_p6_HM5LTBCXY.2.aligned.duplicate...
# 79  2_PEDS063T_CM_p6_HM5LTBCXY.2.aligned.duplicate...
# 80  2_PEDS063T_RETM_p6_HM5LTBCXY.2.aligned.duplica...
# 81  2_PEDS105N_CM_p9_HM5LTBCXY.2.aligned.duplicate...
# 82  2_PEDS105N_Primary_HM5LTBCXY.2.aligned.duplica...
# 83  2_PEDS142T_RETM_p9_HM5LTBCXY.2.aligned.duplica...
# 84  2_TC011T_Primary_HM5LTBCXY.2.aligned.duplicate...
# 85  2_TC012T_Primary_HM5LTBCXY.2.aligned.duplicate...
#
#                                clean_bai_file_capture tsca_id  \
# 0   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 1   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 2   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 3   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 4   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 5   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 6   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 7   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 8   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 9   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 10  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 11  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 12  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 13  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 14  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 15  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 16  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 17  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 18  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 19  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 20  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 21  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 22  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 23  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 24  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 25  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 26  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 27  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 28  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 29  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# ..                                                ...     ...
# 56  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 57  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 58  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 59  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 60  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 61  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 62  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 63  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 64  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 65  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 66  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 67  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 68  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 69  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 70  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 71  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 72  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 73  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 74  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 75  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 76  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 77  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 78  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 79  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 80  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 81  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 82  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 83  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 84  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
# 85  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA21
#
#            External Sample ID  \
# 0            AA53T_2_OPAC_p11
# 1                AA55T_CM_p12
# 2              AA56T_OPAC_p12
# 3               AB059T_CM_p12
# 4             AB059T_OPAC_p12
# 5   BT1018_NSA_p5_LowAdherent
# 6                BT1160_KL_CL
# 7           BT1160_KL_Primary
# 8                 BT869_KL_CL
# 9    CCLF_AA1016T_ASC_OPAC_p3
# 10       CCLF_AA1019T_Primary
# 11       CCLF_AA1022T_Primary
# 12       CCLF_AA1023T_Primary
# 13    CCLF_AA1024T_PF_Primary
# 14   CCLF_AA1026T_ASC_Primary
# 15   CCLF_AA1027T_ASC_Primary
# 16   CCLF_AB1021T_ASC_Primary
# 17       CCLF_AB1022T_Primary
# 18       CCLF_AB1025T_Primary
# 19       CCLF_AB1026T_Primary
# 20         CCLF_JL1003T_CM_p5
# 21         CCLF_KL1068T_CM_p5
# 22         CCLF_KL1073T_CM_p5
# 23         CCLF_KL1075T_CM_p5
# 24         CCLF_KL1076T_CM_p5
# 25         CCLF_KL1077T_CM_p5
# 26       CCLF_KL1100T_Primary
# 27       CCLF_KL1101T_Primary
# 28       CCLF_NH1002T_OPAC_p4
# 29       CCLF_NH1003T_OPAC_p5
# ..                        ...
# 56     CCLF_RCRF1016T_Primary
# 57     CCLF_RCRF1017N_Primary
# 58     CCLF_RCRF1017T_Primary
# 59            COL016T_OPAC_p2
# 60            COL016T_OPAC_p4
# 61               CY013T_CM_p7
# 62               CY016T_CM_p6
# 63             CY016T_RETM_p7
# 64             CY017T_RETM_p7
# 65             CY018T_Primary
# 66             CY019T_Primary
# 67             CY020T_Primary
# 68               DIPGIV_KL_CL
# 69             DIPGXIII_KL_CL
# 70             DIPGXVII_KL_CL
# 71              DIPGXXV_KL_CL
# 72             EH028T_Primary
# 73             EH029N_Primary
# 74             EH029T_Primary
# 75             EH030N_Primary
# 76             EH030T_Primary
# 77              JL62N_RETM_p5
# 78             PEDS063N_CM_p6
# 79             PEDS063T_CM_p6
# 80           PEDS063T_RETM_p6
# 81             PEDS105N_CM_p9
# 82           PEDS105N_Primary
# 83           PEDS142T_RETM_p9
# 84             TC011T_Primary
# 85             TC012T_Primary
#
#                                            Collection
# 0   Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 1   Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 2   Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 3   Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 4   Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 5   Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 6   Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 7   Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 8   Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 9   Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 10  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 11  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 12  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 13  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 14  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 15  Cancer Cell Line Factory (CCLF) / Andy Aguirre...
# 16  Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 17  Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 18  Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 19  Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 20  Cancer Cell Line Factory (CCLF) / Jochen Lorch...
# 21  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 22  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 23  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 24  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 25  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 26  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 27  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 28  Cancer Cell Line Factory (CCLF) / Nir Hacohen ...
# 29  Cancer Cell Line Factory (CCLF) / Nir Hacohen ...
# ..                                                ...
# 56  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 57  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 58  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 59  Cancer Cell Line Factory (CCLF) / Brian Wolpin...
# 60  Cancer Cell Line Factory (CCLF) / Brian Wolpin...
# 61  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 62  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 63  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 64  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 65  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 66  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 67  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 68  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 69  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 70  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 71  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 72  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 73  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 74  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 75  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 76  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 77  Cancer Cell Line Factory (CCLF) / Jochen Lorch...
# 78  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 79  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 80  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 81  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 82  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 83  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 84  Cancer Cell Line Factory (CCLF) / Eli Van Alle...
# 85  Cancer Cell Line Factory (CCLF) / Eli Van Alle...
#
# [86 rows x 20 columns]
