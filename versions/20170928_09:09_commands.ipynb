# %% [markdown]
# ### Commands

# %%
from firecloud import api as firecloud_api
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### Parameters
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"
paths_to_samples_info = "paths_to_batches_info.xlsx"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"
batches_info = pd.read_excel(paths_to_samples_info)

# %% [markdown]
# #### Deletions

# %%
### Delete unnecessary attributes in samples
attrs = ["annotate_variants_vcf", "annotate_variants_vcf_index", "oncotated_maf", "mutect2_vcf_index", "match_normal_oncotated_maf", "gnomad_vcf", "merged_vcfs", "match_primary_tumor_bam_file"]
for idx, row in all_samples.iterrows():
    fc_interface.delete_entity_attributes(namespace, workspace, "sample", row['entity:sample_id'], attrs)

# %%
### Delete method repostory
firecloud_api.delete_repository_method('tsca', 'CreatePoN', 15)

# %%
### Delete method repository
firecloud_api.delete_repository_method('tsca', 'Mutect2_for_Normal', 1)

# %%
### Delete multiple method repositories
for i in range(10, 23):
    firecloud_api.delete_repository_method('tsca', 'CreatePoN', i)

# %%
### Delete method config
firecloud_api.delete_workspace_config(namespace, workspace, "tsca", "Mutect2_for_Normal")

# %% [markdown]
# #### Pair creation

# %%
### Create pairs
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
### Upload pairs
res = fc_interface.upload_pairs(namespace, workspace, clean_pairs_list)

# %%
# ### Delete unnecessary attributes in pairs
# ### NOT WOKING
# all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
# pairs_list = fc_interface.create_pairs_list(all_samples)
# attrs = ["__annotate_variants_vcf", "__annotate_variants_vcf_index", \
#          "__scattered_intervals", "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2", \
#          "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2"]
# for idx, row in pairs_list.iterrows():
#     fc_interface.delete_entity_attributes(namespace, workspace, "pair", row['entity:pair_id'], attrs)

# %%
### Upload metadata for given batch
fc_interface.update_batch_metadata('TSCA21', \
                                  '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                                      paths_to_samples_info, \
                                        namespace, workspace, google_bucket_id)

# %%
### Delete sample_set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### All paths to batch info
# pd.read_excel('paths_to_batches_info.xlsx').path_to_samples_info.tolist()

# %%
### Create cumulative PoN (all batches)
batches_info = pd.read_excel(paths_to_samples_info)
PoN = fc_interface.create_panel_of_normals(batches_info.path_to_samples_info.tolist(), -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'CumPoN21', namespace, workspace)

# %%
### Create PoN from normals of only one batch (no samples from other batches)
batches_info = pd.read_excel(paths_to_samples_info)
tsca21_path = batches_info.path_to_samples_info.tolist()[-1]
PoN = fc_interface.create_panel_of_normals([tsca21_path], -1, 'PoN_TSCA21_Normals')
fc_interface.upload_pon(PoN, 'PoN_TSCA21_Normals', namespace, workspace)

# %%
### Delete pair set
fc_interface.delete_pair_set(namespace, workspace, 'TSCA1213')

# %%
### Delete sample set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### Download method configs
fc_interface.download_method_configs(namespace, workspace)

# %%
### Upload pairsets
tn_pairsets, tp_pairsets = fc_interface.create_pairsets(all_samples, clean_pairs_list)
fc_interface.upload_pairsets(namespace, workspace, tn_pairsets, "TN")
fc_interface.upload_pairsets(namespace, workspace, tp_pairsets, "TP")

# %%
### Delete all pairs
for idx, row in clean_pairs_list.iterrows():
    res = fc_interface.delete_pair(namespace, workspace, row['entity:pair_id'])
    print(res)

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

### Update pair attributes
update_pair_attrs(namespace, workspace, clean_pairs_list, attrs=['control_sample_tsca_id'])

# %%
### Create PoN from all normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
### Create PoN with normals from batch + other normals
batches_info = pd.read_excel(paths_to_samples_info)
all_paths = batches_info.path_to_samples_info.tolist()
# PoN = fc_interface.create_panel_of_normals(all_paths, -1, 'Cum_PoN_21_all')
# fc_interface.upload_pon(PoN, 'Cum_PoN_21_all', namespace, workspace)

# %%
# batch_id = 'TSCA21'
# batch_path = batches_info.loc[batches_info.tsca_id==batch_id, 'path_to_samples_info'].item()
# pd.read_table(batch_path)
# batch_id, paths, N, name

# %%
# Retrieve samples before export to FC
tsca21 = \
    fc_interface.\
        prepare_batch_samples_for_metadata_export('/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                            'TSCA21', google_bucket_id)

# %%
### Update WDLs
fc_interface.download_remote_wdls(namespace, workspace)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
### Upload metadata for given batch
fc_interface.update_batch_metadata('TSCA21', \
                                  '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                                      paths_to_samples_info, \
                                        namespace, workspace, google_bucket_id)
# Out:
# 65 Participants in this batch
# 95 Samples in this batch

# %%
(r1, r2, r3, r4, r5, r6) = fc_interface.export_batch_metadata_to_fc('TSCA21', namespace, workspace)

# %%
paths_to_batches_info = "paths_to_batches_info.xlsx"

# %%
# Retrieve list of samples with corresponding cohort from bsp.broadinstitute.org
samples_with_cohort = pd.read_excel('cohort_data/bsp_data.xls')

# All samples, without cohort data
all_samples = fc_interface.get_samples_multiple_batches(paths_to_batches_info, google_bucket_id)

# Add cohort data to all samples
data = pd.merge(all_samples, samples_with_cohort[['Sample ID', 'Collection']], \
                 left_on='bsp_sample_id_validation', \
                 right_on='Sample ID', \
                 how='outer') \
                .drop(['Sample ID'], axis=1)

# FC doesn't accept cohort names with non-alphanumeric characters, so use cohort codes instead
# Load dictionary of {long cohort name : short cohort code}
cohort_formatted_names = pd.read_table('cohort_files/cohort_names_dictionary.txt', \
                                       header=None, names=['cohort_name', 'cohort_code'])

# Add cohort codes to data
data = pd.merge(data, cohort_formatted_names, \
                        left_on='Collection', right_on='cohort_name', how='outer').\
                        drop(['cohort_name'], axis=1)

# Prepare for FC export format
data = data.rename(columns={'cohort_code': 'membership:sample_set_id', 'entity:sample_id': 'sample_id'})
# data = data[['membership:sample_set_id', 'sample_id']]

# %%
data.loc[ pd.isnull(data['membership:sample_set_id']), 'tsca_id'].unique()
# Out:
# array(['TSCA1213', 'TSCA15', 'TSCA20', 'TSCA16'], dtype=object)

# %%
samples_with_cohort.shape
# Out:
# (760, 70)

# %%
data[data['tsca_id'] == "TSCA16"]
# Out:
#                          sample_id participant_id  \
# 48            AB053-Tumor-SM-DNUMO          AB053
# 101          BT1011-Tumor-SM-DNUNI         BT1011
# 102          BT1015-Tumor-SM-DNULF         BT1015
# 103          BT1018-Tumor-SM-DNULG         BT1018
# 104          BT1037-Tumor-SM-DNUNG         BT1037
# 105          BT1038-Tumor-SM-DNUMR         BT1038
# 106           BT954-Tumor-SM-DO3CX          BT954
# 107           BT970-Tumor-SM-DNUM8          BT970
# 108           BT990-Tumor-SM-DO3D1          BT990
# 453           CO001-Tumor-SM-DNUN1          CO001
# 454           CO002-Tumor-SM-DNUND          CO002
# 455           CO003-Tumor-SM-DNUNP          CO003
# 456           CO004-Tumor-SM-DNULC          CO004
# 457           CO005-Tumor-SM-DNULO          CO005
# 458           CO006-Tumor-SM-DNUM1          CO006
# 459           CO007-Tumor-SM-DNUMD          CO007
# 460           CO008-Tumor-SM-DNUMP          CO008
# 471           CY010-Tumor-SM-DNUN9          CY010
# 472           CY010-Tumor-SM-DNUMW          CY010
# 473           CY010-Tumor-SM-DNUMF          CY010
# 474           CY011-Tumor-SM-DNULH          CY011
# 475           CY011-Tumor-SM-DNUM6          CY011
# 476           CY011-Tumor-SM-DNUMJ          CY011
# 542           EH017-Tumor-SM-DNUM4          EH017
# 543           EH024-Tumor-SM-DNUL1          EH024
# 562           HG005-Tumor-SM-DNULV          HG005
# 563           HG017-Tumor-SM-DNUML          HG017
# 564           HG017-Tumor-SM-DNULB          HG017
# 565           HG018-Tumor-SM-DNUMX          HG018
# 566           HG018-Tumor-SM-DNUNA          HG018
# ..                             ...            ...
# 757        PEDS200-Normal-SM-DNUMK        PEDS200
# 758        PEDS200-Normal-SM-DNUME        PEDS200
# 759         PEDS200-Tumor-SM-DNUMU        PEDS200
# 760         PEDS200-Tumor-SM-DNUMQ        PEDS200
# 761         PEDS202-Tumor-SM-DNULK        PEDS202
# 762         PEDS202-Tumor-SM-DNUNN        PEDS202
# 763         PEDS202-Tumor-SM-DNULW        PEDS202
# 764        PEDS204-Normal-SM-DNUMZ        PEDS204
# 765         PEDS204-Tumor-SM-DO3D5        PEDS204
# 766         PEDS209-Tumor-SM-DNULE        PEDS209
# 767         PEDS209-Tumor-SM-DNULQ        PEDS209
# 768         PEDS209-Tumor-SM-DNULA        PEDS209
# 769        PEDS211-Normal-SM-DO3D4        PEDS211
# 770         PEDS211-Tumor-SM-DNUM5        PEDS211
# 771         PEDS211-Tumor-SM-DO3CZ        PEDS211
# 897    CCLF_RCRF004-Tumor-SM-DNULL   CCLF_RCRF004
# 898    CCLF_RCRF004-Tumor-SM-DNUMY   CCLF_RCRF004
# 899    CCLF_RCRF004-Tumor-SM-DNUMA   CCLF_RCRF004
# 900    CCLF_RCRF004-Tumor-SM-DNUMM   CCLF_RCRF004
# 901    CCLF_RCRF004-Tumor-SM-DNULX   CCLF_RCRF004
# 902  CCLF_RCRF1005-Normal-SM-DNUL8  CCLF_RCRF1005
# 903   CCLF_RCRF1005-Tumor-SM-DNUNL  CCLF_RCRF1005
# 943    CCLF_SS1002-Normal-SM-DNUMI    CCLF_SS1002
# 944     CCLF_SS1002-Tumor-SM-DNUNC    CCLF_SS1002
# 945     CCLF_SS1003-Tumor-SM-DNUNO    CCLF_SS1003
# 946    CCLF_SS1004-Normal-SM-DNUMG    CCLF_SS1004
# 947     CCLF_SS1004-Tumor-SM-DNUN6    CCLF_SS1004
# 948     CCLF_SS1005-Tumor-SM-DO7N1    CCLF_SS1005
# 958           PK044-Tumor-SM-DNUMC          PK044
# 959           SP022-Tumor-SM-DNUMH          SP022
#
#                                 clean_bam_file_capture  \
# 48   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 101  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 102  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 103  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 104  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 105  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 106  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 107  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 108  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 453  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 454  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 455  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 456  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 457  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 458  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 459  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 460  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 471  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 472  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 473  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 474  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 475  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 476  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 542  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 543  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 562  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 563  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 564  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 565  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 566  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# ..                                                 ...
# 757  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 758  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 759  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 760  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 761  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 762  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 763  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 764  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 765  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 766  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 767  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 768  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 769  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 770  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 771  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 897  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 898  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 899  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 900  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 901  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 902  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 903  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 943  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 944  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 945  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 946  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 947  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 948  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 958  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# 959  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
#
#              external_id_validation   aggregation_product_name_validation  \
# 48                   AB053T_OPAC_p4  TSCA Rapid Cancer Detection Panel v2
# 101                    BT1011_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 102                    BT1015_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 103           BT1018_NSA_Laminin_p5  TSCA Rapid Cancer Detection Panel v2
# 104                    BT1037_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 105                    BT1038_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 106                    BT954_NSA_p5  TSCA Rapid Cancer Detection Panel v2
# 107                     BT970_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 108                    BT990_NSA_p5  TSCA Rapid Cancer Detection Panel v2
# 453                  CO001T_1_CM_p7  TSCA Rapid Cancer Detection Panel v2
# 454                 CO002T_1_CM_p10  TSCA Rapid Cancer Detection Panel v2
# 455                 CO003T_1_CM_p10  TSCA Rapid Cancer Detection Panel v2
# 456                  CO004T_1_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 457                  CO005T_1_CM_p8  TSCA Rapid Cancer Detection Panel v2
# 458                  CO006T_1_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 459                  CO007T_1_CM_p8  TSCA Rapid Cancer Detection Panel v2
# 460                  CO008T_1_CM_p8  TSCA Rapid Cancer Detection Panel v2
# 471                   CY010T_AR5_p7  TSCA Rapid Cancer Detection Panel v2
# 472                  CY010T_RETM_p7  TSCA Rapid Cancer Detection Panel v2
# 473                  CY010T_SMGM_p7  TSCA Rapid Cancer Detection Panel v2
# 474                   CY011T_AR5_p7  TSCA Rapid Cancer Detection Panel v2
# 475                    CY011T_CM_p7  TSCA Rapid Cancer Detection Panel v2
# 476                  CY011T_RETM_p7  TSCA Rapid Cancer Detection Panel v2
# 542                    EH017T_CM_p4  TSCA Rapid Cancer Detection Panel v2
# 543                       EH024T_CM  TSCA Rapid Cancer Detection Panel v2
# 562                    HG005T_CM_p4  TSCA Rapid Cancer Detection Panel v2
# 563          HG017T_2_CM_2DTrans_p6  TSCA Rapid Cancer Detection Panel v2
# 564                  HG017T_OPAC_p7  TSCA Rapid Cancer Detection Panel v2
# 565                HG018T_2_RETM_p5  TSCA Rapid Cancer Detection Panel v2
# 566                    HG018T_CM_p6  TSCA Rapid Cancer Detection Panel v2
# ..                              ...                                   ...
# 757                PEDS200N_RETM_p5  TSCA Rapid Cancer Detection Panel v2
# 758                PEDS200N_SMGM_p5  TSCA Rapid Cancer Detection Panel v2
# 759                PEDS200T_RETM_p5  TSCA Rapid Cancer Detection Panel v2
# 760                PEDS200T_SMGM_p5  TSCA Rapid Cancer Detection Panel v2
# 761                 PEDS202T_AR5_p8  TSCA Rapid Cancer Detection Panel v2
# 762                  PEDS202T_CM_p7  TSCA Rapid Cancer Detection Panel v2
# 763                PEDS202T_WITP_p7  TSCA Rapid Cancer Detection Panel v2
# 764                  PEDS204N_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 765                  PEDS204T_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 766                 PEDS209T_AR5_p6  TSCA Rapid Cancer Detection Panel v2
# 767                PEDS209T_RETM_p6  TSCA Rapid Cancer Detection Panel v2
# 768                PEDS209T_SMGM_p6  TSCA Rapid Cancer Detection Panel v2
# 769                  PEDS211N_CM_p6  TSCA Rapid Cancer Detection Panel v2
# 770                  PEDS211T_CM_p5  TSCA Rapid Cancer Detection Panel v2
# 771                  PEDS211T_FM_p5  TSCA Rapid Cancer Detection Panel v2
# 897           CCLF_RCRF1004T_AR5_p3  TSCA Rapid Cancer Detection Panel v2
# 898          CCLF_RCRF1004T_BEGM_p2  TSCA Rapid Cancer Detection Panel v2
# 899  CCLF_RCRF1004T_CM_WITP_VEGF_p2  TSCA Rapid Cancer Detection Panel v2
# 900            CCLF_RCRF1004T_CM_p2  TSCA Rapid Cancer Detection Panel v2
# 901           CCLF_RCRF1004T_M87_p3  TSCA Rapid Cancer Detection Panel v2
# 902              CCLF_RCRF1005N_M87  TSCA Rapid Cancer Detection Panel v2
# 903          CCLF_RCRF1005T_Primary  TSCA Rapid Cancer Detection Panel v2
# 943            CCLF_SS1002N_Primary  TSCA Rapid Cancer Detection Panel v2
# 944            CCLF_SS1002T_Primary  TSCA Rapid Cancer Detection Panel v2
# 945            CCLF_SS1003T_Primary  TSCA Rapid Cancer Detection Panel v2
# 946            CCLF_SS1004N_Primary  TSCA Rapid Cancer Detection Panel v2
# 947            CCLF_SS1004T_Primary  TSCA Rapid Cancer Detection Panel v2
# 948            CCLF_SS1005T_Primary  TSCA Rapid Cancer Detection Panel v2
# 958      PK044T_ProstateOrganoid_p3  TSCA Rapid Cancer Detection Panel v2
# 959                  SP022T_RETM_p9  TSCA Rapid Cancer Detection Panel v2
#
#     bsp_sample_id_validation stock_sample_id_validation sample_type  \
# 48                  SM-DOEKQ                   SM-DNUMO       Tumor
# 101                 SM-DOELK                   SM-DNUNI       Tumor
# 102                 SM-DOEJH                   SM-DNULF       Tumor
# 103                 SM-DOEJI                   SM-DNULG       Tumor
# 104                 SM-DOELI                   SM-DNUNG       Tumor
# 105                 SM-DOEKT                   SM-DNUMR       Tumor
# 106                 SM-DOEJ7                   SM-DO3CX       Tumor
# 107                 SM-DOEKA                   SM-DNUM8       Tumor
# 108                 SM-DOEKB                   SM-DO3D1       Tumor
# 453                 SM-DOEL3                   SM-DNUN1       Tumor
# 454                 SM-DOELF                   SM-DNUND       Tumor
# 455                 SM-DOELR                   SM-DNUNP       Tumor
# 456                 SM-DOEJE                   SM-DNULC       Tumor
# 457                 SM-DOEJQ                   SM-DNULO       Tumor
# 458                 SM-DOEK3                   SM-DNUM1       Tumor
# 459                 SM-DOEKF                   SM-DNUMD       Tumor
# 460                 SM-DOEKR                   SM-DNUMP       Tumor
# 471                 SM-DOELB                   SM-DNUN9       Tumor
# 472                 SM-DOEKY                   SM-DNUMW       Tumor
# 473                 SM-DOEKH                   SM-DNUMF       Tumor
# 474                 SM-DOEJJ                   SM-DNULH       Tumor
# 475                 SM-DOEK8                   SM-DNUM6       Tumor
# 476                 SM-DOEKL                   SM-DNUMJ       Tumor
# 542                 SM-DOEK6                   SM-DNUM4       Tumor
# 543                 SM-DOEJ3                   SM-DNUL1       Tumor
# 562                 SM-DOEJX                   SM-DNULV       Tumor
# 563                 SM-DOEKN                   SM-DNUML       Tumor
# 564                 SM-DOEJD                   SM-DNULB       Tumor
# 565                 SM-DOEKZ                   SM-DNUMX       Tumor
# 566                 SM-DOELC                   SM-DNUNA       Tumor
# ..                       ...                        ...         ...
# 757                 SM-DOEKM                   SM-DNUMK      Normal
# 758                 SM-DOEKG                   SM-DNUME      Normal
# 759                 SM-DOEKW                   SM-DNUMU       Tumor
# 760                 SM-DOEKS                   SM-DNUMQ       Tumor
# 761                 SM-DOEJM                   SM-DNULK       Tumor
# 762                 SM-DOELP                   SM-DNUNN       Tumor
# 763                 SM-DOEJY                   SM-DNULW       Tumor
# 764                 SM-DOEL2                   SM-DNUMZ      Normal
# 765                 SM-DOELH                   SM-DO3D5       Tumor
# 766                 SM-DOEJG                   SM-DNULE       Tumor
# 767                 SM-DOEJS                   SM-DNULQ       Tumor
# 768                 SM-DOEJC                   SM-DNULA       Tumor
# 769                 SM-DOELD                   SM-DO3D4      Normal
# 770                 SM-DOEK7                   SM-DNUM5       Tumor
# 771                 SM-DOEJU                   SM-DO3CZ       Tumor
# 897                 SM-DOEJN                   SM-DNULL       Tumor
# 898                 SM-DOEL1                   SM-DNUMY       Tumor
# 899                 SM-DOEKC                   SM-DNUMA       Tumor
# 900                 SM-DOEKO                   SM-DNUMM       Tumor
# 901                 SM-DOEJZ                   SM-DNULX       Tumor
# 902                 SM-DOEJA                   SM-DNUL8      Normal
# 903                 SM-DOELN                   SM-DNUNL       Tumor
# 943                 SM-DOEKK                   SM-DNUMI      Normal
# 944                 SM-DOELE                   SM-DNUNC       Tumor
# 945                 SM-DOELQ                   SM-DNUNO       Tumor
# 946                 SM-DOEKI                   SM-DNUMG      Normal
# 947                 SM-DOEL8                   SM-DNUN6       Tumor
# 948                 SM-DOEKV                   SM-DO7N1       Tumor
# 958                 SM-DOEKE                   SM-DNUMC       Tumor
# 959                 SM-DOEKJ                   SM-DNUMH       Tumor
#
#     picard_aggregation_type_validation     processed_subtype_validation  \
# 48                                 PCR              Cells:Pellet frozen
# 101                                PCR              Cells:Pellet frozen
# 102                                PCR              Cells:Pellet frozen
# 103                                PCR              Cells:Pellet frozen
# 104                                PCR              Cells:Pellet frozen
# 105                                PCR              Cells:Pellet frozen
# 106                                PCR              Cells:Pellet frozen
# 107                                PCR              Cells:Pellet frozen
# 108                                PCR              Cells:Pellet frozen
# 453                                PCR              Cells:Pellet frozen
# 454                                PCR              Cells:Pellet frozen
# 455                                PCR              Cells:Pellet frozen
# 456                                PCR              Cells:Pellet frozen
# 457                                PCR              Cells:Pellet frozen
# 458                                PCR              Cells:Pellet frozen
# 459                                PCR              Cells:Pellet frozen
# 460                                PCR              Cells:Pellet frozen
# 471                                PCR              Cells:Pellet frozen
# 472                                PCR              Cells:Pellet frozen
# 473                                PCR              Cells:Pellet frozen
# 474                                PCR              Cells:Pellet frozen
# 475                                PCR              Cells:Pellet frozen
# 476                                PCR              Cells:Pellet frozen
# 542                                PCR              Cells:Pellet frozen
# 543                                PCR  Tissue:Tissue Lysate/Homogenate
# 562                                PCR              Cells:Pellet frozen
# 563                                PCR              Cells:Pellet frozen
# 564                                PCR              Cells:Pellet frozen
# 565                                PCR              Cells:Pellet frozen
# 566                                PCR              Cells:Pellet frozen
# ..                                 ...                              ...
# 757                                PCR              Cells:Pellet frozen
# 758                                PCR              Cells:Pellet frozen
# 759                                PCR              Cells:Pellet frozen
# 760                                PCR              Cells:Pellet frozen
# 761                                PCR              Cells:Pellet frozen
# 762                                PCR              Cells:Pellet frozen
# 763                                PCR              Cells:Pellet frozen
# 764                                PCR              Cells:Pellet frozen
# 765                                PCR              Cells:Pellet frozen
# 766                                PCR              Cells:Pellet frozen
# 767                                PCR              Cells:Pellet frozen
# 768                                PCR              Cells:Pellet frozen
# 769                                PCR              Cells:Pellet frozen
# 770                                PCR              Cells:Pellet frozen
# 771                                PCR              Cells:Pellet frozen
# 897                                PCR              Cells:Pellet frozen
# 898                                PCR              Cells:Pellet frozen
# 899                                PCR              Cells:Pellet frozen
# 900                                PCR              Cells:Pellet frozen
# 901                                PCR              Cells:Pellet frozen
# 902                                PCR  Tissue:Tissue Lysate/Homogenate
# 903                                PCR  Tissue:Tissue Lysate/Homogenate
# 943                                PCR  Tissue:Tissue Lysate/Homogenate
# 944                                PCR  Tissue:Tissue Lysate/Homogenate
# 945                                PCR  Tissue:Tissue Lysate/Homogenate
# 946                                PCR  Tissue:Tissue Lysate/Homogenate
# 947                                PCR  Tissue:Tissue Lysate/Homogenate
# 948                                PCR  Tissue:Tissue Lysate/Homogenate
# 958                                PCR              Cells:Pellet frozen
# 959                                PCR              Cells:Pellet frozen
#
#             source_subtype_validation      squid_sample_id_validation  \
# 48                Tissue:Fresh Tissue                  AB053T_OPAC_p4
# 101               Tissue:Fresh Tissue                    BT1011_CM_p5
# 102           Cells:Cell Line, Viable                    BT1015_CM_p5
# 103               Tissue:Fresh Tissue           BT1018_NSA_Laminin_p5
# 104           Cells:Cell Line, Viable                    BT1037_CM_p5
# 105           Cells:Cell Line, Viable                    BT1038_CM_p5
# 106           Cells:Cell Line, Viable                    BT954_NSA_p5
# 107           Cells:Cell Line, Viable                     BT970_CM_p5
# 108           Cells:Cell Line, Viable                    BT990_NSA_p5
# 453           Cells:Cell Line, Viable                  CO001T_1_CM_p7
# 454               Tissue:Fresh Tissue                 CO002T_1_CM_p10
# 455               Tissue:Fresh Tissue                 CO003T_1_CM_p10
# 456               Tissue:Fresh Tissue                  CO004T_1_CM_p6
# 457               Tissue:Fresh Tissue                  CO005T_1_CM_p8
# 458               Tissue:Fresh Tissue                  CO006T_1_CM_p5
# 459               Tissue:Fresh Tissue                  CO007T_1_CM_p8
# 460               Tissue:Fresh Tissue                  CO008T_1_CM_p8
# 471           Cells:Cell Line, Viable                   CY010T_AR5_p7
# 472           Cells:Cell Line, Viable                  CY010T_RETM_p7
# 473           Cells:Cell Line, Viable                  CY010T_SMGM_p7
# 474           Cells:Cell Line, Viable                   CY011T_AR5_p7
# 475           Cells:Cell Line, Viable                    CY011T_CM_p7
# 476           Cells:Cell Line, Viable                  CY011T_RETM_p7
# 542                     Cells:Growing                    EH017T_CM_p4
# 543               Tissue:Fresh Tissue                       EH024T_CM
# 562  Tissue:DMSO Cryopreserved Tissue                    HG005T_CM_p4
# 563               Tissue:Fresh Tissue          HG017T_2_CM_2DTrans_p6
# 564               Tissue:Fresh Tissue                  HG017T_OPAC_p7
# 565               Tissue:Fresh Tissue                HG018T_2_RETM_p5
# 566               Tissue:Fresh Tissue                    HG018T_CM_p6
# ..                                ...                             ...
# 757           Cells:Cell Line, Viable                PEDS200N_RETM_p5
# 758           Cells:Cell Line, Viable                PEDS200N_SMGM_p5
# 759           Cells:Cell Line, Viable                PEDS200T_RETM_p5
# 760           Cells:Cell Line, Viable                PEDS200T_SMGM_p5
# 761           Cells:Cell Line, Viable                 PEDS202T_AR5_p8
# 762           Cells:Cell Line, Viable                  PEDS202T_CM_p7
# 763           Cells:Cell Line, Viable                PEDS202T_WITP_p7
# 764           Cells:Cell Line, Viable                  PEDS204N_CM_p6
# 765               Tissue:Fresh Tissue                  PEDS204T_CM_p6
# 766           Cells:Cell Line, Viable                 PEDS209T_AR5_p6
# 767           Cells:Cell Line, Viable                PEDS209T_RETM_p6
# 768           Cells:Cell Line, Viable                PEDS209T_SMGM_p6
# 769           Cells:Cell Line, Viable                  PEDS211N_CM_p6
# 770               Tissue:Fresh Tissue                  PEDS211T_CM_p5
# 771               Tissue:Fresh Tissue                  PEDS211T_FM_p5
# 897           Cells:Cell Line, Viable           CCLF_RCRF1004T_AR5_p3
# 898           Cells:Cell Line, Viable          CCLF_RCRF1004T_BEGM_p2
# 899           Cells:Cell Line, Viable  CCLF_RCRF1004T_CM_WITP_VEGF_p2
# 900           Cells:Cell Line, Viable            CCLF_RCRF1004T_CM_p2
# 901           Cells:Cell Line, Viable           CCLF_RCRF1004T_M87_p3
# 902               Tissue:Fresh Tissue              CCLF_RCRF1005N_M87
# 903               Tissue:Fresh Tissue          CCLF_RCRF1005T_Primary
# 943               Tissue:Fresh Tissue            CCLF_SS1002N_Primary
# 944               Tissue:Fresh Tissue            CCLF_SS1002T_Primary
# 945               Tissue:Fresh Tissue            CCLF_SS1003T_Primary
# 946               Tissue:Fresh Tissue            CCLF_SS1004N_Primary
# 947               Tissue:Fresh Tissue            CCLF_SS1004T_Primary
# 948               Tissue:Fresh Tissue            CCLF_SS1005T_Primary
# 958               Tissue:Fresh Tissue      PK044T_ProstateOrganoid_p3
# 959               Tissue:Fresh Tissue                  SP022T_RETM_p9
#
#     tumor_subtype short_letter_code  \
# 48        Primary                TP
# 101       Primary                TP
# 102       Primary                TP
# 103       Primary                TP
# 104    Metastatic                TM
# 105    Metastatic                TM
# 106     Recurrent                TR
# 107       Primary                TP
# 108       Primary                TP
# 453    Metastatic                TM
# 454       Primary                TP
# 455       Primary                TP
# 456    Metastatic                TM
# 457       Primary                TP
# 458       Primary                TP
# 459    Metastatic                TM
# 460    Metastatic                TM
# 471    Metastatic                TM
# 472    Metastatic                TM
# 473    Metastatic                TM
# 474    Metastatic                TM
# 475    Metastatic                TM
# 476    Metastatic                TM
# 542       Primary                TP
# 543       Primary                TP
# 562       Primary                TP
# 563       Primary                TP
# 564       Primary                TP
# 565    Metastatic                TM
# 566    Metastatic                TM
# ..            ...               ...
# 757           NaN             NCELL
# 758           NaN             NCELL
# 759       Primary                TP
# 760       Primary                TP
# 761       Primary                TP
# 762       Primary                TP
# 763       Primary                TP
# 764           NaN             NCELL
# 765       Primary                TP
# 766       Primary                TP
# 767       Primary                TP
# 768       Primary                TP
# 769           NaN             NCELL
# 770       Primary                TP
# 771       Primary                TP
# 897       Primary                TP
# 898       Primary                TP
# 899       Primary                TP
# 900       Primary                TP
# 901       Primary                TP
# 902       Primary              NDNA
# 903       Primary                TP
# 943       Primary              NDNA
# 944       Primary                TP
# 945       Primary                TP
# 946       Primary              NDNA
# 947       Primary                TP
# 948       Primary                TP
# 958    Metastatic                TM
# 959       Primary                TP
#
#                                           bam_filename  \
# 48   2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# 101  2_BT1011_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 102  2_BT1015_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 103  2_BT1018_NSA_Laminin_p5_H5TTJBCXY.2.aligned.du...
# 104  2_BT1037_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 105  2_BT1038_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 106  2_BT954_NSA_p5_H5TTJBCXY.2.aligned.duplicates_...
# 107  2_BT970_CM_p5_H5TTJBCXY.2.aligned.duplicates_m...
# 108  2_BT990_NSA_p5_H5TTJBCXY.2.aligned.duplicates_...
# 453  2_CO001T_1_CM_p7_H5TTJBCXY.2.aligned.duplicate...
# 454  2_CO002T_1_CM_p10_H5TTJBCXY.2.aligned.duplicat...
# 455  2_CO003T_1_CM_p10_H5TTJBCXY.2.aligned.duplicat...
# 456  2_CO004T_1_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 457  2_CO005T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 458  2_CO006T_1_CM_p5_H5TTJBCXY.2.aligned.duplicate...
# 459  2_CO007T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 460  2_CO008T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 471  2_CY010T_AR5_p7_H5TTJBCXY.2.aligned.duplicates...
# 472  2_CY010T_RETM_p7_H5TTJBCXY.2.aligned.duplicate...
# 473  2_CY010T_SMGM_p7_H5TTJBCXY.2.aligned.duplicate...
# 474  2_CY011T_AR5_p7_H5TTJBCXY.2.aligned.duplicates...
# 475  2_CY011T_CM_p7_H5TTJBCXY.2.aligned.duplicates_...
# 476  2_CY011T_RETM_p7_H5TTJBCXY.2.aligned.duplicate...
# 542  2_EH017T_CM_p4_H5TTJBCXY.2.aligned.duplicates_...
# 543  2_EH024T_CM_H5TTJBCXY.2.aligned.duplicates_mar...
# 562  2_HG005T_CM_p4_H5TTJBCXY.2.aligned.duplicates_...
# 563  2_HG017T_2_CM_2DTrans_p6_H5TTJBCXY.2.aligned.d...
# 564  2_HG017T_OPAC_p7_H5TTJBCXY.2.aligned.duplicate...
# 565  2_HG018T_2_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 566  2_HG018T_CM_p6_H5TTJBCXY.2.aligned.duplicates_...
# ..                                                 ...
# 757  2_PEDS200N_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 758  2_PEDS200N_SMGM_p5_H5TTJBCXY.2.aligned.duplica...
# 759  2_PEDS200T_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 760  2_PEDS200T_SMGM_p5_H5TTJBCXY.2.aligned.duplica...
# 761  2_PEDS202T_AR5_p8_H5TTJBCXY.2.aligned.duplicat...
# 762  2_PEDS202T_CM_p7_H5TTJBCXY.2.aligned.duplicate...
# 763  2_PEDS202T_WITP_p7_H5TTJBCXY.2.aligned.duplica...
# 764  2_PEDS204N_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 765  2_PEDS204T_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 766  2_PEDS209T_AR5_p6_H5TTJBCXY.2.aligned.duplicat...
# 767  2_PEDS209T_RETM_p6_H5TTJBCXY.2.aligned.duplica...
# 768  2_PEDS209T_SMGM_p6_H5TTJBCXY.2.aligned.duplica...
# 769  2_PEDS211N_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 770  2_PEDS211T_CM_p5_H5TTJBCXY.2.aligned.duplicate...
# 771  2_PEDS211T_FM_p5_H5TTJBCXY.2.aligned.duplicate...
# 897  2_CCLF_RCRF1004T_AR5_p3_H5TTJBCXY.2.aligned.du...
# 898  2_CCLF_RCRF1004T_BEGM_p2_H5TTJBCXY.2.aligned.d...
# 899  2_CCLF_RCRF1004T_CM_WITP_VEGF_p2_H5TTJBCXY.2.a...
# 900  2_CCLF_RCRF1004T_CM_p2_H5TTJBCXY.2.aligned.dup...
# 901  2_CCLF_RCRF1004T_M87_p3_H5TTJBCXY.2.aligned.du...
# 902  2_CCLF_RCRF1005N_M87_H5TTJBCXY.2.aligned.dupli...
# 903  2_CCLF_RCRF1005T_Primary_H5TTJBCXY.2.aligned.d...
# 943  2_CCLF_SS1002N_Primary_H5TTJBCXY.2.aligned.dup...
# 944  2_CCLF_SS1002T_Primary_H5TTJBCXY.2.aligned.dup...
# 945  2_CCLF_SS1003T_Primary_H5TTJBCXY.2.aligned.dup...
# 946  2_CCLF_SS1004N_Primary_H5TTJBCXY.2.aligned.dup...
# 947  2_CCLF_SS1004T_Primary_H5TTJBCXY.2.aligned.dup...
# 948  2_CCLF_SS1005T_Primary_H5TTJBCXY.2.aligned.dup...
# 958  2_PK044T_ProstateOrganoid_p3_H5TTJBCXY.2.align...
# 959  2_SP022T_RETM_p9_H5TTJBCXY.2.aligned.duplicate...
#
#                                           bai_filename  \
# 48   2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# 101  2_BT1011_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 102  2_BT1015_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 103  2_BT1018_NSA_Laminin_p5_H5TTJBCXY.2.aligned.du...
# 104  2_BT1037_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 105  2_BT1038_CM_p5_H5TTJBCXY.2.aligned.duplicates_...
# 106  2_BT954_NSA_p5_H5TTJBCXY.2.aligned.duplicates_...
# 107  2_BT970_CM_p5_H5TTJBCXY.2.aligned.duplicates_m...
# 108  2_BT990_NSA_p5_H5TTJBCXY.2.aligned.duplicates_...
# 453  2_CO001T_1_CM_p7_H5TTJBCXY.2.aligned.duplicate...
# 454  2_CO002T_1_CM_p10_H5TTJBCXY.2.aligned.duplicat...
# 455  2_CO003T_1_CM_p10_H5TTJBCXY.2.aligned.duplicat...
# 456  2_CO004T_1_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 457  2_CO005T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 458  2_CO006T_1_CM_p5_H5TTJBCXY.2.aligned.duplicate...
# 459  2_CO007T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 460  2_CO008T_1_CM_p8_H5TTJBCXY.2.aligned.duplicate...
# 471  2_CY010T_AR5_p7_H5TTJBCXY.2.aligned.duplicates...
# 472  2_CY010T_RETM_p7_H5TTJBCXY.2.aligned.duplicate...
# 473  2_CY010T_SMGM_p7_H5TTJBCXY.2.aligned.duplicate...
# 474  2_CY011T_AR5_p7_H5TTJBCXY.2.aligned.duplicates...
# 475  2_CY011T_CM_p7_H5TTJBCXY.2.aligned.duplicates_...
# 476  2_CY011T_RETM_p7_H5TTJBCXY.2.aligned.duplicate...
# 542  2_EH017T_CM_p4_H5TTJBCXY.2.aligned.duplicates_...
# 543  2_EH024T_CM_H5TTJBCXY.2.aligned.duplicates_mar...
# 562  2_HG005T_CM_p4_H5TTJBCXY.2.aligned.duplicates_...
# 563  2_HG017T_2_CM_2DTrans_p6_H5TTJBCXY.2.aligned.d...
# 564  2_HG017T_OPAC_p7_H5TTJBCXY.2.aligned.duplicate...
# 565  2_HG018T_2_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 566  2_HG018T_CM_p6_H5TTJBCXY.2.aligned.duplicates_...
# ..                                                 ...
# 757  2_PEDS200N_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 758  2_PEDS200N_SMGM_p5_H5TTJBCXY.2.aligned.duplica...
# 759  2_PEDS200T_RETM_p5_H5TTJBCXY.2.aligned.duplica...
# 760  2_PEDS200T_SMGM_p5_H5TTJBCXY.2.aligned.duplica...
# 761  2_PEDS202T_AR5_p8_H5TTJBCXY.2.aligned.duplicat...
# 762  2_PEDS202T_CM_p7_H5TTJBCXY.2.aligned.duplicate...
# 763  2_PEDS202T_WITP_p7_H5TTJBCXY.2.aligned.duplica...
# 764  2_PEDS204N_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 765  2_PEDS204T_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 766  2_PEDS209T_AR5_p6_H5TTJBCXY.2.aligned.duplicat...
# 767  2_PEDS209T_RETM_p6_H5TTJBCXY.2.aligned.duplica...
# 768  2_PEDS209T_SMGM_p6_H5TTJBCXY.2.aligned.duplica...
# 769  2_PEDS211N_CM_p6_H5TTJBCXY.2.aligned.duplicate...
# 770  2_PEDS211T_CM_p5_H5TTJBCXY.2.aligned.duplicate...
# 771  2_PEDS211T_FM_p5_H5TTJBCXY.2.aligned.duplicate...
# 897  2_CCLF_RCRF1004T_AR5_p3_H5TTJBCXY.2.aligned.du...
# 898  2_CCLF_RCRF1004T_BEGM_p2_H5TTJBCXY.2.aligned.d...
# 899  2_CCLF_RCRF1004T_CM_WITP_VEGF_p2_H5TTJBCXY.2.a...
# 900  2_CCLF_RCRF1004T_CM_p2_H5TTJBCXY.2.aligned.dup...
# 901  2_CCLF_RCRF1004T_M87_p3_H5TTJBCXY.2.aligned.du...
# 902  2_CCLF_RCRF1005N_M87_H5TTJBCXY.2.aligned.dupli...
# 903  2_CCLF_RCRF1005T_Primary_H5TTJBCXY.2.aligned.d...
# 943  2_CCLF_SS1002N_Primary_H5TTJBCXY.2.aligned.dup...
# 944  2_CCLF_SS1002T_Primary_H5TTJBCXY.2.aligned.dup...
# 945  2_CCLF_SS1003T_Primary_H5TTJBCXY.2.aligned.dup...
# 946  2_CCLF_SS1004N_Primary_H5TTJBCXY.2.aligned.dup...
# 947  2_CCLF_SS1004T_Primary_H5TTJBCXY.2.aligned.dup...
# 948  2_CCLF_SS1005T_Primary_H5TTJBCXY.2.aligned.dup...
# 958  2_PK044T_ProstateOrganoid_p3_H5TTJBCXY.2.align...
# 959  2_SP022T_RETM_p9_H5TTJBCXY.2.aligned.duplicate...
#
#                                 clean_bai_file_capture tsca_id  \
# 48   gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 101  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 102  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 103  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 104  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 105  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 106  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 107  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 108  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 453  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 454  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 455  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 456  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 457  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 458  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 459  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 460  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 471  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 472  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 473  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 474  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 475  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 476  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 542  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 543  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 562  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 563  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 564  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 565  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 566  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# ..                                                 ...     ...
# 757  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 758  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 759  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 760  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 761  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 762  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 763  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 764  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 765  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 766  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 767  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 768  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 769  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 770  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 771  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 897  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 898  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 899  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 900  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 901  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 902  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 903  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 943  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 944  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 945  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 946  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 947  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 948  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 958  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 959  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
#
#                                             Collection  \
# 48   Cancer Cell Line Factory (CCLF) / Adam Bass/Ku...
# 101  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 102  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 103  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 104  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 105  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 106  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 107  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 108  Cancer Cell Line Factory (CCLF) / Keith Ligon ...
# 453  Cancer Cell Line Factory (CCLF) / David Sidran...
# 454  Cancer Cell Line Factory (CCLF) / David Sidran...
# 455  Cancer Cell Line Factory (CCLF) / David Sidran...
# 456  Cancer Cell Line Factory (CCLF) / David Sidran...
# 457  Cancer Cell Line Factory (CCLF) / David Sidran...
# 458  Cancer Cell Line Factory (CCLF) / David Sidran...
# 459  Cancer Cell Line Factory (CCLF) / David Sidran...
# 460  Cancer Cell Line Factory (CCLF) / David Sidran...
# 471  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 472  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 473  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 474  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 475  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 476  Cancer Cell Line Factory (CCLF) / Charles Yoon...
# 542  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 543  Cancer Cell Line Factory (CCLF) / Lisa Henske ...
# 562  Cancer Cell Line Factory (CCLF) / Hui Gao (NIB...
# 563  Cancer Cell Line Factory (CCLF) / Hui Gao (NIB...
# 564  Cancer Cell Line Factory (CCLF) / Hui Gao (NIB...
# 565  Cancer Cell Line Factory (CCLF) / Hui Gao (NIB...
# 566  Cancer Cell Line Factory (CCLF) / Hui Gao (NIB...
# ..                                                 ...
# 757  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 758  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 759  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 760  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 761  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 762  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 763  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 764  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 765  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 766  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 767  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 768  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 769  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 770  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 771  Cancer Cell Line Factory (CCLF) / Hong/Crompto...
# 897  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 898  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 899  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 900  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 901  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 902  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 903  Cancer Cell Line Factory (CCLF) / Brian McStee...
# 943  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 944  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 945  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 946  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 947  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 948  Cancer Cell Line Factory (CCLF) / Sabina Signo...
# 958  Cancer Cell Line Factory (CCLF) / Mary-Ellen T...
# 959  Cancer Cell Line Factory (CCLF) / Sid Puram/De...
#
#     membership:sample_set_id
# 48                        AB
# 101                       BT
# 102                       BT
# 103                       BT
# 104                       BT
# 105                       BT
# 106                       BT
# 107                       BT
# 108                       BT
# 453                       CO
# 454                       CO
# 455                       CO
# 456                       CO
# 457                       CO
# 458                       CO
# 459                       CO
# 460                       CO
# 471                       CY
# 472                       CY
# 473                       CY
# 474                       CY
# 475                       CY
# 476                       CY
# 542                       EH
# 543                       EH
# 562                       HG
# 563                       HG
# 564                       HG
# 565                       HG
# 566                       HG
# ..                       ...
# 757                     PEDS
# 758                     PEDS
# 759                     PEDS
# 760                     PEDS
# 761                     PEDS
# 762                     PEDS
# 763                     PEDS
# 764                     PEDS
# 765                     PEDS
# 766                     PEDS
# 767                     PEDS
# 768                     PEDS
# 769                     PEDS
# 770                     PEDS
# 771                     PEDS
# 897                CCLF_RCRF
# 898                CCLF_RCRF
# 899                CCLF_RCRF
# 900                CCLF_RCRF
# 901                CCLF_RCRF
# 902                CCLF_RCRF
# 903                CCLF_RCRF
# 943                       SS
# 944                       SS
# 945                       SS
# 946                       SS
# 947                       SS
# 948                       SS
# 958                      NaN
# 959                       SP
#
# [95 rows x 20 columns]
