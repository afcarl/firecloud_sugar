# %%
import v2fc_interface as fs

# %load_ext autoreload
# %autoreload 2

# %%
paths_to_samples_info = pd.read_excel("paths_to_batches_info.xlsx")
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA_2_0"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"

# %%
participants = pd.concat([pd.read_table(i) for i in paths_to_samples_info['path_to_samples_info'].tolist()], axis=0)

# %%
len(participants['individual_id'].unique().tolist())
# Out:
# 581

# %%
dfs = []
for idx, row in paths_to_samples_info.iterrows():
    print(row['tsca_id'])
    pts = fs.prepare_participants_for_metadata_export(row['path_to_samples_info'])
    res = fs.save_and_upload_participants(participants, namespace, workspace, row['tsca_id'])
    print(res.text)
# Out:
# TSCA1213
# 160 Participants in this batch
# {
#   "statusCode": 400,
#   "source": "FireCloud",
#   "timestamp": 1509647236173,
#   "causes": [],
#   "stackTrace": [],
#   "message": "Invalid first column header, should look like tsvType:entity_type_id"
# }
#
# TSCA14
# 73 Participants in this batch
# {
#   "statusCode": 400,
#   "source": "FireCloud",
#   "timestamp": 1509647238943,
#   "causes": [],
#   "stackTrace": [],
#   "message": "Invalid first column header, should look like tsvType:entity_type_id"
# }
#
# TSCA15
# 103 Participants in this batch
# {
#   "statusCode": 400,
#   "source": "FireCloud",
#   "timestamp": 1509647241655,
#   "causes": [],
#   "stackTrace": [],
#   "message": "Invalid first column header, should look like tsvType:entity_type_id"
# }
#
# TSCA16
# 59 Participants in this batch
# {
#   "statusCode": 400,
#   "source": "FireCloud",
#   "timestamp": 1509647244458,
#   "causes": [],
#   "stackTrace": [],
#   "message": "Invalid first column header, should look like tsvType:entity_type_id"
# }
#
# TSCA17
# 63 Participants in this batch
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0dccbaa72e0b> in <module>()
#       3     print(row['tsca_id'])
#       4     pts = fs.prepare_participants_for_metadata_export(row['path_to_samples_info'])
# ----> 5     res = fs.save_and_upload_participants(participants, namespace, workspace, row['tsca_id'])
#       6     print(res.text)
#
# /Users/mimoun/production_fc/metadata_exports/v2fc_interface.py in save_and_upload_participants(data, namespace, workspace, tsca_id)
#     164     filename = './%s/fc_upload_patients_%s.txt' % (tsca_id, tsca_id)
#     165     data.to_csv(filename, '\t', index=False)
# --> 166     res = upload_entities_from_tsv(namespace, workspace, filename)
#     167     return res
#     168
#
# /Users/mimoun/production_fc/metadata_exports/v2fc_interface.py in upload_entities_from_tsv(namespace, workspace, entities_tsv_file)
#     178         HTTP Response
#     179     """
# --> 180     res = firecloud_api.upload_entities_tsv(namespace, workspace, entities_tsv=entities_tsv_file)
#     181     return res
#     182
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/firecloud/api.py in upload_entities_tsv(namespace, workspace, entities_tsv)
#     186     else:
#     187         raise ValueError('Unsupported input type.')
# --> 188     return upload_entities(namespace, workspace, entity_data)
#     189
#     190 def copy_entities(from_namespace, from_workspace, to_namespace,
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/firecloud/api.py in upload_entities(namespace, workspace, entity_data)
#     159     })
#     160     uri = "workspaces/{0}/{1}/importEntities".format(namespace, workspace)
# --> 161     return __post(uri, headers=headers, data=body)
#     162
#     163 def upload_entities_tsv(namespace, workspace, entities_tsv):
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/firecloud/api.py in __post(methcall, headers, root_url, **kwargs)
#      64     if not headers:
#      65         headers = _fiss_access_headers({"Content-type":  "application/json"})
# ---> 66     r = requests.post(urljoin(root_url, methcall), headers=headers, **kwargs)
#      67     if fcconfig.verbosity > 1:
#      68         info = r.url
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/mimoun/anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/mimoun/anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/mimoun/anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/mimoun/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
participants = fs.prepare_participants_for_metadata_export("/xchip/clf/seq_data/processed_for_fh/tsca1213_201610_SN0106956/tsca1213_201610_SN0106956.import_samples.txt")
# Out:
# 160 Participants in this batch

# %%
participants
# Out:
#     entity:participant_id
# 0                    AA33
# 1                    AA34
# 2                    AA36
# 3                    AA39
# 4                    AA40
# 5                   AB044
# 6                 ANGMCSS
# 7                  BT1008
# 8                   BT922
# 9                   BT923
# 10                  BT950
# 11                  BT961
# 12                  BT972
# 13                CHLA200
# 14                  CO001
# 15                  CO002
# 16                  CO003
# 17                  CO004
# 18                  CO005
# 19                  CO006
# 20                  CO007
# 21               COGAR359
# 22                COGH430
# 23                  CY004
# 24                  CY007
# 25                  CY010
# 26                  DW027
# 27                  DW031
# 29                  DW032
# 30                  DW033
# ..                    ...
# 144                 JNT97
# 145                 JNT98
# 146                 JNT99
# 147                   MB1
# 148                OACM51
# 149                OCIC5x
# 150                OCIP8p
# 151                 OV17R
# 152             PACADD165
# 153             PACADD183
# 154               PEDS071
# 155               PEDS153
# 158               PEDS163
# 160               PEDS165
# 165               PEDS166
# 167               PEDS167
# 169               PEDS168
# 172               PEDS171
# 175               PEDS174
# 177               PEDS175
# 178               PEDS176
# 180               PEDS185
# 182               PEDS186
# 183               PEDS187
# 184               PEDS190
# 185                 PM748
# 186                  SW13
# 187                 SW756
# 188                 SW954
# 189                 UMUC9
#
# [160 rows x 1 columns]

# %%
# Out:
# <Response [200]>

# %%
# Out:
#   entity:participant_id
# 0                  AA33

# %%
fs.save_and_upload_participants(participants.iloc[[0]], namespace, workspace, "TSCA1213")
# Out:
# <Response [200]>
