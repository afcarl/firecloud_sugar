# %% [markdown]
# ### Commands

# %%
from firecloud import api as firecloud_api
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2

# %%
### Parameters
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"
paths_to_samples_info = "paths_to_batches_info.xlsx"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"

# %% [markdown]
# #### Deletions

# %%
### Delete unnecessary attributes in samples
attrs = ["annotate_variants_vcf", "annotate_variants_vcf_index", "oncotated_maf", "mutect2_vcf_index", "match_normal_oncotated_maf", "gnomad_vcf", "merged_vcfs", "match_primary_tumor_bam_file"]
for idx, row in all_samples.iterrows():
    fc_interface.delete_entity_attributes(namespace, workspace, "sample", row['entity:sample_id'], attrs)

# %%
### Delete method repostory
firecloud_api.delete_repository_method('tsca', 'CreatePoN', 15)

# %%
### Delete method repository
firecloud_api.delete_repository_method('tsca', 'Mutect2_for_Normal', 1)

# %%
### Delete multiple method repositories
for i in range(10, 23):
    firecloud_api.delete_repository_method('tsca', 'CreatePoN', i)

# %%
### Delete method config
firecloud_api.delete_workspace_config(namespace, workspace, "tsca", "Mutect2_for_Normal")

# %%
### Create pairs
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
### Upload pairs
# res = fc_interface.upload_pairs(namespace, workspace, clean_pairs_list)

# %%
# ### Delete unnecessary attributes in pairs
# ### NOT WOKING
# all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
# pairs_list = fc_interface.create_pairs_list(all_samples)
# attrs = ["__annotate_variants_vcf", "__annotate_variants_vcf_index", \
#          "__scattered_intervals", "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2", \
#          "__tmp_mutect_vcf2", "_tmp_mutect_vcf_index2"]
# for idx, row in pairs_list.iterrows():
#     fc_interface.delete_entity_attributes(namespace, workspace, "pair", row['entity:pair_id'], attrs)

# %%
### Upload metadata for given batch
fc_interface.update_batch_metadata('TSCA21', \
                                  '/xchip/clf/seq_data/processed_for_fh/tsca21_201708_SN0128552/tsca21_201708_SN0128552.import_samples.txt', \
                                      paths_to_samples_info, \
                                        namespace, workspace, google_bucket_id)

# %%
### Delete sample_set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### All paths to batch info
# pd.read_excel('paths_to_batches_info.xlsx').path_to_samples_info.tolist()

# %%
### Create cumulative PoN
batches_info = pd.read_excel(paths_to_samples_info)
PoN = fc_interface.create_panel_of_normals(batches_info.path_to_samples_info.tolist(), -1, 'CumPoN21')
fc_interface.upload_pon(PoN, 'CumPoN21', namespace, workspace)

# %%
### Create PoN from normals of only one batch
tsca21_path = batches_info.path_to_samples_info.tolist()[-1]
PoN = fc_interface.create_panel_of_normals([tsca21_path], -1, 'PoN_TSCA21_Normals')
fc_interface.upload_pon(PoN, 'PoN_TSCA21_Normals', namespace, workspace)

# %%
### Delete pair set
fc_interface.delete_pair_set(namespace, workspace, 'TSCA1213')

# %%
### Delete sample set
fc_interface.delete_sample_set(namespace, workspace, 'TSCA1213')

# %%
### Download method configs
fc_interface.download_method_configs(namespace, workspace)

# %%
### Upload pairsets
tn_pairsets, tp_pairsets = fc_interface.create_pairsets(all_samples, clean_pairs_list)
fc_interface.upload_pairsets(namespace, workspace, tn_pairsets, "TN")
fc_interface.upload_pairsets(namespace, workspace, tp_pairsets, "TP")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)
pairs_list = fc_interface.create_pairs_list(all_samples)
blacklist = ["DW039-Tumor-SM-DB2IF"]
clean_pairs_list = pairs_list[ ~pairs_list['case_sample_id'].isin(blacklist)]

# %%
clean_pairs_list.head(1)
# Out:
#               entity:pair_id       case_sample_id control_sample_id  \
# 0  AA34-Tumor-SM-D4L25_NA_TN  AA34-Tumor-SM-D4L25                NA
#
#   participant_id    match_type case_sample_tsca_id control_sample_tsca_id
# 0           AA34  tumor_normal            TSCA1213                     NA

# %%
for idx, row in clean_pairs_list.iterrows():
    print(row.index.tolist())
# Out:
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ['entity:pair_id', 'case_sample_id', 'control_sample_id', 'participant_id', 'match_type', 'case_sample_tsca_id', 'control_sample_tsca_id']
# ...

# %%
def update_pair_attrs(namespace, workspace, pairs, a):
    """Update pair attributes
    Args:
        - pairs: df of pairs to update
    """
    for idx, row in pairs.iterrows():
        attrs = row.index.tolist()        
        attr_update = [{"op": "AddUpdateAttribute", "attributeName":  attr, \
                        "addUpdateAttribute": row[attr]} for attr in attrs]
        print(attr_update)
#         attr_update = [{"op": "AddUpdateAttribute", "attributeName": "control_sample_tsca_id", \
#                 "addUpdateAttribute": "TSCA14"}]
#         control_sample_tsca_id

# %%
update_pairs(namespace, workspace, clean_pairs_list)
# Out:
# [{'op': 'AddUpdateAttribute', 'attributeName': 'entity:pair_id', 'addUpdateAttribute': 'AA34-Tumor-SM-D4L25_NA_TN'}, {'op': 'AddUpdateAttribute', 'attributeName': 'case_sample_id', 'addUpdateAttribute': 'AA34-Tumor-SM-D4L25'}, {'op': 'AddUpdateAttribute', 'attributeName': 'control_sample_id', 'addUpdateAttribute': 'NA'}, {'op': 'AddUpdateAttribute', 'attributeName': 'participant_id', 'addUpdateAttribute': 'AA34'}, {'op': 'AddUpdateAttribute', 'attributeName': 'match_type', 'addUpdateAttribute': 'tumor_normal'}, {'op': 'AddUpdateAttribute', 'attributeName': 'case_sample_tsca_id', 'addUpdateAttribute': 'TSCA1213'}, {'op': 'AddUpdateAttribute', 'attributeName': 'control_sample_tsca_id', 'addUpdateAttribute': 'NA'}]
# ...

# %%
# UPDATE THIS ONE:
# BT1016-Tumor-SM-GBJ9Q_BT1016-Tumor-SM-DB2IY_TP

# %%
pair_id = "BT1016-Tumor-SM-GBJ9Q_BT1016-Tumor-SM-DB2IY_TP"
sample_id = "BT1016-Tumor-SM-GBJ9Q"
match_normal_id = "BT1016-Tumor-SM-DB2IY"

# %%
clean_pairs_list[ clean_pairs_list['entity:pair_id'] == pair_id].
# Out:
#                                       entity:pair_id         case_sample_id  \
# 1619  BT1016-Tumor-SM-GBJ9Q_BT1016-Tumor-SM-DB2IY_TP  BT1016-Tumor-SM-GBJ9Q
#
#           control_sample_id participant_id     match_type case_sample_tsca_id  \
# 1619  BT1016-Tumor-SM-DB2IY         BT1016  tumor_primary              TSCA21
#
#      control_sample_tsca_id
# 1619                 TSCA14

# %%
def update_pairs(namespace, workspace, pairs):
    os.system('mkdir -p Pairs')
    filename = './Pairs/fc_upload_pairs.txt'
    pairs.to_csv(filename, '\t', index=False)
    for idx, row in pairs.iterrows():
#         attr_update = [{"op": "AddUpdateAttribute", "attributeName":  attr, "addUpdateAttribute": } for attr in attrs]
#         res = firecloud_api.update_entity(namespace, workspace, "pair", row['entity:pair_id'], attr_update)

# %%
attr_update = [{"op": "AddUpdateAttribute", "attributeName": "control_sample_tsca_id", \
                "addUpdateAttribute": "TSCA14"}]

# %%
res = firecloud_api.update_entity(namespace, workspace, "pair", \
                            "BT1016-Tumor-SM-GBJ9Q_BT1016-Tumor-SM-DB2IY_TP", attr_update)

# %%
res.json()
# Out:
# {'attributes': {'case_sample': {'entityName': 'BT1016-Tumor-SM-GBJ9Q',
#    'entityType': 'sample'},
#   'case_sample_tsca_id': 'TSCA21',
#   'control_sample': {'entityName': 'BT1016-Tumor-SM-DB2IY',
#    'entityType': 'sample'},
#   'control_sample_tsca_id': 'TSCA14',
#   'match_type': 'tumor_primary',
#   'participant': {'entityName': 'BT1016', 'entityType': 'participant'}},
#  'entityType': 'pair',
#  'name': 'BT1016-Tumor-SM-GBJ9Q_BT1016-Tumor-SM-DB2IY_TP'}

# %%
# all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)

# all_paths_df = pd.read_excel('paths_to_batches_info.xlsx')

# # for idx, row in all_paths_df.iterrows():
# #     fc_interface.prepare_batch_sample_set_for_metadata_export(row.path_to_samples_info, row.tsca_id);
# #     tsca_id = row.tsca_id
# #     tumors_sample_set_metadata  = "%s/fc_upload_sample_set_tsca_%s_tumors.txt" % (tsca_id, tsca_id)
# #     normals_sample_set_metadata = "%s/fc_upload_sample_set_tsca_%s_normals.txt" % (tsca_id, tsca_id)
# #     res = fc_interface.upload_entities_from_tsv(namespace, workspace, tumors_sample_set_metadata)
# #     res = fc_interface.upload_entities_from_tsv(namespace, workspace, normals_sample_set_metadata)

# %%
for idx, row in clean_pairs_list.iterrows():
    res = fc_interface.delete_pair(namespace, workspace, row['entity:pair_id'])
    print(res)
