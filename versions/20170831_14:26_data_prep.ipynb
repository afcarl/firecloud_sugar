# %%
# pd.read_table("/xchip/clf/seq_data/processed_for_fh/tsca20_201707_SN0125362/tsca20_201707_SN0125362.import_samples.txt")

# %%
import fc_interface

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
paths_to_batches_info = pd.read_excel("paths_to_batches_info.xlsx")
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA"

# %%
all_samples = fc_interface.get_samples_multiple_batches(paths_to_samples_info, google_bucket_id)

# %%
all_samples [ all_samples.sample_type == "Normal"]
# Out:
# (146, 18)

# %%
all_samples[all_samples['participant_id'] =="AB053"]
# Out:
#        entity:sample_id participant_id  \
# 0  AB053-Tumor-SM-DNUMO          AB053
# 5  AB053-Tumor-SM-E7S1O          AB053
# 6  AB053-Tumor-SM-E7S1C          AB053
# 1  AB053-Tumor-SM-F29RR          AB053
#
#                               clean_bam_file_capture external_id_validation  \
# 0  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...         AB053T_OPAC_p4
# 5  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...         AB053T_5050_p8
# 6  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...        AB053T_CM_p8_2D
# 1  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...      AB053T_OPAC_p8_2D
#
#     aggregation_product_name_validation bsp_sample_id_validation  \
# 0  TSCA Rapid Cancer Detection Panel v2                 SM-DOEKQ
# 5  TSCA Rapid Cancer Detection Panel v2                 SM-E7S1O
# 6  TSCA Rapid Cancer Detection Panel v2                 SM-E7S1C
# 1  TSCA Rapid Cancer Detection Panel v2                 SM-F29RR
#
#   stock_sample_id_validation sample_type picard_aggregation_type_validation  \
# 0                   SM-DNUMO       Tumor                                PCR
# 5                   SM-E77BC       Tumor                                PCR
# 6                   SM-E77B1       Tumor                                PCR
# 1                   SM-F21NR       Tumor                                PCR
#
#   processed_subtype_validation source_subtype_validation  \
# 0          Cells:Pellet frozen       Tissue:Fresh Tissue
# 5              DNA:DNA Somatic       Tissue:Fresh Tissue
# 6              DNA:DNA Somatic       Tissue:Fresh Tissue
# 1              DNA:DNA Somatic   Cells:Cell Line, Viable
#
#   squid_sample_id_validation tumor_subtype short_letter_code  \
# 0             AB053T_OPAC_p4       Primary                TP
# 5             AB053T_5050_p8       Primary                TP
# 6            AB053T_CM_p8_2D       Primary                TP
# 1          AB053T_OPAC_p8_2D       Primary                TP
#
#                                         bam_filename  \
# 0  2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# 5  2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# 6  2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# 1  2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                                         bai_filename  \
# 0  2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# 5  2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# 6  2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# 1  2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                               clean_bai_file_capture tsca_id
# 0  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# 5  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# 6  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# 1  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA19

# %%
# all_samples.groupby('participant_id').size().unstack()

# %%
mi_all_samples = all_samples.set_index(['participant_id'])

# %%
mi_all_samples[mi_all_samples.index=="AB053"]
# Out:
#                     entity:sample_id  \
# participant_id
# AB053           AB053-Tumor-SM-DNUMO
# AB053           AB053-Tumor-SM-E7S1O
# AB053           AB053-Tumor-SM-E7S1C
# AB053           AB053-Tumor-SM-F29RR
#
#                                            clean_bam_file_capture  \
# participant_id
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
#
#                external_id_validation   aggregation_product_name_validation  \
# participant_id
# AB053                  AB053T_OPAC_p4  TSCA Rapid Cancer Detection Panel v2
# AB053                  AB053T_5050_p8  TSCA Rapid Cancer Detection Panel v2
# AB053                 AB053T_CM_p8_2D  TSCA Rapid Cancer Detection Panel v2
# AB053               AB053T_OPAC_p8_2D  TSCA Rapid Cancer Detection Panel v2
#
#                bsp_sample_id_validation stock_sample_id_validation  \
# participant_id
# AB053                          SM-DOEKQ                   SM-DNUMO
# AB053                          SM-E7S1O                   SM-E77BC
# AB053                          SM-E7S1C                   SM-E77B1
# AB053                          SM-F29RR                   SM-F21NR
#
#                sample_type picard_aggregation_type_validation  \
# participant_id
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
#
#                processed_subtype_validation source_subtype_validation  \
# participant_id
# AB053                   Cells:Pellet frozen       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic   Cells:Cell Line, Viable
#
#                squid_sample_id_validation tumor_subtype short_letter_code  \
# participant_id
# AB053                      AB053T_OPAC_p4       Primary                TP
# AB053                      AB053T_5050_p8       Primary                TP
# AB053                     AB053T_CM_p8_2D       Primary                TP
# AB053                   AB053T_OPAC_p8_2D       Primary                TP
#
#                                                      bam_filename  \
# participant_id
# AB053           2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# AB053           2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# AB053           2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# AB053           2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                                                      bai_filename  \
# participant_id
# AB053           2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# AB053           2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# AB053           2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# AB053           2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                                            clean_bai_file_capture tsca_id
# participant_id
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA19

# %%
mi_all_samples.loc["AB053"]
# Out:
#                     entity:sample_id  \
# participant_id
# AB053           AB053-Tumor-SM-DNUMO
# AB053           AB053-Tumor-SM-E7S1O
# AB053           AB053-Tumor-SM-E7S1C
# AB053           AB053-Tumor-SM-F29RR
#
#                                            clean_bam_file_capture  \
# participant_id
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...
#
#                external_id_validation   aggregation_product_name_validation  \
# participant_id
# AB053                  AB053T_OPAC_p4  TSCA Rapid Cancer Detection Panel v2
# AB053                  AB053T_5050_p8  TSCA Rapid Cancer Detection Panel v2
# AB053                 AB053T_CM_p8_2D  TSCA Rapid Cancer Detection Panel v2
# AB053               AB053T_OPAC_p8_2D  TSCA Rapid Cancer Detection Panel v2
#
#                bsp_sample_id_validation stock_sample_id_validation  \
# participant_id
# AB053                          SM-DOEKQ                   SM-DNUMO
# AB053                          SM-E7S1O                   SM-E77BC
# AB053                          SM-E7S1C                   SM-E77B1
# AB053                          SM-F29RR                   SM-F21NR
#
#                sample_type picard_aggregation_type_validation  \
# participant_id
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
# AB053                Tumor                                PCR
#
#                processed_subtype_validation source_subtype_validation  \
# participant_id
# AB053                   Cells:Pellet frozen       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic       Tissue:Fresh Tissue
# AB053                       DNA:DNA Somatic   Cells:Cell Line, Viable
#
#                squid_sample_id_validation tumor_subtype short_letter_code  \
# participant_id
# AB053                      AB053T_OPAC_p4       Primary                TP
# AB053                      AB053T_5050_p8       Primary                TP
# AB053                     AB053T_CM_p8_2D       Primary                TP
# AB053                   AB053T_OPAC_p8_2D       Primary                TP
#
#                                                      bam_filename  \
# participant_id
# AB053           2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# AB053           2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# AB053           2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# AB053           2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                                                      bai_filename  \
# participant_id
# AB053           2_AB053T_OPAC_p4_H5TTJBCXY.2.aligned.duplicate...
# AB053           2_AB053T_5050_p8_H57WVBCXY.2.aligned.duplicate...
# AB053           2_AB053T_CM_p8_2D_H57WVBCXY.2.aligned.duplicat...
# AB053           2_AB053T_OPAC_p8_2D_HKWLGBCXY.2.aligned.duplic...
#
#                                            clean_bai_file_capture tsca_id
# participant_id
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA16
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA17
# AB053           gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA19

# %%
# all_samples.head(2)
# Out:
#        entity:sample_id participant_id  \
# 0  AA33-Normal-SM-D4L4D           AA33
# 1   AA34-Tumor-SM-D4L25           AA34
#
#                               clean_bam_file_capture external_id_validation  \
# 0  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...            AA33N_3D_p5
# 1  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...            AA34T_3D_p4
#
#     aggregation_product_name_validation bsp_sample_id_validation  \
# 0  TSCA Rapid Cancer Detection Panel v2                 SM-D59KF
# 1  TSCA Rapid Cancer Detection Panel v2                 SM-D59I2
#
#   stock_sample_id_validation sample_type picard_aggregation_type_validation  \
# 0                   SM-D4L4D      Normal                                PCR
# 1                   SM-D4L25       Tumor                                PCR
#
#   processed_subtype_validation source_subtype_validation  \
# 0          Cells:Pellet frozen       Tissue:Fresh Tissue
# 1          Cells:Pellet frozen       Tissue:Fresh Tissue
#
#   squid_sample_id_validation tumor_subtype short_letter_code  \
# 0                AA33N_3D_p5           NaN              NDNA
# 1                AA34T_3D_p4    Metastatic                TM
#
#                                         bam_filename  \
# 0  1_AA33N_3D_p5_HVLVWBCXX.1.aligned.duplicates_m...
# 1  1_AA34T_3D_p4_HVLVWBCXX.1.aligned.duplicates_m...
#
#                                         bai_filename  \
# 0  1_AA33N_3D_p5_HVLVWBCXX.1.aligned.duplicates_m...
# 1  1_AA34T_3D_p4_HVLVWBCXX.1.aligned.duplicates_m...
#
#                               clean_bai_file_capture   tsca_id
# 0  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA1213
# 1  gs://fc-35446f22-ea37-483a-bd6c-5e9fc56851ff/s...  TSCA1213

# %%
tumor_samples = all_samples[all_samples.sample_type=="Tumor"]

# %%
dfs = []

# %%
for index, row in tumor_samples.iterrows():
    # Find all samples from same individual (same individual_id, different sample_id)
    patient_samples = all_samples[ (all_samples['participant_id'] == row['participant_id']) \
                                      & (all_samples['entity:sample_id'] != row['entity:sample_id']) ]
    
    # NOTE: If more than one match tumor tissue or match normal found, select one at random.
    # The match normal is used to compute allelic fractions in Mutect2, so for now we ignore the conditions it was grown in.
    
    # Match normal: Add match normal
    match_normal = patient_samples[ patient_samples['sample_type'] == "Normal"]
    #   > No match normal found
    if match_normal.empty: 
        continue
    #   > Match normal found
    elif match_normal.shape[0] > 0:
        match_normal = match_normal.sample(n=1)
    
    # Create DF with pair set
    control_sample_id = match_normal['entity:sample_id'].item()
    pair_id = "%s$%s" % (row['entity:sample_id'], control_sample_id)
    control_sample_id = match_normal['entity:sample_id'].item()
    df_dict = {'entity:pair_id': pair_id, 'case_sample_id': row['entity:sample_id'], \
                'control_sample_id': control_sample_id, \
                'particpant_id': row['participant_id']}
    
    print(df_dict)
    df = pd.DataFrame().from_dict(df_)
#     dfs.append(df)
# Out:
# {'entity:pair_id': 'EH014-Tumor-SM-D4L26$EH014-Normal-SM-D4L35', 'case_sample_id': 'EH014-Tumor-SM-D4L26', 'control_sample_id': 'EH014-Normal-SM-D4L35', 'particpant_id': 'EH014'}
# {'entity:pair_id': 'EH014-Tumor-SM-D4L1T$EH014-Normal-SM-D4L35', 'case_sample_id': 'EH014-Tumor-SM-D4L1T', 'control_sample_id': 'EH014-Normal-SM-D4L35', 'particpant_id': 'EH014'}
# {'entity:pair_id': 'EH014-Tumor-SM-D4L2W$EH014-Normal-SM-D4L46', 'case_sample_id': 'EH014-Tumor-SM-D4L2W', 'control_sample_id': 'EH014-Normal-SM-D4L46', 'particpant_id': 'EH014'}
# {'entity:pair_id': 'EH015-Tumor-SM-D4L1Z$EH015-Normal-SM-D4L2J', 'case_sample_id': 'EH015-Tumor-SM-D4L1Z', 'control_sample_id': 'EH015-Normal-SM-D4L2J', 'particpant_id': 'EH015'}
# {'entity:pair_id': 'EH015-Tumor-SM-D4L2X$EH015-Normal-SM-D4L38', 'case_sample_id': 'EH015-Tumor-SM-D4L2X', 'control_sample_id': 'EH015-Normal-SM-D4L38', 'particpant_id': 'EH015'}
# {'entity:pair_id': 'EH015-Tumor-SM-D4L3A$EH015-Normal-SM-D4L38', 'case_sample_id': 'EH015-Tumor-SM-D4L3A', 'control_sample_id': 'EH015-Normal-SM-D4L38', 'particpant_id': 'EH015'}
# {'entity:pair_id': 'EH015-Tumor-SM-D4L2B$EH015-Normal-SM-D4L2J', 'case_sample_id': 'EH015-Tumor-SM-D4L2B', 'control_sample_id': 'EH015-Normal-SM-D4L2J', 'particpant_id': 'EH015'}
# {'entity:pair_id': 'JL54-Tumor-SM-D4L2D$JL54-Normal-SM-D4L3X', 'case_sample_id': 'JL54-Tumor-SM-D4L2D', 'control_sample_id': 'JL54-Normal-SM-D4L3X', 'particpant_id': 'JL54'}
# {'entity:pair_id': 'JL58-Tumor-SM-D4L32$JL58-Normal-SM-DB2JJ', 'case_sample_id': 'JL58-Tumor-SM-D4L32', 'control_sample_id': 'JL58-Normal-SM-DB2JJ', 'particpant_id': 'JL58'}
# {'entity:pair_id': 'PEDS153-Tumor-SM-D4L39$PEDS153-Normal-SM-D4L1X', 'case_sample_id': 'PEDS153-Tumor-SM-D4L39', 'control_sample_id': 'PEDS153-Normal-SM-D4L1X', 'particpant_id': 'PEDS153'}
# {'entity:pair_id': 'PEDS153-Tumor-SM-D4L3G$PEDS153-Normal-SM-DB2IU', 'case_sample_id': 'PEDS153-Tumor-SM-D4L3G', 'control_sample_id': 'PEDS153-Normal-SM-DB2IU', 'particpant_id': 'PEDS153'}
# {'entity:pair_id': 'PEDS165-Tumor-SM-D4L2U$PEDS165-Normal-SM-D4L3J', 'case_sample_id': 'PEDS165-Tumor-SM-D4L2U', 'control_sample_id': 'PEDS165-Normal-SM-D4L3J', 'particpant_id': 'PEDS165'}
# {'entity:pair_id': 'PEDS165-Tumor-SM-D4L29$PEDS165-Normal-SM-D4L3J', 'case_sample_id': 'PEDS165-Tumor-SM-D4L29', 'control_sample_id': 'PEDS165-Normal-SM-D4L3J', 'particpant_id': 'PEDS165'}
# {'entity:pair_id': 'PEDS165-Tumor-SM-D4L1U$PEDS165-Normal-SM-D4L3J', 'case_sample_id': 'PEDS165-Tumor-SM-D4L1U', 'control_sample_id': 'PEDS165-Normal-SM-D4L3J', 'particpant_id': 'PEDS165'}
# {'entity:pair_id': 'PEDS165-Tumor-SM-D4L43$PEDS165-Normal-SM-D4L3J', 'case_sample_id': 'PEDS165-Tumor-SM-D4L43', 'control_sample_id': 'PEDS165-Normal-SM-D4L3J', 'particpant_id': 'PEDS165'}
# {'entity:pair_id': 'PEDS166-Tumor-SM-D4L2O$PEDS166-Normal-SM-DB2I5', 'case_sample_id': 'PEDS166-Tumor-SM-D4L2O', 'control_sample_id': 'PEDS166-Normal-SM-DB2I5', 'particpant_id': 'PEDS166'}
# {'entity:pair_id': 'PEDS167-Tumor-SM-D4L31$PEDS167-Normal-SM-D4L3M', 'case_sample_id': 'PEDS167-Tumor-SM-D4L31', 'control_sample_id': 'PEDS167-Normal-SM-D4L3M', 'particpant_id': 'PEDS167'}
# {'entity:pair_id': 'PEDS168-Tumor-SM-D4L2K$PEDS168-Normal-SM-D4L28', 'case_sample_id': 'PEDS168-Tumor-SM-D4L2K', 'control_sample_id': 'PEDS168-Normal-SM-D4L28', 'particpant_id': 'PEDS168'}
# {'entity:pair_id': 'PEDS176-Tumor-SM-D4L2T$PEDS176-Normal-SM-DNUN3', 'case_sample_id': 'PEDS176-Tumor-SM-D4L2T', 'control_sample_id': 'PEDS176-Normal-SM-DNUN3', 'particpant_id': 'PEDS176'}
# {'entity:pair_id': 'PEDS185-Tumor-SM-D4L2N$PEDS185-Normal-SM-D4L2Y', 'case_sample_id': 'PEDS185-Tumor-SM-D4L2N', 'control_sample_id': 'PEDS185-Normal-SM-D4L2Y', 'particpant_id': 'PEDS185'}
# {'entity:pair_id': 'PEDS187-Tumor-SM-D4L22$PEDS187-Normal-SM-E7S1S', 'case_sample_id': 'PEDS187-Tumor-SM-D4L22', 'control_sample_id': 'PEDS187-Normal-SM-E7S1S', 'particpant_id': 'PEDS187'}
# {'entity:pair_id': 'AB056-Tumor-SM-DB2JY$AB056-Normal-SM-DB2JM', 'case_sample_id': 'AB056-Tumor-SM-DB2JY', 'control_sample_id': 'AB056-Normal-SM-DB2JM', 'particpant_id': 'AB056'}
# {'entity:pair_id': 'EH019-Tumor-SM-DB3RA$EH019-Normal-SM-DHZ8I', 'case_sample_id': 'EH019-Tumor-SM-DB3RA', 'control_sample_id': 'EH019-Normal-SM-DHZ8I', 'particpant_id': 'EH019'}
# {'entity:pair_id': 'EH020-Tumor-SM-DB3R4$EH020-Normal-SM-DHZ8U', 'case_sample_id': 'EH020-Tumor-SM-DB3R4', 'control_sample_id': 'EH020-Normal-SM-DHZ8U', 'particpant_id': 'EH020'}
# {'entity:pair_id': 'JL57-Tumor-SM-DB2K7$JL57-Normal-SM-DNULJ', 'case_sample_id': 'JL57-Tumor-SM-DB2K7', 'control_sample_id': 'JL57-Normal-SM-DNULJ', 'particpant_id': 'JL57'}
# {'entity:pair_id': 'JL58-Tumor-SM-DB2J7$JL58-Normal-SM-D4L4B', 'case_sample_id': 'JL58-Tumor-SM-DB2J7', 'control_sample_id': 'JL58-Normal-SM-D4L4B', 'particpant_id': 'JL58'}
# {'entity:pair_id': 'JL58-Tumor-SM-DB2K8$JL58-Normal-SM-DNUN8', 'case_sample_id': 'JL58-Tumor-SM-DB2K8', 'control_sample_id': 'JL58-Normal-SM-DNUN8', 'particpant_id': 'JL58'}
# {'entity:pair_id': 'JL61-Tumor-SM-DB2IT$JL61-Normal-SM-DB2JI', 'case_sample_id': 'JL61-Tumor-SM-DB2IT', 'control_sample_id': 'JL61-Normal-SM-DB2JI', 'particpant_id': 'JL61'}
# {'entity:pair_id': 'PEDS157-Tumor-SM-DB2II$PEDS157-Normal-SM-DB2I6', 'case_sample_id': 'PEDS157-Tumor-SM-DB2II', 'control_sample_id': 'PEDS157-Normal-SM-DB2I6', 'particpant_id': 'PEDS157'}
# {'entity:pair_id': 'PEDS157-Tumor-SM-DB2HV$PEDS157-Normal-SM-DB2I6', 'case_sample_id': 'PEDS157-Tumor-SM-DB2HV', 'control_sample_id': 'PEDS157-Normal-SM-DB2I6', 'particpant_id': 'PEDS157'}
# {'entity:pair_id': 'PEDS167-Tumor-SM-DB2IE$PEDS167-Normal-SM-D4L3M', 'case_sample_id': 'PEDS167-Tumor-SM-DB2IE', 'control_sample_id': 'PEDS167-Normal-SM-D4L3M', 'particpant_id': 'PEDS167'}
# {'entity:pair_id': 'PEDS167-Tumor-SM-DB2KF$PEDS167-Normal-SM-D4L3M', 'case_sample_id': 'PEDS167-Tumor-SM-DB2KF', 'control_sample_id': 'PEDS167-Normal-SM-D4L3M', 'particpant_id': 'PEDS167'}
# {'entity:pair_id': 'PEDS175-Tumor-SM-DB2JN$PEDS175-Normal-SM-DB2IZ', 'case_sample_id': 'PEDS175-Tumor-SM-DB2JN', 'control_sample_id': 'PEDS175-Normal-SM-DB2IZ', 'particpant_id': 'PEDS175'}
# {'entity:pair_id': 'PEDS176-Tumor-SM-DB3R9$PEDS176-Normal-SM-DB2J8', 'case_sample_id': 'PEDS176-Tumor-SM-DB3R9', 'control_sample_id': 'PEDS176-Normal-SM-DB2J8', 'particpant_id': 'PEDS176'}
# {'entity:pair_id': 'PEDS176-Tumor-SM-DB2JX$PEDS176-Normal-SM-D4L2I', 'case_sample_id': 'PEDS176-Tumor-SM-DB2JX', 'control_sample_id': 'PEDS176-Normal-SM-D4L2I', 'particpant_id': 'PEDS176'}
# {'entity:pair_id': 'PEDS176-Tumor-SM-DB2I7$PEDS176-Normal-SM-DNUN3', 'case_sample_id': 'PEDS176-Tumor-SM-DB2I7', 'control_sample_id': 'PEDS176-Normal-SM-DNUN3', 'particpant_id': 'PEDS176'}
# {'entity:pair_id': 'PEDS191-Tumor-SM-DB2KD$PEDS191-Normal-SM-E7S25', 'case_sample_id': 'PEDS191-Tumor-SM-DB2KD', 'control_sample_id': 'PEDS191-Normal-SM-E7S25', 'particpant_id': 'PEDS191'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-DB2HW$PEDS194-Normal-SM-DB2IW', 'case_sample_id': 'PEDS194-Tumor-SM-DB2HW', 'control_sample_id': 'PEDS194-Normal-SM-DB2IW', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS199-Tumor-SM-DB2JW$PEDS199-Normal-SM-DB2K9', 'case_sample_id': 'PEDS199-Tumor-SM-DB2JW', 'control_sample_id': 'PEDS199-Normal-SM-DB2K9', 'particpant_id': 'PEDS199'}
# {'entity:pair_id': 'AA33-Tumor-SM-DHZ9X$AA33-Normal-SM-DHZ9L', 'case_sample_id': 'AA33-Tumor-SM-DHZ9X', 'control_sample_id': 'AA33-Normal-SM-DHZ9L', 'particpant_id': 'AA33'}
# {'entity:pair_id': 'EH014-Tumor-SM-DHZ54$EH014-Normal-SM-D4L46', 'case_sample_id': 'EH014-Tumor-SM-DHZ54', 'control_sample_id': 'EH014-Normal-SM-D4L46', 'particpant_id': 'EH014'}
# {'entity:pair_id': 'EH019-Tumor-SM-DHZ9T$EH019-Normal-SM-DB2J3', 'case_sample_id': 'EH019-Tumor-SM-DHZ9T', 'control_sample_id': 'EH019-Normal-SM-DB2J3', 'particpant_id': 'EH019'}
# {'entity:pair_id': 'EH019-Tumor-SM-DHZ7S$EH019-Normal-SM-DHZ8I', 'case_sample_id': 'EH019-Tumor-SM-DHZ7S', 'control_sample_id': 'EH019-Normal-SM-DHZ8I', 'particpant_id': 'EH019'}
# {'entity:pair_id': 'EH019-Tumor-SM-DHZA6$EH019-Normal-SM-DB2J3', 'case_sample_id': 'EH019-Tumor-SM-DHZA6', 'control_sample_id': 'EH019-Normal-SM-DB2J3', 'particpant_id': 'EH019'}
# {'entity:pair_id': 'EH020-Tumor-SM-DHZ85$EH020-Normal-SM-DHZ8U', 'case_sample_id': 'EH020-Tumor-SM-DHZ85', 'control_sample_id': 'EH020-Normal-SM-DHZ8U', 'particpant_id': 'EH020'}
# {'entity:pair_id': 'EH020-Tumor-SM-DHZ8H$EH020-Normal-SM-DHZ8U', 'case_sample_id': 'EH020-Tumor-SM-DHZ8H', 'control_sample_id': 'EH020-Normal-SM-DHZ8U', 'particpant_id': 'EH020'}
# {'entity:pair_id': 'EH020-Tumor-SM-DHZ8T$EH020-Normal-SM-DB2IQ', 'case_sample_id': 'EH020-Tumor-SM-DHZ8T', 'control_sample_id': 'EH020-Normal-SM-DB2IQ', 'particpant_id': 'EH020'}
# {'entity:pair_id': 'EH021-Tumor-SM-DHZ9I$EH021-Normal-SM-DHZ9J', 'case_sample_id': 'EH021-Tumor-SM-DHZ9I', 'control_sample_id': 'EH021-Normal-SM-DHZ9J', 'particpant_id': 'EH021'}
# {'entity:pair_id': 'EH021-Tumor-SM-DHZ9U$EH021-Normal-SM-DHZ9J', 'case_sample_id': 'EH021-Tumor-SM-DHZ9U', 'control_sample_id': 'EH021-Normal-SM-DHZ9J', 'particpant_id': 'EH021'}
# {'entity:pair_id': 'EH021-Tumor-SM-DHZ96$EH021-Normal-SM-DHZ4X', 'case_sample_id': 'EH021-Tumor-SM-DHZ96', 'control_sample_id': 'EH021-Normal-SM-DHZ4X', 'particpant_id': 'EH021'}
# {'entity:pair_id': 'EH021-Tumor-SM-DHZ6Y$EH021-Normal-SM-DHZ9J', 'case_sample_id': 'EH021-Tumor-SM-DHZ6Y', 'control_sample_id': 'EH021-Normal-SM-DHZ9J', 'particpant_id': 'EH021'}
# {'entity:pair_id': 'EH022-Tumor-SM-DHZA7$EH022-Normal-SM-DHZ6N', 'case_sample_id': 'EH022-Tumor-SM-DHZA7', 'control_sample_id': 'EH022-Normal-SM-DHZ6N', 'particpant_id': 'EH022'}
# {'entity:pair_id': 'EH022-Tumor-SM-DHZ5O$EH022-Normal-SM-DHZ97', 'case_sample_id': 'EH022-Tumor-SM-DHZ5O', 'control_sample_id': 'EH022-Normal-SM-DHZ97', 'particpant_id': 'EH022'}
# {'entity:pair_id': 'GG001-Tumor-SM-DHZ89$GG001-Normal-SM-DHZ8L', 'case_sample_id': 'GG001-Tumor-SM-DHZ89', 'control_sample_id': 'GG001-Normal-SM-DHZ8L', 'particpant_id': 'GG001'}
# {'entity:pair_id': 'GG004-Tumor-SM-DHZ9M$GG004-Normal-SM-DHZ9Y', 'case_sample_id': 'GG004-Tumor-SM-DHZ9M', 'control_sample_id': 'GG004-Normal-SM-DHZ9Y', 'particpant_id': 'GG004'}
# {'entity:pair_id': 'JL62-Tumor-SM-DHZ6X$JL62-Normal-SM-DHZ6L', 'case_sample_id': 'JL62-Tumor-SM-DHZ6X', 'control_sample_id': 'JL62-Normal-SM-DHZ6L', 'particpant_id': 'JL62'}
# {'entity:pair_id': 'CCLF_PEDS1002-Tumor-SM-DHZ5P$CCLF_PEDS1002-Normal-SM-DHZ7F', 'case_sample_id': 'CCLF_PEDS1002-Tumor-SM-DHZ5P', 'control_sample_id': 'CCLF_PEDS1002-Normal-SM-DHZ7F', 'particpant_id': 'CCLF_PEDS1002'}
# {'entity:pair_id': 'CCLF_PEDS1005-Tumor-SM-DHZ6I$CCLF_PEDS1005-Normal-SM-EUVG6', 'case_sample_id': 'CCLF_PEDS1005-Tumor-SM-DHZ6I', 'control_sample_id': 'CCLF_PEDS1005-Normal-SM-EUVG6', 'particpant_id': 'CCLF_PEDS1005'}
# {'entity:pair_id': 'PEDS167-Tumor-SM-DHZA3$PEDS167-Normal-SM-D4L3M', 'case_sample_id': 'PEDS167-Tumor-SM-DHZA3', 'control_sample_id': 'PEDS167-Normal-SM-D4L3M', 'particpant_id': 'PEDS167'}
# {'entity:pair_id': 'PEDS179-Tumor-SM-DHZ91$PEDS179-Normal-SM-DHZ8Z', 'case_sample_id': 'PEDS179-Tumor-SM-DHZ91', 'control_sample_id': 'PEDS179-Normal-SM-DHZ8Z', 'particpant_id': 'PEDS179'}
# {'entity:pair_id': 'PEDS179-Tumor-SM-DHZA8$PEDS179-Normal-SM-DHZ8Z', 'case_sample_id': 'PEDS179-Tumor-SM-DHZA8', 'control_sample_id': 'PEDS179-Normal-SM-DHZ8Z', 'particpant_id': 'PEDS179'}
# {'entity:pair_id': 'PEDS182-Tumor-SM-DHZ9C$PEDS182-Normal-SM-DHZA1', 'case_sample_id': 'PEDS182-Tumor-SM-DHZ9C', 'control_sample_id': 'PEDS182-Normal-SM-DHZA1', 'particpant_id': 'PEDS182'}
# {'entity:pair_id': 'PEDS182-Tumor-SM-DHZ8C$PEDS182-Normal-SM-DHZA1', 'case_sample_id': 'PEDS182-Tumor-SM-DHZ8C', 'control_sample_id': 'PEDS182-Normal-SM-DHZA1', 'particpant_id': 'PEDS182'}
# {'entity:pair_id': 'PEDS182-Tumor-SM-DHZ9D$PEDS182-Normal-SM-DHZ8O', 'case_sample_id': 'PEDS182-Tumor-SM-DHZ9D', 'control_sample_id': 'PEDS182-Normal-SM-DHZ8O', 'particpant_id': 'PEDS182'}
# {'entity:pair_id': 'PEDS182-Tumor-SM-DHZ8V$PEDS182-Normal-SM-DHZ8O', 'case_sample_id': 'PEDS182-Tumor-SM-DHZ8V', 'control_sample_id': 'PEDS182-Normal-SM-DHZ8O', 'particpant_id': 'PEDS182'}
# {'entity:pair_id': 'PEDS182-Tumor-SM-DHZA5$PEDS182-Normal-SM-DHZ8O', 'case_sample_id': 'PEDS182-Tumor-SM-DHZA5', 'control_sample_id': 'PEDS182-Normal-SM-DHZ8O', 'particpant_id': 'PEDS182'}
# {'entity:pair_id': 'PEDS187-Tumor-SM-DHZ87$PEDS187-Normal-SM-E7S1S', 'case_sample_id': 'PEDS187-Tumor-SM-DHZ87', 'control_sample_id': 'PEDS187-Normal-SM-E7S1S', 'particpant_id': 'PEDS187'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-DHZA4$PEDS194-Normal-SM-DHZ8P', 'case_sample_id': 'PEDS194-Tumor-SM-DHZA4', 'control_sample_id': 'PEDS194-Normal-SM-DHZ8P', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-DHZ8Q$PEDS194-Normal-SM-DHZ7O', 'case_sample_id': 'PEDS194-Tumor-SM-DHZ8Q', 'control_sample_id': 'PEDS194-Normal-SM-DHZ7O', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-DHZ8F$PEDS194-Normal-SM-DHZ8D', 'case_sample_id': 'PEDS194-Tumor-SM-DHZ8F', 'control_sample_id': 'PEDS194-Normal-SM-DHZ8D', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS199-Tumor-SM-DHZ8R$PEDS199-Normal-SM-E7S1P', 'case_sample_id': 'PEDS199-Tumor-SM-DHZ8R', 'control_sample_id': 'PEDS199-Normal-SM-E7S1P', 'particpant_id': 'PEDS199'}
# {'entity:pair_id': 'PEDS199-Tumor-SM-DHZ8E$PEDS199-Normal-SM-DNULP', 'case_sample_id': 'PEDS199-Tumor-SM-DHZ8E', 'control_sample_id': 'PEDS199-Normal-SM-DNULP', 'particpant_id': 'PEDS199'}
# {'entity:pair_id': 'PEDS199-Tumor-SM-DHZ8J$PEDS199-Normal-SM-DNULP', 'case_sample_id': 'PEDS199-Tumor-SM-DHZ8J', 'control_sample_id': 'PEDS199-Normal-SM-DNULP', 'particpant_id': 'PEDS199'}
# {'entity:pair_id': 'PEDS200-Tumor-SM-DHZ7M$PEDS200-Normal-SM-DHZ9Z', 'case_sample_id': 'PEDS200-Tumor-SM-DHZ7M', 'control_sample_id': 'PEDS200-Normal-SM-DHZ9Z', 'particpant_id': 'PEDS200'}
# {'entity:pair_id': 'PEDS203-Tumor-SM-DHZ8N$PEDS203-Normal-SM-DHZ8B', 'case_sample_id': 'PEDS203-Tumor-SM-DHZ8N', 'control_sample_id': 'PEDS203-Normal-SM-DHZ8B', 'particpant_id': 'PEDS203'}
# {'entity:pair_id': 'PEDS206-Tumor-SM-DHZ58$PEDS206-Normal-SM-DHZ4V', 'case_sample_id': 'PEDS206-Tumor-SM-DHZ58', 'control_sample_id': 'PEDS206-Normal-SM-DHZ4V', 'particpant_id': 'PEDS206'}
# {'entity:pair_id': 'PEDS207-Tumor-SM-DHZ6O$PEDS207-Normal-SM-DHZ6C', 'case_sample_id': 'PEDS207-Tumor-SM-DHZ6O', 'control_sample_id': 'PEDS207-Normal-SM-DHZ6C', 'particpant_id': 'PEDS207'}
# {'entity:pair_id': 'PEDS209-Tumor-SM-DHZ51$PEDS209-Normal-SM-DHZ7E', 'case_sample_id': 'PEDS209-Tumor-SM-DHZ51', 'control_sample_id': 'PEDS209-Normal-SM-DHZ7E', 'particpant_id': 'PEDS209'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DHZ5Y$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DHZ5Y', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'TC007-Tumor-SM-DHZ6T$TC007-Normal-SM-DHZ6S', 'case_sample_id': 'TC007-Tumor-SM-DHZ6T', 'control_sample_id': 'TC007-Normal-SM-DHZ6S', 'particpant_id': 'TC007'}
# {'entity:pair_id': 'CCLF_PEDS1007-Tumor-SM-DNULY$CCLF_PEDS1007-Normal-SM-E7S12', 'case_sample_id': 'CCLF_PEDS1007-Tumor-SM-DNULY', 'control_sample_id': 'CCLF_PEDS1007-Normal-SM-E7S12', 'particpant_id': 'CCLF_PEDS1007'}
# {'entity:pair_id': 'CCLF_PEDS1012-Tumor-SM-DNUN2$CCLF_PEDS1012-Normal-SM-EUVHI', 'case_sample_id': 'CCLF_PEDS1012-Tumor-SM-DNUN2', 'control_sample_id': 'CCLF_PEDS1012-Normal-SM-EUVHI', 'particpant_id': 'CCLF_PEDS1012'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DNULL$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DNULL', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DNUMY$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DNUMY', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DNUMA$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DNUMA', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DNUMM$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DNUMM', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'CCLF_RCRF004-Tumor-SM-DNULX$CCLF_RCRF004-Normal-SM-DHZ5M', 'case_sample_id': 'CCLF_RCRF004-Tumor-SM-DNULX', 'control_sample_id': 'CCLF_RCRF004-Normal-SM-DHZ5M', 'particpant_id': 'CCLF_RCRF004'}
# {'entity:pair_id': 'CCLF_RCRF1005-Tumor-SM-DNUNL$CCLF_RCRF1005-Normal-SM-DNUL8', 'case_sample_id': 'CCLF_RCRF1005-Tumor-SM-DNUNL', 'control_sample_id': 'CCLF_RCRF1005-Normal-SM-DNUL8', 'particpant_id': 'CCLF_RCRF1005'}
# {'entity:pair_id': 'CCLF_SS1002-Tumor-SM-DNUNC$CCLF_SS1002-Normal-SM-DNUMI', 'case_sample_id': 'CCLF_SS1002-Tumor-SM-DNUNC', 'control_sample_id': 'CCLF_SS1002-Normal-SM-DNUMI', 'particpant_id': 'CCLF_SS1002'}
# {'entity:pair_id': 'CCLF_SS1003-Tumor-SM-DNUNO$CCLF_SS1003-Normal-SM-E7S2A', 'case_sample_id': 'CCLF_SS1003-Tumor-SM-DNUNO', 'control_sample_id': 'CCLF_SS1003-Normal-SM-E7S2A', 'particpant_id': 'CCLF_SS1003'}
# {'entity:pair_id': 'CCLF_SS1004-Tumor-SM-DNUN6$CCLF_SS1004-Normal-SM-DNUMG', 'case_sample_id': 'CCLF_SS1004-Tumor-SM-DNUN6', 'control_sample_id': 'CCLF_SS1004-Normal-SM-DNUMG', 'particpant_id': 'CCLF_SS1004'}
# {'entity:pair_id': 'CCLF_SS1005-Tumor-SM-DO7N1$CCLF_SS1005-Normal-SM-E7S1G', 'case_sample_id': 'CCLF_SS1005-Tumor-SM-DO7N1', 'control_sample_id': 'CCLF_SS1005-Normal-SM-E7S1G', 'particpant_id': 'CCLF_SS1005'}
# {'entity:pair_id': 'JL61-Tumor-SM-DNULD$JL61-Normal-SM-DNUNK', 'case_sample_id': 'JL61-Tumor-SM-DNULD', 'control_sample_id': 'JL61-Normal-SM-DNUNK', 'particpant_id': 'JL61'}
# {'entity:pair_id': 'JL61-Tumor-SM-DNUL2$JL61-Normal-SM-DB2JI', 'case_sample_id': 'JL61-Tumor-SM-DNUL2', 'control_sample_id': 'JL61-Normal-SM-DB2JI', 'particpant_id': 'JL61'}
# {'entity:pair_id': 'PEDS171-Tumor-SM-DNULI$PEDS171-Normal-SM-D4L3R', 'case_sample_id': 'PEDS171-Tumor-SM-DNULI', 'control_sample_id': 'PEDS171-Normal-SM-D4L3R', 'particpant_id': 'PEDS171'}
# {'entity:pair_id': 'PEDS171-Tumor-SM-DNUL6$PEDS171-Normal-SM-D4L1V', 'case_sample_id': 'PEDS171-Tumor-SM-DNUL6', 'control_sample_id': 'PEDS171-Normal-SM-D4L1V', 'particpant_id': 'PEDS171'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-DNUM2$PEDS194-Normal-SM-DHZ8P', 'case_sample_id': 'PEDS194-Tumor-SM-DNUM2', 'control_sample_id': 'PEDS194-Normal-SM-DHZ8P', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS196-Tumor-SM-DNUN5$PEDS196-Normal-SM-DNULT', 'case_sample_id': 'PEDS196-Tumor-SM-DNUN5', 'control_sample_id': 'PEDS196-Normal-SM-DNULT', 'particpant_id': 'PEDS196'}
# {'entity:pair_id': 'PEDS196-Tumor-SM-DNUN4$PEDS196-Normal-SM-DNULT', 'case_sample_id': 'PEDS196-Tumor-SM-DNUN4', 'control_sample_id': 'PEDS196-Normal-SM-DNULT', 'particpant_id': 'PEDS196'}
# {'entity:pair_id': 'PEDS200-Tumor-SM-DNUMU$PEDS200-Normal-SM-DNUME', 'case_sample_id': 'PEDS200-Tumor-SM-DNUMU', 'control_sample_id': 'PEDS200-Normal-SM-DNUME', 'particpant_id': 'PEDS200'}
# {'entity:pair_id': 'PEDS200-Tumor-SM-DNUMQ$PEDS200-Normal-SM-DNUME', 'case_sample_id': 'PEDS200-Tumor-SM-DNUMQ', 'control_sample_id': 'PEDS200-Normal-SM-DNUME', 'particpant_id': 'PEDS200'}
# {'entity:pair_id': 'PEDS204-Tumor-SM-DO3D5$PEDS204-Normal-SM-DNUMZ', 'case_sample_id': 'PEDS204-Tumor-SM-DO3D5', 'control_sample_id': 'PEDS204-Normal-SM-DNUMZ', 'particpant_id': 'PEDS204'}
# {'entity:pair_id': 'PEDS209-Tumor-SM-DNULE$PEDS209-Normal-SM-DHZ7E', 'case_sample_id': 'PEDS209-Tumor-SM-DNULE', 'control_sample_id': 'PEDS209-Normal-SM-DHZ7E', 'particpant_id': 'PEDS209'}
# {'entity:pair_id': 'PEDS209-Tumor-SM-DNULQ$PEDS209-Normal-SM-E7S1H', 'case_sample_id': 'PEDS209-Tumor-SM-DNULQ', 'control_sample_id': 'PEDS209-Normal-SM-E7S1H', 'particpant_id': 'PEDS209'}
# {'entity:pair_id': 'PEDS209-Tumor-SM-DNULA$PEDS209-Normal-SM-DHZ7E', 'case_sample_id': 'PEDS209-Tumor-SM-DNULA', 'control_sample_id': 'PEDS209-Normal-SM-DHZ7E', 'particpant_id': 'PEDS209'}
# {'entity:pair_id': 'PEDS211-Tumor-SM-DNUM5$PEDS211-Normal-SM-E7S1T', 'case_sample_id': 'PEDS211-Tumor-SM-DNUM5', 'control_sample_id': 'PEDS211-Normal-SM-E7S1T', 'particpant_id': 'PEDS211'}
# {'entity:pair_id': 'PEDS211-Tumor-SM-DO3CZ$PEDS211-Normal-SM-E7S1T', 'case_sample_id': 'PEDS211-Tumor-SM-DO3CZ', 'control_sample_id': 'PEDS211-Normal-SM-E7S1T', 'particpant_id': 'PEDS211'}
# {'entity:pair_id': 'CCLF_JL1001-Tumor-SM-E7RZ7$CCLF_JL1001-Normal-SM-E7S2K', 'case_sample_id': 'CCLF_JL1001-Tumor-SM-E7RZ7', 'control_sample_id': 'CCLF_JL1001-Normal-SM-E7S2K', 'particpant_id': 'CCLF_JL1001'}
# {'entity:pair_id': 'CCLF_PEDS1005-Tumor-SM-E7S1I$CCLF_PEDS1005-Normal-SM-EUVG6', 'case_sample_id': 'CCLF_PEDS1005-Tumor-SM-E7S1I', 'control_sample_id': 'CCLF_PEDS1005-Normal-SM-EUVG6', 'particpant_id': 'CCLF_PEDS1005'}
# {'entity:pair_id': 'CCLF_PEDS1008-Tumor-SM-E7S2F$CCLF_PEDS1008-Normal-SM-E7S1Q', 'case_sample_id': 'CCLF_PEDS1008-Tumor-SM-E7S2F', 'control_sample_id': 'CCLF_PEDS1008-Normal-SM-E7S1Q', 'particpant_id': 'CCLF_PEDS1008'}
# {'entity:pair_id': 'CCLF_PEDS1008-Tumor-SM-E7RZ2$CCLF_PEDS1008-Normal-SM-E7S1Q', 'case_sample_id': 'CCLF_PEDS1008-Tumor-SM-E7RZ2', 'control_sample_id': 'CCLF_PEDS1008-Normal-SM-E7S1Q', 'particpant_id': 'CCLF_PEDS1008'}
# {'entity:pair_id': 'CCLF_PEDS1011-Tumor-SM-E7RZQ$CCLF_PEDS1011-Normal-SM-E7RZE', 'case_sample_id': 'CCLF_PEDS1011-Tumor-SM-E7RZQ', 'control_sample_id': 'CCLF_PEDS1011-Normal-SM-E7RZE', 'particpant_id': 'CCLF_PEDS1011'}
# {'entity:pair_id': 'CCLF_PEDS1012-Tumor-SM-E7S13$CCLF_PEDS1012-Normal-SM-EUVHI', 'case_sample_id': 'CCLF_PEDS1012-Tumor-SM-E7S13', 'control_sample_id': 'CCLF_PEDS1012-Normal-SM-EUVHI', 'particpant_id': 'CCLF_PEDS1012'}
# {'entity:pair_id': 'CCLF_PEDS1012-Tumor-SM-E7S1F$CCLF_PEDS1012-Normal-SM-EUVHI', 'case_sample_id': 'CCLF_PEDS1012-Tumor-SM-E7S1F', 'control_sample_id': 'CCLF_PEDS1012-Normal-SM-EUVHI', 'particpant_id': 'CCLF_PEDS1012'}
# {'entity:pair_id': 'CCLF_PEDS1012-Tumor-SM-E7S1R$CCLF_PEDS1012-Normal-SM-EUVHI', 'case_sample_id': 'CCLF_PEDS1012-Tumor-SM-E7S1R', 'control_sample_id': 'CCLF_PEDS1012-Normal-SM-EUVHI', 'particpant_id': 'CCLF_PEDS1012'}
# {'entity:pair_id': 'CCLF_PEDS1019-Tumor-SM-E7S2G$CCLF_PEDS1019-Normal-SM-EUVGI', 'case_sample_id': 'CCLF_PEDS1019-Tumor-SM-E7S2G', 'control_sample_id': 'CCLF_PEDS1019-Normal-SM-EUVGI', 'particpant_id': 'CCLF_PEDS1019'}
# {'entity:pair_id': 'CCLF_PEDS1020-Tumor-SM-E7RZL$CCLF_PEDS1020-Normal-SM-E7RZ9', 'case_sample_id': 'CCLF_PEDS1020-Tumor-SM-E7RZL', 'control_sample_id': 'CCLF_PEDS1020-Normal-SM-E7RZ9', 'particpant_id': 'CCLF_PEDS1020'}
# {'entity:pair_id': 'CCLF_PEDS1021-Tumor-SM-E7S1A$CCLF_PEDS1021-Normal-SM-E7RZX', 'case_sample_id': 'CCLF_PEDS1021-Tumor-SM-E7S1A', 'control_sample_id': 'CCLF_PEDS1021-Normal-SM-E7RZX', 'particpant_id': 'CCLF_PEDS1021'}
# {'entity:pair_id': 'CCLF_PEDS1022-Tumor-SM-E7RZF$CCLF_PEDS1022-Normal-SM-E7RZ3', 'case_sample_id': 'CCLF_PEDS1022-Tumor-SM-E7RZF', 'control_sample_id': 'CCLF_PEDS1022-Normal-SM-E7RZ3', 'particpant_id': 'CCLF_PEDS1022'}
# {'entity:pair_id': 'CCLF_RCRF1007-Tumor-SM-E7S1Y$CCLF_RCRF1007-Normal-SM-E7S1M', 'case_sample_id': 'CCLF_RCRF1007-Tumor-SM-E7S1Y', 'control_sample_id': 'CCLF_RCRF1007-Normal-SM-E7S1M', 'particpant_id': 'CCLF_RCRF1007'}
# {'entity:pair_id': 'CCLF_SS1006-Tumor-SM-E7S14$CCLF_SS1006-Normal-SM-E7RZR', 'case_sample_id': 'CCLF_SS1006-Tumor-SM-E7S14', 'control_sample_id': 'CCLF_SS1006-Normal-SM-E7RZR', 'particpant_id': 'CCLF_SS1006'}
# {'entity:pair_id': 'JL62-Tumor-SM-E7RZ6$JL62-Normal-SM-DHZ6L', 'case_sample_id': 'JL62-Tumor-SM-E7RZ6', 'control_sample_id': 'JL62-Normal-SM-DHZ6L', 'particpant_id': 'JL62'}
# {'entity:pair_id': 'PEDS171-Tumor-SM-E7S11$PEDS171-Normal-SM-D4L1V', 'case_sample_id': 'PEDS171-Tumor-SM-E7S11', 'control_sample_id': 'PEDS171-Normal-SM-D4L1V', 'particpant_id': 'PEDS171'}
# {'entity:pair_id': 'PEDS194-Tumor-SM-E7S1D$PEDS194-Normal-SM-DHZ7O', 'case_sample_id': 'PEDS194-Tumor-SM-E7S1D', 'control_sample_id': 'PEDS194-Normal-SM-DHZ7O', 'particpant_id': 'PEDS194'}
# {'entity:pair_id': 'PEDS196-Tumor-SM-E7RZA$PEDS196-Normal-SM-DNULT', 'case_sample_id': 'PEDS196-Tumor-SM-E7RZA', 'control_sample_id': 'PEDS196-Normal-SM-DNULT', 'particpant_id': 'PEDS196'}
# {'entity:pair_id': 'PEDS204-Tumor-SM-E7RZM$PEDS204-Normal-SM-DNUMZ', 'case_sample_id': 'PEDS204-Tumor-SM-E7RZM', 'control_sample_id': 'PEDS204-Normal-SM-DNUMZ', 'particpant_id': 'PEDS204'}
# {'entity:pair_id': 'PEDS204-Tumor-SM-E7S2N$PEDS204-Normal-SM-DNUMZ', 'case_sample_id': 'PEDS204-Tumor-SM-E7S2N', 'control_sample_id': 'PEDS204-Normal-SM-DNUMZ', 'particpant_id': 'PEDS204'}
# {'entity:pair_id': 'PEDS207-Tumor-SM-E7S1Z$PEDS207-Normal-SM-E7RZ4', 'case_sample_id': 'PEDS207-Tumor-SM-E7S1Z', 'control_sample_id': 'PEDS207-Normal-SM-E7RZ4', 'particpant_id': 'PEDS207'}
# {'entity:pair_id': 'PEDS207-Tumor-SM-E7RZG$PEDS207-Normal-SM-DHZ6C', 'case_sample_id': 'PEDS207-Tumor-SM-E7RZG', 'control_sample_id': 'PEDS207-Normal-SM-DHZ6C', 'particpant_id': 'PEDS207'}
# {'entity:pair_id': 'PEDS207-Tumor-SM-E7RZI$PEDS207-Normal-SM-DHZ6C', 'case_sample_id': 'PEDS207-Tumor-SM-E7RZI', 'control_sample_id': 'PEDS207-Normal-SM-DHZ6C', 'particpant_id': 'PEDS207'}
# {'entity:pair_id': 'PEDS211-Tumor-SM-E7S22$PEDS211-Normal-SM-E7S1T', 'case_sample_id': 'PEDS211-Tumor-SM-E7S22', 'control_sample_id': 'PEDS211-Normal-SM-E7S1T', 'particpant_id': 'PEDS211'}
# {'entity:pair_id': 'PEDS211-Tumor-SM-E7S2E$PEDS211-Normal-SM-DO3D4', 'case_sample_id': 'PEDS211-Tumor-SM-E7S2E', 'control_sample_id': 'PEDS211-Normal-SM-DO3D4', 'particpant_id': 'PEDS211'}
# {'entity:pair_id': 'CCLF_JL1001-Tumor-SM-EUVHJ$CCLF_JL1001-Normal-SM-E7S2K', 'case_sample_id': 'CCLF_JL1001-Tumor-SM-EUVHJ', 'control_sample_id': 'CCLF_JL1001-Normal-SM-E7S2K', 'particpant_id': 'CCLF_JL1001'}
# {'entity:pair_id': 'CCLF_JL1001-Tumor-SM-EUVG4$CCLF_JL1001-Normal-SM-E7S2K', 'case_sample_id': 'CCLF_JL1001-Tumor-SM-EUVG4', 'control_sample_id': 'CCLF_JL1001-Normal-SM-E7S2K', 'particpant_id': 'CCLF_JL1001'}
# {'entity:pair_id': 'CCLF_JL1001-Tumor-SM-EUVGS$CCLF_JL1001-Normal-SM-EUVFR', 'case_sample_id': 'CCLF_JL1001-Tumor-SM-EUVGS', 'control_sample_id': 'CCLF_JL1001-Normal-SM-EUVFR', 'particpant_id': 'CCLF_JL1001'}
# {'entity:pair_id': 'CCLF_JL1001-Tumor-SM-EUVGG$CCLF_JL1001-Normal-SM-E7S2K', 'case_sample_id': 'CCLF_JL1001-Tumor-SM-EUVGG', 'control_sample_id': 'CCLF_JL1001-Normal-SM-E7S2K', 'particpant_id': 'CCLF_JL1001'}
# {'entity:pair_id': 'CCLF_PEDS1008-Tumor-SM-EUVH8$CCLF_PEDS1008-Normal-SM-E7S1Q', 'case_sample_id': 'CCLF_PEDS1008-Tumor-SM-EUVH8', 'control_sample_id': 'CCLF_PEDS1008-Normal-SM-E7S1Q', 'particpant_id': 'CCLF_PEDS1008'}
# {'entity:pair_id': 'CCLF_PEDS1008-Tumor-SM-EUVI3$CCLF_PEDS1008-Normal-SM-E7S23', 'case_sample_id': 'CCLF_PEDS1008-Tumor-SM-EUVI3', 'control_sample_id': 'CCLF_PEDS1008-Normal-SM-E7S23', 'particpant_id': 'CCLF_PEDS1008'}
# {'entity:pair_id': 'CCLF_PEDS1011-Tumor-SM-EUVHE$CCLF_PEDS1011-Normal-SM-E7RZE', 'case_sample_id': 'CCLF_PEDS1011-Tumor-SM-EUVHE', 'control_sample_id': 'CCLF_PEDS1011-Normal-SM-E7RZE', 'particpant_id': 'CCLF_PEDS1011'}
# {'entity:pair_id': 'CCLF_PEDS1021-Tumor-SM-EUVG7$CCLF_PEDS1021-Normal-SM-E7RZX', 'case_sample_id': 'CCLF_PEDS1021-Tumor-SM-EUVG7', 'control_sample_id': 'CCLF_PEDS1021-Normal-SM-E7RZX', 'particpant_id': 'CCLF_PEDS1021'}
# {'entity:pair_id': 'CCLF_PEDS1021-Tumor-SM-EUVGU$CCLF_PEDS1021-Normal-SM-E7RZX', 'case_sample_id': 'CCLF_PEDS1021-Tumor-SM-EUVGU', 'control_sample_id': 'CCLF_PEDS1021-Normal-SM-E7RZX', 'particpant_id': 'CCLF_PEDS1021'}
# {'entity:pair_id': 'CCLF_PEDS1025-Tumor-SM-EUVHD$CCLF_PEDS1025-Normal-SM-F29S8', 'case_sample_id': 'CCLF_PEDS1025-Tumor-SM-EUVHD', 'control_sample_id': 'CCLF_PEDS1025-Normal-SM-F29S8', 'particpant_id': 'CCLF_PEDS1025'}
# {'entity:pair_id': 'CCLF_PEDS1025-Tumor-SM-EUVI2$CCLF_PEDS1025-Normal-SM-EUVG1', 'case_sample_id': 'CCLF_PEDS1025-Tumor-SM-EUVI2', 'control_sample_id': 'CCLF_PEDS1025-Normal-SM-EUVG1', 'particpant_id': 'CCLF_PEDS1025'}
# {'entity:pair_id': 'CCLF_PEDS1025-Tumor-SM-EUVHP$CCLF_PEDS1025-Normal-SM-EUVFO', 'case_sample_id': 'CCLF_PEDS1025-Tumor-SM-EUVHP', 'control_sample_id': 'CCLF_PEDS1025-Normal-SM-EUVFO', 'particpant_id': 'CCLF_PEDS1025'}
# {'entity:pair_id': 'CCLF_PEDS1025-Tumor-SM-EUVFV$CCLF_PEDS1025-Normal-SM-EUVG1', 'case_sample_id': 'CCLF_PEDS1025-Tumor-SM-EUVFV', 'control_sample_id': 'CCLF_PEDS1025-Normal-SM-EUVG1', 'particpant_id': 'CCLF_PEDS1025'}
# {'entity:pair_id': 'CCLF_PEDS1026-Tumor-SM-EUVGD$CCLF_PEDS1026-Normal-SM-EUVHW', 'case_sample_id': 'CCLF_PEDS1026-Tumor-SM-EUVGD', 'control_sample_id': 'CCLF_PEDS1026-Normal-SM-EUVHW', 'particpant_id': 'CCLF_PEDS1026'}
# {'entity:pair_id': 'CCLF_PEDS1026-Tumor-SM-EUVGP$CCLF_PEDS1026-Normal-SM-EUVHW', 'case_sample_id': 'CCLF_PEDS1026-Tumor-SM-EUVGP', 'control_sample_id': 'CCLF_PEDS1026-Normal-SM-EUVHW', 'particpant_id': 'CCLF_PEDS1026'}
# {'entity:pair_id': 'CCLF_PEDS1026-Tumor-SM-EUVHK$CCLF_PEDS1026-Normal-SM-EUVH2', 'case_sample_id': 'CCLF_PEDS1026-Tumor-SM-EUVHK', 'control_sample_id': 'CCLF_PEDS1026-Normal-SM-EUVH2', 'particpant_id': 'CCLF_PEDS1026'}
# {'entity:pair_id': 'CCLF_PEDS1027-Tumor-SM-EUVFW$CCLF_PEDS1027-Normal-SM-F67E1', 'case_sample_id': 'CCLF_PEDS1027-Tumor-SM-EUVFW', 'control_sample_id': 'CCLF_PEDS1027-Normal-SM-F67E1', 'particpant_id': 'CCLF_PEDS1027'}
# {'entity:pair_id': 'CCLF_PEDS1029-Tumor-SM-EUVFZ$CCLF_PEDS1029-Normal-SM-EUVH1', 'case_sample_id': 'CCLF_PEDS1029-Tumor-SM-EUVFZ', 'control_sample_id': 'CCLF_PEDS1029-Normal-SM-EUVH1', 'particpant_id': 'CCLF_PEDS1029'}
# {'entity:pair_id': 'CCLF_PEDS1011-Tumor-SM-F29S5$CCLF_PEDS1011-Normal-SM-E7RZE', 'case_sample_id': 'CCLF_PEDS1011-Tumor-SM-F29S5', 'control_sample_id': 'CCLF_PEDS1011-Normal-SM-E7RZE', 'particpant_id': 'CCLF_PEDS1011'}
# {'entity:pair_id': 'CCLF_PEDS1023-Tumor-SM-F29S7$CCLF_PEDS1023-Normal-SM-F29S6', 'case_sample_id': 'CCLF_PEDS1023-Tumor-SM-F29S7', 'control_sample_id': 'CCLF_PEDS1023-Normal-SM-F29S6', 'particpant_id': 'CCLF_PEDS1023'}
# {'entity:pair_id': 'CCLF_PEDS1025-Tumor-SM-F29S9$CCLF_PEDS1025-Normal-SM-EUVG8', 'case_sample_id': 'CCLF_PEDS1025-Tumor-SM-F29S9', 'control_sample_id': 'CCLF_PEDS1025-Normal-SM-EUVG8', 'particpant_id': 'CCLF_PEDS1025'}
# {'entity:pair_id': 'CCLF_PEDS1033-Tumor-SM-F29SF$CCLF_PEDS1033-Normal-SM-F29SD', 'case_sample_id': 'CCLF_PEDS1033-Tumor-SM-F29SF', 'control_sample_id': 'CCLF_PEDS1033-Normal-SM-F29SD', 'particpant_id': 'CCLF_PEDS1033'}
# {'entity:pair_id': 'CCLF_PEDS1033-Tumor-SM-F29SE$CCLF_PEDS1033-Normal-SM-F29SD', 'case_sample_id': 'CCLF_PEDS1033-Tumor-SM-F29SE', 'control_sample_id': 'CCLF_PEDS1033-Normal-SM-F29SD', 'particpant_id': 'CCLF_PEDS1033'}
# {'entity:pair_id': 'CCLF_PEDS1035-Tumor-SM-F29SI$CCLF_PEDS1035-Normal-SM-F29SG', 'case_sample_id': 'CCLF_PEDS1035-Tumor-SM-F29SI', 'control_sample_id': 'CCLF_PEDS1035-Normal-SM-F29SG', 'particpant_id': 'CCLF_PEDS1035'}
# {'entity:pair_id': 'CCLF_PEDS1035-Tumor-SM-F29SJ$CCLF_PEDS1035-Normal-SM-F29SG', 'case_sample_id': 'CCLF_PEDS1035-Tumor-SM-F29SJ', 'control_sample_id': 'CCLF_PEDS1035-Normal-SM-F29SG', 'particpant_id': 'CCLF_PEDS1035'}
# {'entity:pair_id': 'CCLF_SS1008-Tumor-SM-F29SM$CCLF_SS1008-Normal-SM-F29SL', 'case_sample_id': 'CCLF_SS1008-Tumor-SM-F29SM', 'control_sample_id': 'CCLF_SS1008-Normal-SM-F29SL', 'particpant_id': 'CCLF_SS1008'}
# {'entity:pair_id': 'CCLF_SS1008-Tumor-SM-F29SN$CCLF_SS1008-Normal-SM-F29SL', 'case_sample_id': 'CCLF_SS1008-Tumor-SM-F29SN', 'control_sample_id': 'CCLF_SS1008-Normal-SM-F29SL', 'particpant_id': 'CCLF_SS1008'}
# {'entity:pair_id': 'CCLF_SS1009-Tumor-SM-F29SP$CCLF_SS1009-Normal-SM-F29SO', 'case_sample_id': 'CCLF_SS1009-Tumor-SM-F29SP', 'control_sample_id': 'CCLF_SS1009-Normal-SM-F29SO', 'particpant_id': 'CCLF_SS1009'}
# {'entity:pair_id': 'EH026-Tumor-SM-F29SW$EH026-Normal-SM-F29SV', 'case_sample_id': 'EH026-Tumor-SM-F29SW', 'control_sample_id': 'EH026-Normal-SM-F29SV', 'particpant_id': 'EH026'}
# {'entity:pair_id': 'EH027-Tumor-SM-F29SY$EH027-Normal-SM-F29SX', 'case_sample_id': 'EH027-Tumor-SM-F29SY', 'control_sample_id': 'EH027-Normal-SM-F29SX', 'particpant_id': 'EH027'}
# {'entity:pair_id': 'CCLF_PEDS1021-Tumor-SM-F67F8$CCLF_PEDS1021-Normal-SM-E7RZX', 'case_sample_id': 'CCLF_PEDS1021-Tumor-SM-F67F8', 'control_sample_id': 'CCLF_PEDS1021-Normal-SM-E7RZX', 'particpant_id': 'CCLF_PEDS1021'}
# {'entity:pair_id': 'CCLF_PEDS1021-Tumor-SM-F67EV$CCLF_PEDS1021-Normal-SM-E7RZX', 'case_sample_id': 'CCLF_PEDS1021-Tumor-SM-F67EV', 'control_sample_id': 'CCLF_PEDS1021-Normal-SM-E7RZX', 'particpant_id': 'CCLF_PEDS1021'}
# {'entity:pair_id': 'CCLF_PEDS1022-Tumor-SM-F67DU$CCLF_PEDS1022-Normal-SM-E7RZ3', 'case_sample_id': 'CCLF_PEDS1022-Tumor-SM-F67DU', 'control_sample_id': 'CCLF_PEDS1022-Normal-SM-E7RZ3', 'particpant_id': 'CCLF_PEDS1022'}
# {'entity:pair_id': 'CCLF_PEDS1029-Tumor-SM-F67FP$CCLF_PEDS1029-Normal-SM-F67EJ', 'case_sample_id': 'CCLF_PEDS1029-Tumor-SM-F67FP', 'control_sample_id': 'CCLF_PEDS1029-Normal-SM-F67EJ', 'particpant_id': 'CCLF_PEDS1029'}
# {'entity:pair_id': 'CCLF_PEDS1033-Tumor-SM-F67EA$CCLF_PEDS1033-Normal-SM-F67FB', 'case_sample_id': 'CCLF_PEDS1033-Tumor-SM-F67EA', 'control_sample_id': 'CCLF_PEDS1033-Normal-SM-F67FB', 'particpant_id': 'CCLF_PEDS1033'}
# {'entity:pair_id': 'CCLF_PEDS1033-Tumor-SM-F67G3$CCLF_PEDS1033-Normal-SM-F67FB', 'case_sample_id': 'CCLF_PEDS1033-Tumor-SM-F67G3', 'control_sample_id': 'CCLF_PEDS1033-Normal-SM-F67FB', 'particpant_id': 'CCLF_PEDS1033'}
# {'entity:pair_id': 'CCLF_PEDS1033-Tumor-SM-F67FY$CCLF_PEDS1033-Normal-SM-F29SC', 'case_sample_id': 'CCLF_PEDS1033-Tumor-SM-F67FY', 'control_sample_id': 'CCLF_PEDS1033-Normal-SM-F29SC', 'particpant_id': 'CCLF_PEDS1033'}
# {'entity:pair_id': 'CCLF_PEDS1034-Tumor-SM-F67EF$CCLF_PEDS1034-Normal-SM-F67G4', 'case_sample_id': 'CCLF_PEDS1034-Tumor-SM-F67EF', 'control_sample_id': 'CCLF_PEDS1034-Normal-SM-F67G4', 'particpant_id': 'CCLF_PEDS1034'}
# {'entity:pair_id': 'CCLF_PEDS1035-Tumor-SM-F67DQ$CCLF_PEDS1035-Normal-SM-F29SH', 'case_sample_id': 'CCLF_PEDS1035-Tumor-SM-F67DQ', 'control_sample_id': 'CCLF_PEDS1035-Normal-SM-F29SH', 'particpant_id': 'CCLF_PEDS1035'}
# {'entity:pair_id': 'CCLF_PEDS1037-Tumor-SM-F67FK$CCLF_PEDS1037-Normal-SM-F67FW', 'case_sample_id': 'CCLF_PEDS1037-Tumor-SM-F67FK', 'control_sample_id': 'CCLF_PEDS1037-Normal-SM-F67FW', 'particpant_id': 'CCLF_PEDS1037'}
# {'entity:pair_id': 'CCLF_RCRF1009-Tumor-SM-F67FI$CCLF_RCRF1009-Normal-SM-F67FU', 'case_sample_id': 'CCLF_RCRF1009-Tumor-SM-F67FI', 'control_sample_id': 'CCLF_RCRF1009-Normal-SM-F67FU', 'particpant_id': 'CCLF_RCRF1009'}
# {'entity:pair_id': 'PEDS063-Tumor-SM-F67EL$PEDS063-Normal-SM-F67EX', 'case_sample_id': 'PEDS063-Tumor-SM-F67EL', 'control_sample_id': 'PEDS063-Normal-SM-F67EX', 'particpant_id': 'PEDS063'}
# {'entity:pair_id': 'PEDS143-Tumor-SM-F67FL$PEDS143-Normal-SM-F67F9', 'case_sample_id': 'PEDS143-Tumor-SM-F67FL', 'control_sample_id': 'PEDS143-Normal-SM-F67F9', 'particpant_id': 'PEDS143'}

# %%
test = {'entity:pair_id': 'EH014-Tumor-SM-D4L26$EH014-Normal-SM-D4L35', 'case_sample_id': 'EH014-Tumor-SM-D4L26', 'control_sample_id': 'EH014-Normal-SM-D4L35', 'particpant_id': 'EH014'}

# %%
pd.DataFrame().from_dict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1d5231e7001b> in <module>()
# ----> 1 pd.DataFrame().from_dict(test)
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype)
#     859             raise ValueError('only recognize index or columns for orient')
#     860
# --> 861         return cls(data, index=index, columns=columns, dtype=dtype)
#     862
#     863     def to_dict(self, orient='dict'):
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5592     # figure out the index, if necessary
#    5593     if index is None:
# -> 5594         index = extract_index(arrays)
#    5595     else:
#    5596         index = _ensure_index(index)
#
# /Users/mimoun/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5631
#    5632         if not indexes and not raw_lengths:
# -> 5633             raise ValueError('If using all scalar values, you must pass'
#    5634                              ' an index')
#    5635
#
# ValueError: If using all scalar values, you must pass an index

# %%
def add_matching_samples(all_samples, batch_samples):
    """Add sample_id and bam filepath of matching normals and primary tumor tissue for every sample
    in batch_samples
    Args:
        - all_samples: df with target samples we want to find matches in
        - batch_samples: df with source samples we want to find matches for
    Returns: 
        - batch_samples (augmented)
    """
    for index, row in batch_samples.iterrows():
        # Find all samples from same individual (same individual_id, different sample_id)
        patient_samples = all_samples[ (all_samples['participant_id'] == row['participant_id']) \
                                      & (all_samples['entity:sample_id'] != row['entity:sample_id']) ]

        # NOTE: If more than one match tumor tissue or match normal found, select one at random.
        # The match normal is used to compute allelic fractions in Mutect2, so for now we ignore the conditions it was grown in.

        # Tumor tissue: Add primary tumor tissue
        match_primary_tumor = patient_samples[ patient_samples['external_id_validation'] \
                                              .str.contains('primary|prim|tissue|tiss') ]
        #    > No primary tumor tissue found
        if match_primary_tumor.empty:
            batch_samples.loc[index, 'match_primary_tumor_sample_id'] = "NA"
            batch_samples.loc[index, 'match_primary_tumor_bam_file'] = "NA"
        #    > Tumor tissue found
        elif match_primary_tumor.shape[0] > 0:
            match_primary_tumor = match_primary_tumor.sample(n=1)
            batch_samples.loc[index, 'match_primary_tumor_sample_id'] = match_primary_tumor['entity:sample_id'].item()
            batch_samples.loc[index, 'match_primary_tumor_bam_file'] = match_primary_tumor['clean_bam_file_capture'].item()

        # Match normal: Add match normal
        match_normal = patient_samples[ patient_samples['sample_type'] == "Normal"]
        #   > No match normal found
        if match_normal.empty: 
            batch_samples.loc[index, 'match_normal_sample_id'] = "NA"
            batch_samples.loc[index, 'match_normal_bam_file'] = "NA"
        #   > Match normal found
        elif match_normal.shape[0] > 0:
            match_normal = match_normal.sample(n=1)
            batch_samples.loc[index, 'match_normal_sample_id'] = match_normal['entity:sample_id'].item()
            batch_samples.loc[index, 'match_normal_bam_file'] = match_normal['clean_bam_file_capture'].item()
            
    return batch_samples
