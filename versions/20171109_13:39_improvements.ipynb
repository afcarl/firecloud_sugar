# %%
import v2fc_interface as fs
from firecloud import api as firecloud_api
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
paths_to_samples_info = pd.read_excel("paths_to_batches_info.xlsx")
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA_2_0"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"

# %%
tsca_id = "TSCA1213"
latest_tsca_id = "TSCA22"
path_to_samples_info = "/xchip/clf/seq_data/processed_for_fh/tsca1213_201610_SN0106956/tsca1213_201610_SN0106956.import_samples.txt"

# %%
### PROCESS FOR NEW BATCH
tsca_id = "TSCA1213"
latest_tsca_id = "TSCA22"
path_to_samples_info = "/xchip/clf/seq_data/processed_for_fh/tsca1213_201610_SN0106956/tsca1213_201610_SN0106956.import_samples.txt"
res = fs.upload_all(tsca_id, latest_tsca_id, path_to_samples_info, namespace, workspace, google_bucket_id)
# Out:
# 160 Participants in this batch
# 190 Samples in this batch

# %%
batch_sample_set, batch_tumor_set, batch_normal_set = fs.prepare_batch_sample_set_for_metadata_export(path_to_samples_info, tsca_id)
# Out:
# 190 Samples in this batch

# %%
fs.filter_existing_samples(batch_sample_set, 'sample_id', namespace, workspace)
# Out:
#     membership:sample_set_id                sample_id
# 0                     TSCA22     AA33-Normal-SM-D4L4D
# 1                     TSCA22      AA34-Tumor-SM-D4L25
# 2                     TSCA22      AA36-Tumor-SM-D4L2H
# 3                     TSCA22      AA39-Tumor-SM-D4L3Q
# 4                     TSCA22      AA40-Tumor-SM-D4L42
# 5                     TSCA22     AB044-Tumor-SM-D4L2M
# 6                     TSCA22   ANGMCSS-Tumor-SM-D4L2G
# 7                     TSCA22    BT1008-Tumor-SM-D4L45
# 8                     TSCA22     BT922-Tumor-SM-D4L1W
# 9                     TSCA22     BT923-Tumor-SM-D4L3W
# 10                    TSCA22     BT950-Tumor-SM-D4L48
# 11                    TSCA22     BT961-Tumor-SM-D4L3C
# 12                    TSCA22     BT972-Tumor-SM-D4L3Y
# 13                    TSCA22   CHLA200-Tumor-SM-CNN37
# 14                    TSCA22     CO001-Tumor-SM-D4L3V
# 15                    TSCA22     CO002-Tumor-SM-D4L47
# 16                    TSCA22     CO003-Tumor-SM-D4L1Y
# 17                    TSCA22     CO004-Tumor-SM-D4L3B
# 18                    TSCA22     CO005-Tumor-SM-D4L2P
# 19                    TSCA22     CO006-Tumor-SM-D4L7Q
# 20                    TSCA22     CO007-Tumor-SM-D4L49
