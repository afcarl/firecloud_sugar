# %%
import v2fc_interface as fs
from firecloud import api as firecloud_api
# %load_ext autoreload
# %autoreload 2

# %%
paths_to_samples_info = pd.read_excel("paths_to_batches_info.xlsx")
namespace = "nci-mimoun-bi-org"
workspace = "CCLF_TSCA_2_0"
google_bucket_id = "fc-35446f22-ea37-483a-bd6c-5e9fc56851ff"

# %%
tsca_id = "TSCA1213"
latest_tsca_id = "TSCA22"
path_to_samples_info = "/xchip/clf/seq_data/processed_for_fh/tsca1213_201610_SN0106956/tsca1213_201610_SN0106956.import_samples.txt"

# %%
### PROCESS FOR NEW BATCH
tsca_id = "TSCA1213"
latest_tsca_id = "TSCA22"
path_to_samples_info = "/xchip/clf/seq_data/processed_for_fh/tsca1213_201610_SN0106956/tsca1213_201610_SN0106956.import_samples.txt"
res = fs.upload_data_new_batch(tsca_id, latest_tsca_id, path_to_samples_info, namespace, workspace, google_bucket_id)
# res = update_cohorts(latest_tsca_id, namespace, workspace, google_bucket_id)

# %%
# fs.update_cohorts(latest_tsca_id, namespace, workspace, google_bucket_id)

# %%
remote_sample_sets = pd.read_table('remote_files/sample_set_membership_%s.tsv'%latest_tsca_id)

# %%
remote_sample_sets
# Out:
#      membership:sample_set_id                        sample
# 0                   COHORT_AA          AA33-Normal-SM-D4L4D
# 1                   COHORT_AA           AA34-Tumor-SM-D4L25
# 2                   COHORT_AA           AA36-Tumor-SM-D4L2H
# 3                   COHORT_AA           AA39-Tumor-SM-D4L3Q
# 4                   COHORT_AA           AA40-Tumor-SM-D4L42
# 5                   COHORT_AA           AA24-Tumor-SM-DHZ8W
# 6                   COHORT_AA           AA25-Tumor-SM-DHZ99
# 7                   COHORT_AA          AA33-Normal-SM-DHZ9L
# 8                   COHORT_AA           AA33-Tumor-SM-DHZ9X
# 9                   COHORT_AA           AA38-Tumor-SM-DHZ98
# 10                  COHORT_AA           AA39-Tumor-SM-DHZAA
# 11                  COHORT_AA           AA40-Tumor-SM-DHZ7W
# 12                  COHORT_AA           AA42-Tumor-SM-DHZ9W
# 13                  COHORT_AA           AA43-Tumor-SM-DHZ8K
# 14                  COHORT_AA          AA44-Normal-SM-DHZ88
# 15                  COHORT_AA           AA45-Tumor-SM-DHZ9K
# 16                  COHORT_AA           AA46-Tumor-SM-DHZA9
# 17                  COHORT_AA           AA47-Tumor-SM-DHZ7V
# 18                  COHORT_AA           AA38-Tumor-SM-E7S17
# 19                  COHORT_AA           AA42-Tumor-SM-E7S2I
# 20                  COHORT_AA           AA45-Tumor-SM-E7RZ5
# 21                  COHORT_AA           AA47-Tumor-SM-E7S1J
# 22                  COHORT_AA           AA49-Tumor-SM-E7S1V
# 23                  COHORT_AA           AA49-Tumor-SM-EUVFI
# 24                  COHORT_AA           AA53-Tumor-SM-EUVFU
# 25                  COHORT_AA           AA55-Tumor-SM-EUVGJ
# 26                  COHORT_AA           AA56-Tumor-SM-EUVGH
# 27                  COHORT_AA           AA59-Tumor-SM-EUVH6
# 28                  COHORT_AA           AA66-Tumor-SM-F29RQ
# 29                  COHORT_AA    CCLF_AA1003-Tumor-SM-F29RS
# ...                       ...                           ...
# 5870                 TSCA22_T  CCLF_RCRF1010-Tumor-SM-GL7MX
# 5871                 TSCA22_T  CCLF_RCRF1010-Tumor-SM-GL7NA
# 5872                 TSCA22_T  CCLF_RCRF1012-Tumor-SM-GL7MH
# 5873                 TSCA22_T  CCLF_RCRF1013-Tumor-SM-GL7LW
# 5874                 TSCA22_T  CCLF_RCRF1013-Tumor-SM-GL7M1
# 5875                 TSCA22_T  CCLF_RCRF1013-Tumor-SM-GL7ML
# 5876                 TSCA22_T  CCLF_RCRF1013-Tumor-SM-GL7M9
# 5877                 TSCA22_T  CCLF_RCRF1014-Tumor-SM-GL7NI
# 5878                 TSCA22_T  CCLF_RCRF1014-Tumor-SM-GL7LJ
# 5879                 TSCA22_T  CCLF_RCRF1015-Tumor-SM-GL7N5
# 5880                 TSCA22_T  CCLF_RCRF1015-Tumor-SM-GL7N6
# 5881                 TSCA22_T  CCLF_RCRF1015-Tumor-SM-GL7LS
# 5882                 TSCA22_T  CCLF_RCRF1018-Tumor-SM-GL7LH
# 5883                 TSCA22_T    CCLF_SS1008-Tumor-SM-GL7MC
# 5884                 TSCA22_T    CCLF_SS1009-Tumor-SM-GL7NQ
# 5885                 TSCA22_T          CY014-Tumor-SM-GL7ME
# 5886                 TSCA22_T          CY018-Tumor-SM-GL7N4
# 5887                 TSCA22_T          CY018-Tumor-SM-GL7M2
# 5888                 TSCA22_T          CY020-Tumor-SM-GL7LR
# 5889                 TSCA22_T          CY020-Tumor-SM-GL7NG
# 5890                 TSCA22_T          CY021-Tumor-SM-GL7MD
# 5891                 TSCA22_T          EH031-Tumor-SM-GL7NX
# 5892                 TSCA22_T          EH032-Tumor-SM-GL7LK
# 5893                 TSCA22_T          EW012-Tumor-SM-GL7NM
# 5894                 TSCA22_T          HG018-Tumor-SM-GL7NY
# 5895                 TSCA22_T          HG018-Tumor-SM-GL7MK
# 5896                 TSCA22_T  CCLF_RCRF1014-Tumor-SM-GL7MT
# 5897                 TSCA22_T          TC011-Tumor-SM-GL7NS
# 5898                 TSCA22_T          TC011-Tumor-SM-GL7M5
# 5899                 TSCA22_T          TC013-Tumor-SM-GL7NU
#
# [5900 rows x 2 columns]

# %%
# all_samples = fs.get_samples_with_cohort(latest_tsca_id, "paths_to_batches_info.xlsx", google_bucket_id)
# pairs = fs.create_pairs_list(all_samples)

# %%
cohorts = fs.prepare_cohorts_for_metadata_export("paths_to_batches_info.xlsx", google_bucket_id, latest_tsca_id, namespace, workspace, blacklist=[])

# %%
cohort.head(2)
# Out:
#   membership:sample_set_id             sample_id
# 0                COHORT_AA  AA33-Normal-SM-D4L4D
# 1                COHORT_AA   AA34-Tumor-SM-D4L25

# %%
cohorts_clean = cohorts[~cohorts['sample_id'].isin()]
# Out:
#      membership:sample_set_id                    sample_id
# 0                   COHORT_AA         AA33-Normal-SM-D4L4D
# 1                   COHORT_AA          AA34-Tumor-SM-D4L25
# 2                   COHORT_AA          AA36-Tumor-SM-D4L2H
# 3                   COHORT_AA          AA39-Tumor-SM-D4L3Q
# 4                   COHORT_AA          AA40-Tumor-SM-D4L42
# 5                   COHORT_AA          AA24-Tumor-SM-DHZ8W
# 6                   COHORT_AA          AA25-Tumor-SM-DHZ99
# 7                   COHORT_AA         AA33-Normal-SM-DHZ9L
# 8                   COHORT_AA          AA33-Tumor-SM-DHZ9X
# 9                   COHORT_AA          AA38-Tumor-SM-DHZ98
# 10                  COHORT_AA          AA39-Tumor-SM-DHZAA
# 11                  COHORT_AA          AA40-Tumor-SM-DHZ7W
# 12                  COHORT_AA          AA42-Tumor-SM-DHZ9W
# 13                  COHORT_AA          AA43-Tumor-SM-DHZ8K
# 14                  COHORT_AA         AA44-Normal-SM-DHZ88
# 15                  COHORT_AA          AA45-Tumor-SM-DHZ9K
# 16                  COHORT_AA          AA46-Tumor-SM-DHZA9
# 17                  COHORT_AA          AA47-Tumor-SM-DHZ7V
# 18                  COHORT_AA          AA38-Tumor-SM-E7S17
# 19                  COHORT_AA          AA42-Tumor-SM-E7S2I
# 20                  COHORT_AA          AA45-Tumor-SM-E7RZ5
# 21                  COHORT_AA          AA47-Tumor-SM-E7S1J
# 22                  COHORT_AA          AA49-Tumor-SM-E7S1V
# 23                  COHORT_AA          AA49-Tumor-SM-EUVFI
# 24                  COHORT_AA          AA53-Tumor-SM-EUVFU
# 25                  COHORT_AA          AA55-Tumor-SM-EUVGJ
# 26                  COHORT_AA          AA56-Tumor-SM-EUVGH
# 27                  COHORT_AA          AA59-Tumor-SM-EUVH6
# 28                  COHORT_AA          AA66-Tumor-SM-F29RQ
# 29                  COHORT_AA   CCLF_AA1003-Tumor-SM-F29RS
# ...                       ...                          ...
# 1110         COHORT_CSHL_PDAC  CSHL_PDAC_25-Tumor-SM-F29TS
# 1111         COHORT_CSHL_PDAC  CSHL_PDAC_26-Tumor-SM-F29TT
# 1112         COHORT_CSHL_PDAC  CSHL_PDAC_27-Tumor-SM-F29TU
# 1113         COHORT_CSHL_PDAC  CSHL_PDAC_28-Tumor-SM-F29TV
# 1114         COHORT_CSHL_PDAC  CSHL_PDAC_29-Tumor-SM-F29TW
# 1115         COHORT_CSHL_PDAC   CSHL_PDAC_3-Tumor-SM-F29T6
# 1116         COHORT_CSHL_PDAC  CSHL_PDAC_30-Tumor-SM-F29TX
# 1117         COHORT_CSHL_PDAC  CSHL_PDAC_31-Tumor-SM-F29TZ
# 1118         COHORT_CSHL_PDAC  CSHL_PDAC_32-Tumor-SM-F29U1
# 1119         COHORT_CSHL_PDAC  CSHL_PDAC_33-Tumor-SM-F29U2
# 1120         COHORT_CSHL_PDAC  CSHL_PDAC_34-Tumor-SM-F29U3
# 1121         COHORT_CSHL_PDAC  CSHL_PDAC_34-Tumor-SM-F29U4
# 1122         COHORT_CSHL_PDAC  CSHL_PDAC_35-Tumor-SM-F29U5
# 1123         COHORT_CSHL_PDAC  CSHL_PDAC_36-Tumor-SM-F29U6
# 1124         COHORT_CSHL_PDAC  CSHL_PDAC_36-Tumor-SM-F29U7
# 1125         COHORT_CSHL_PDAC  CSHL_PDAC_36-Tumor-SM-F29U8
# 1126         COHORT_CSHL_PDAC  CSHL_PDAC_37-Tumor-SM-F29U9
# 1127         COHORT_CSHL_PDAC  CSHL_PDAC_38-Tumor-SM-F29UA
# 1128         COHORT_CSHL_PDAC  CSHL_PDAC_38-Tumor-SM-F29UB
# 1129         COHORT_CSHL_PDAC  CSHL_PDAC_38-Tumor-SM-F29UC
# 1130         COHORT_CSHL_PDAC  CSHL_PDAC_38-Tumor-SM-F29UD
# 1131         COHORT_CSHL_PDAC  CSHL_PDAC_39-Tumor-SM-F29UE
# 1132         COHORT_CSHL_PDAC   CSHL_PDAC_4-Tumor-SM-F29T7
# 1133         COHORT_CSHL_PDAC  CSHL_PDAC_40-Tumor-SM-F29UF
# 1134         COHORT_CSHL_PDAC   CSHL_PDAC_5-Tumor-SM-F29T8
# 1135         COHORT_CSHL_PDAC   CSHL_PDAC_5-Tumor-SM-F29TY
# 1136         COHORT_CSHL_PDAC   CSHL_PDAC_6-Tumor-SM-F29T9
# 1137         COHORT_CSHL_PDAC   CSHL_PDAC_7-Tumor-SM-F29TA
# 1138         COHORT_CSHL_PDAC   CSHL_PDAC_8-Tumor-SM-F29TB
# 1139         COHORT_CSHL_PDAC   CSHL_PDAC_9-Tumor-SM-F29TC
#
# [1140 rows x 2 columns]

# %%
all_samples = fs.get_samples_with_cohort(latest_tsca_id, "paths_to_batches_info.xlsx", google_bucket_id)
pairs = fs.create_pairs_list(all_samples)
cohort_pairsets = fs.prepare_cohort_pairsets_for_metadata_exports(latest_tsca_id, pairs, all_samples, blacklist=[])

# %%
cohort_pairsets
# Out:
#      membership:pair_set_id                                      pair_id
# 0                 COHORT_AA                    AA34-Tumor-SM-D4L25_NA_TN
# 1                 COHORT_AA                    AA34-Tumor-SM-D4L25_NA_TP
# 2                 COHORT_AA                    AA36-Tumor-SM-D4L2H_NA_TN
# 3                 COHORT_AA                    AA36-Tumor-SM-D4L2H_NA_TP
# 4                 COHORT_AA                    AA39-Tumor-SM-D4L3Q_NA_TN
# 5                 COHORT_AA                    AA39-Tumor-SM-D4L3Q_NA_TP
# 6                 COHORT_AA                    AA40-Tumor-SM-D4L42_NA_TN
# 7                 COHORT_AA                    AA40-Tumor-SM-D4L42_NA_TP
# 8                 COHORT_AA                    AA24-Tumor-SM-DHZ8W_NA_TN
# 9                 COHORT_AA                    AA24-Tumor-SM-DHZ8W_NA_TP
# 10                COHORT_AA                    AA25-Tumor-SM-DHZ99_NA_TN
# 11                COHORT_AA                    AA25-Tumor-SM-DHZ99_NA_TP
# 12                COHORT_AA  AA33-Tumor-SM-DHZ9X_AA33-Normal-SM-D4L4D_TN
# 13                COHORT_AA                    AA33-Tumor-SM-DHZ9X_NA_TP
# 14                COHORT_AA                    AA38-Tumor-SM-DHZ98_NA_TN
# 15                COHORT_AA                    AA38-Tumor-SM-DHZ98_NA_TP
# 16                COHORT_AA                    AA39-Tumor-SM-DHZAA_NA_TN
# 17                COHORT_AA                    AA39-Tumor-SM-DHZAA_NA_TP
# 18                COHORT_AA                    AA40-Tumor-SM-DHZ7W_NA_TN
# 19                COHORT_AA                    AA40-Tumor-SM-DHZ7W_NA_TP
# 20                COHORT_AA                    AA42-Tumor-SM-DHZ9W_NA_TN
# 21                COHORT_AA                    AA42-Tumor-SM-DHZ9W_NA_TP
# 22                COHORT_AA                    AA43-Tumor-SM-DHZ8K_NA_TN
# 23                COHORT_AA                    AA43-Tumor-SM-DHZ8K_NA_TP
# 24                COHORT_AA                    AA45-Tumor-SM-DHZ9K_NA_TN
# 25                COHORT_AA                    AA45-Tumor-SM-DHZ9K_NA_TP
# 26                COHORT_AA                    AA46-Tumor-SM-DHZA9_NA_TN
# 27                COHORT_AA                    AA46-Tumor-SM-DHZA9_NA_TP
# 28                COHORT_AA                    AA47-Tumor-SM-DHZ7V_NA_TN
# 29                COHORT_AA                    AA47-Tumor-SM-DHZ7V_NA_TP
# ...                     ...                                          ...
# 1922       COHORT_CSHL_PDAC            CSHL_PDAC_36-Tumor-SM-F29U8_NA_TN
# 1923       COHORT_CSHL_PDAC            CSHL_PDAC_36-Tumor-SM-F29U8_NA_TP
# 1924       COHORT_CSHL_PDAC            CSHL_PDAC_37-Tumor-SM-F29U9_NA_TN
# 1925       COHORT_CSHL_PDAC            CSHL_PDAC_37-Tumor-SM-F29U9_NA_TP
# 1926       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UA_NA_TN
# 1927       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UA_NA_TP
# 1928       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UB_NA_TN
# 1929       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UB_NA_TP
# 1930       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UC_NA_TN
# 1931       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UC_NA_TP
# 1932       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UD_NA_TN
# 1933       COHORT_CSHL_PDAC            CSHL_PDAC_38-Tumor-SM-F29UD_NA_TP
# 1934       COHORT_CSHL_PDAC            CSHL_PDAC_39-Tumor-SM-F29UE_NA_TN
# 1935       COHORT_CSHL_PDAC            CSHL_PDAC_39-Tumor-SM-F29UE_NA_TP
# 1936       COHORT_CSHL_PDAC             CSHL_PDAC_4-Tumor-SM-F29T7_NA_TN
# 1937       COHORT_CSHL_PDAC             CSHL_PDAC_4-Tumor-SM-F29T7_NA_TP
# 1938       COHORT_CSHL_PDAC            CSHL_PDAC_40-Tumor-SM-F29UF_NA_TN
# 1939       COHORT_CSHL_PDAC            CSHL_PDAC_40-Tumor-SM-F29UF_NA_TP
# 1940       COHORT_CSHL_PDAC             CSHL_PDAC_5-Tumor-SM-F29T8_NA_TN
# 1941       COHORT_CSHL_PDAC             CSHL_PDAC_5-Tumor-SM-F29T8_NA_TP
# 1942       COHORT_CSHL_PDAC             CSHL_PDAC_5-Tumor-SM-F29TY_NA_TN
# 1943       COHORT_CSHL_PDAC             CSHL_PDAC_5-Tumor-SM-F29TY_NA_TP
# 1944       COHORT_CSHL_PDAC             CSHL_PDAC_6-Tumor-SM-F29T9_NA_TN
# 1945       COHORT_CSHL_PDAC             CSHL_PDAC_6-Tumor-SM-F29T9_NA_TP
# 1946       COHORT_CSHL_PDAC             CSHL_PDAC_7-Tumor-SM-F29TA_NA_TN
# 1947       COHORT_CSHL_PDAC             CSHL_PDAC_7-Tumor-SM-F29TA_NA_TP
# 1948       COHORT_CSHL_PDAC             CSHL_PDAC_8-Tumor-SM-F29TB_NA_TN
# 1949       COHORT_CSHL_PDAC             CSHL_PDAC_8-Tumor-SM-F29TB_NA_TP
# 1950       COHORT_CSHL_PDAC             CSHL_PDAC_9-Tumor-SM-F29TC_NA_TN
# 1951       COHORT_CSHL_PDAC             CSHL_PDAC_9-Tumor-SM-F29TC_NA_TP
#
# [1952 rows x 2 columns]
